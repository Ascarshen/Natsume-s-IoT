# %% [markdown]
# # Introduction to Human Activity Recognition

# %% [markdown]
# Here we will explore some common ways of preprocessing human activity recognition data.
#
# Using the example data we will learn:
# * how to merge multiple files into one large DataFrame
# * how to split data into sliding windows
# * how to quickly extract features from a window
# * how to set the number of classes considered for classification
# * how to build a simple Random Forest Classifier and train it on HAR data
# * how to build a simple CNN and train it on HAR data
#
# Bear in mind that the sample data offered is not cleaned or high quality. You should not use it in your own experiments but it is useful for this tutorial.
#
# You will need the following packages:
# * tsfresh
# * scikit-learn
# * tensorflow

# %% [markdown]
# #### Basic imports

# %%
import pandas as pd
import numpy as np
import tsfresh
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import tensorflow as tf

import os

import matplotlib.pyplot as plt

# keras goodies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv1D, Dropout, MaxPooling1D, BatchNormalization
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from tensorflow.keras import metrics as kmetrics
import tensorflow.keras.backend as K

# %% [markdown]
# ## Loading multiple files into one large DataFrame

# %% [markdown]
# At this stage you should only be working with clean data, saved in the format required for Coursework 1. An example of such data can be found in the Data/Clean/ folder.

# %%
base_df = pd.DataFrame()

clean_data_folder = "../pdiot-data/2022"

for each_folder in os.listdir(clean_data_folder):
    files = f"{clean_data_folder}/{each_folder}"
    print (files)
    for file in os.listdir(files):
           
        full_path = f"{files}/{file}"
        # load data into a DataFrame
        new_df = pd.read_csv(full_path)
    
        # merge into the base DataFrame
        base_df = pd.concat([base_df, new_df])
# Out:
# ../pdiot-data/2022/s1923449
# ../pdiot-data/2022/s1912558
# ../pdiot-data/2022/s1853226
# ../pdiot-data/2022/s2308859
# ../pdiot-data/2022/s1977764
# ../pdiot-data/2022/s1996403
# ../pdiot-data/2022/s1925182
# ../pdiot-data/2022/s1960578
# ../pdiot-data/2022/s1918258
# ../pdiot-data/2022/s1927811
# ../pdiot-data/2022/s2299270
# ../pdiot-data/2022/s1931698
# ../pdiot-data/2022/s1941321
# ../pdiot-data/2022/s2303353
# ../pdiot-data/2022/s2298733
# ../pdiot-data/2022/s1800600
# ../pdiot-data/2022/s1834237
# ../pdiot-data/2022/s1828233
# ../pdiot-data/2022/s1892493
# ../pdiot-data/2022/s1951735
# ../pdiot-data/2022/s1911027
# ../pdiot-data/2022/s1800825
# ../pdiot-data/2022/s1961351
# ../pdiot-data/2022/s1826377
# ../pdiot-data/2022/s1973235
# ../pdiot-data/2022/s1909083
# ../pdiot-data/2022/s1836526
# ../pdiot-data/2022/s1967984
# ../pdiot-data/2022/s1809887
# ../pdiot-data/2022/s1912575
# ../pdiot-data/2022/s1962038
# ../pdiot-data/2022/s1908422
# ../pdiot-data/2022/s1918275
# ../pdiot-data/2022/s1862323
# ../pdiot-data/2022/s1858629
# ../pdiot-data/2022/s1974565
# ../pdiot-data/2022/s2303866
# ../pdiot-data/2022/s2342658
# ../pdiot-data/2022/s1976098
# ../pdiot-data/2022/s1817967
# ../pdiot-data/2022/s1998909
# ../pdiot-data/2022/s1973139
# ../pdiot-data/2022/s1956488
# ../pdiot-data/2022/s1965695
# ../pdiot-data/2022/s1925715
# ../pdiot-data/2022/s2255740
# ../pdiot-data/2022/s1910268
# ../pdiot-data/2022/s1951693
# ../pdiot-data/2022/s1911455
# ../pdiot-data/2022/s2269664
# ../pdiot-data/2022/s1948094
# ../pdiot-data/2022/s1967087
# ../pdiot-data/2022/s1957847
# ../pdiot-data/2022/s1921856
# ../pdiot-data/2022/s1912614
# ../pdiot-data/2022/s1863792
# ../pdiot-data/2022/s1832137
# ../pdiot-data/2022/s1862671
# ../pdiot-data/2022/s1925695
# ../pdiot-data/2022/s1837624
# ../pdiot-data/2022/s1832512
# ../pdiot-data/2022/s1852056
# ../pdiot-data/2022/s1915425
# ../pdiot-data/2022/s1935680
# ../pdiot-data/2022/s1842855
# ../pdiot-data/2022/s1901843
# ../pdiot-data/2022/s1920337
# ../pdiot-data/2022/s1926989
# ../pdiot-data/2022/s1732873
# ../pdiot-data/2022/s1839825
# ../pdiot-data/2022/s1931736
# ../pdiot-data/2022/s1904845
# ../pdiot-data/2022/s1810150
# ../pdiot-data/2022/s1992413
# ../pdiot-data/2022/s1923493
# ../pdiot-data/2022/s1925709
# ../pdiot-data/2022/s1957945

# %% [markdown]
# Reset the index of the base DataFrame.

# %%
base_df.reset_index(drop=True, inplace=True)
base_df
# Out:
#             timestamp   accel_x   accel_y   accel_z     gyro_x     gyro_y  \
# 0        1.664376e+12 -0.044189 -0.885071 -0.026917   7.343750  -7.156250
# 1        1.664376e+12 -0.052246 -0.939514 -0.042786   8.656250  -5.453125
# 2        1.664376e+12 -0.062500 -0.963684  0.023132   6.421875  -8.500000
# 3        1.664376e+12 -0.086182 -0.947083  0.032654   3.359375  -7.546875
# 4        1.664376e+12 -0.084229 -0.916565  0.023865   3.921875  -6.968750
# ...               ...       ...       ...       ...        ...        ...
# 1637262  1.664812e+12 -0.072754 -2.000000 -0.014709  -7.421875 -25.406250
# 1637263  1.664812e+12  0.147949 -2.000000  0.122009   7.062500 -52.468750
# 1637264  1.664812e+12  0.264160 -0.744690  0.152283  21.953125 -52.546875
# 1637265  1.664812e+12  0.248047  0.275330 -0.273254 -38.968750 -75.468750
# 1637266  1.664812e+12 -0.515869  0.125671  0.133484 -25.312500  -4.921875
#
#             gyro_z sensor_type            activity_type  activity_code  \
# 0        -2.218750     Respeck  Walking at normal speed              1
# 1        -0.453125     Respeck  Walking at normal speed              1
# 2        -0.843750     Respeck  Walking at normal speed              1
# 3        -0.687500     Respeck  Walking at normal speed              1
# 4        -1.031250     Respeck  Walking at normal speed              1
# ...            ...         ...                      ...            ...
# 1637262 -16.140625     Respeck                  Running             11
# 1637263 -36.484375     Respeck                  Running             11
# 1637264 -26.609375     Respeck                  Running             11
# 1637265 -27.953125     Respeck                  Running             11
# 1637266 -18.125000     Respeck                  Running             11
#
#         subject_id notes                                       recording_id  \
# 0         s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# 1         s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# 2         s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# 3         s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# 4         s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# ...            ...   ...                                                ...
# 1637262   s1957945   NaN       Respeck_s1957945_Running_03-10-2022_16-40-34
# 1637263   s1957945   NaN       Respeck_s1957945_Running_03-10-2022_16-40-34
# 1637264   s1957945   NaN       Respeck_s1957945_Running_03-10-2022_16-40-34
# 1637265   s1957945   NaN       Respeck_s1957945_Running_03-10-2022_16-40-34
# 1637266   s1957945   NaN       Respeck_s1957945_Running_03-10-2022_16-40-34
#
#          mag_x  mag_y  mag_z
# 0          NaN    NaN    NaN
# 1          NaN    NaN    NaN
# 2          NaN    NaN    NaN
# 3          NaN    NaN    NaN
# 4          NaN    NaN    NaN
# ...        ...    ...    ...
# 1637262    NaN    NaN    NaN
# 1637263    NaN    NaN    NaN
# 1637264    NaN    NaN    NaN
# 1637265    NaN    NaN    NaN
# 1637266    NaN    NaN    NaN
#
# [1637267 rows x 16 columns]

# %% [markdown]
# Now you can get a list of all recording ids, activities, sensor types and anything else you might need.

# %%
print(f"The data was collected using the sensors: {base_df.sensor_type.unique()}")
print(f"The data was collected for the activities: {base_df.activity_type.unique()}")
print(f"The number of unique recordings is: {len(base_df.recording_id.unique())}")
print(f"The subject IDs in the recordings are: {len(base_df.subject_id.unique())}")
# Out:
# The data was collected using the sensors: ['Respeck' 'Thingy']
# The data was collected for the activities: ['Walking at normal speed' 'Lying down on back' 'Sitting bent forward'
#  'Sitting' 'Descending stairs' 'Standing' 'Movement' 'Running'
#  'Climbing stairs' 'Lying down on stomach' 'Lying down right' 'Desk work'
#  'Lying down left' 'Sitting bent backward']
# The number of unique recordings is: 2156
# The subject IDs in the recordings are: 78

# %% [markdown]
# You can of course change the clean data folder to where you keep all the PDIoT data and you should be seeing a lot more subject IDs, unique recordings and activity types.

# %% [markdown]
# ## Splitting data into sliding windows

# %% [markdown]
# The sliding window approach is one of the most efficient ways to process Human Activity Recognition data. We saw in the last notebook that sensor data comes in the form of Time Series. One single datapoint is not enough to represent an activity, we need a larger snapshot of the signal for that. The image below shows how a sliding window achieves that.
#
# ![sliding windows](../Images/sliding_windows_complete.png "Sliding Windows")
#
# The windows can have some amount of overlap, as shown in the picture, or they can have no overlap at all in which case they would be side-by-side.
#
# Each window can now be treated as an input datapoint to whichever model you choose to train.

# %% [markdown]
# ### Watch out for separate recordings

# %% [markdown]
# You need to make sure that when you split your data into sliding windows you don't accidentally include two separate recordings in the same window. This would cause the signal from the first recording to suddenly "jump" to an unrelated value from the second recording.
#
# For this, you will have to first split up your dataset by recording (this is where the recording ID comes in), then you have to split each recording into sliding windows. At the end you can aggregate all of your resulting sliding windows in a large dataset.

# %% [markdown]
# ### Sliding windows with Pandas

# %% [markdown]
# Pandas conveniently offers built-in functions that help us create the sliding window data very easily.

# %%
example_recording = base_df[base_df.activity_code == 1]

# confim we only have one recording here
len(example_recording.recording_id.unique())
# Out:
# 154

# %%
window_size = 50 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
step_size = 25 # this is 50% overlap

window_number = 0 # start a counter at 0 to keep track of the window number

large_enough_windows = [window for window in example_recording.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]

# %%
# we then get the windows with the required overlap

overlapping_windows = large_enough_windows[::step_size]

# %%
# then we will append a window ID to each window
for window in overlapping_windows:
    window.loc[:, 'window_id'] = window_number
    window_number += 1

# %%
# now we concatenate all the resulting windows
final_sliding_windows = pd.concat(overlapping_windows).reset_index(drop=True)

# %%
final_sliding_windows
# Out:
#            timestamp   accel_x   accel_y   accel_z     gyro_x    gyro_y  \
# 0       1.664376e+12 -0.044189 -0.885071 -0.026917   7.343750 -7.156250
# 1       1.664376e+12 -0.052246 -0.939514 -0.042786   8.656250 -5.453125
# 2       1.664376e+12 -0.062500 -0.963684  0.023132   6.421875 -8.500000
# 3       1.664376e+12 -0.086182 -0.947083  0.032654   3.359375 -7.546875
# 4       1.664376e+12 -0.084229 -0.916565  0.023865   3.921875 -6.968750
# ...              ...       ...       ...       ...        ...       ...
# 233945  1.664811e+12 -0.030273 -1.120667  0.241882  -9.875000  7.140625
# 233946  1.664811e+12  0.028320 -0.952454  0.352478   8.781250  0.875000
# 233947  1.664811e+12 -0.024170 -0.785217  0.294373  14.765625  0.359375
# 233948  1.664811e+12 -0.132080 -0.772034  0.225037  10.406250 -9.484375
# 233949  1.664811e+12 -0.186035 -0.825256  0.300720   5.187500 -3.109375
#
#           gyro_z sensor_type            activity_type  activity_code  \
# 0      -2.218750     Respeck  Walking at normal speed              1
# 1      -0.453125     Respeck  Walking at normal speed              1
# 2      -0.843750     Respeck  Walking at normal speed              1
# 3      -0.687500     Respeck  Walking at normal speed              1
# 4      -1.031250     Respeck  Walking at normal speed              1
# ...          ...         ...                      ...            ...
# 233945  3.843750     Respeck  Walking at normal speed              1
# 233946  3.625000     Respeck  Walking at normal speed              1
# 233947  5.687500     Respeck  Walking at normal speed              1
# 233948  5.625000     Respeck  Walking at normal speed              1
# 233949  4.218750     Respeck  Walking at normal speed              1
#
#        subject_id notes                                       recording_id  \
# 0        s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# 1        s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# 2        s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# 3        s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# 4        s1923449   NaN  Respeck_s1923449_Walking at normal speed_28-09...
# ...           ...   ...                                                ...
# 233945   s1957945   NaN  Respeck_s1957945_Walking at normal speed_03-10...
# 233946   s1957945   NaN  Respeck_s1957945_Walking at normal speed_03-10...
# 233947   s1957945   NaN  Respeck_s1957945_Walking at normal speed_03-10...
# 233948   s1957945   NaN  Respeck_s1957945_Walking at normal speed_03-10...
# 233949   s1957945   NaN  Respeck_s1957945_Walking at normal speed_03-10...
#
#         mag_x  mag_y  mag_z  window_id
# 0         NaN    NaN    NaN          0
# 1         NaN    NaN    NaN          0
# 2         NaN    NaN    NaN          0
# 3         NaN    NaN    NaN          0
# 4         NaN    NaN    NaN          0
# ...       ...    ...    ...        ...
# 233945    NaN    NaN    NaN       4678
# 233946    NaN    NaN    NaN       4678
# 233947    NaN    NaN    NaN       4678
# 233948    NaN    NaN    NaN       4678
# 233949    NaN    NaN    NaN       4678
#
# [233950 rows x 17 columns]

# %% [markdown]
# You can plot each window to see the signals. Here we will plot the first four windows of the walking activity.

# %%
first_four_windows = [group for _, group in final_sliding_windows[final_sliding_windows.window_id < 4].groupby("window_id")]

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 6))

for i in range(4):
    ax[i].plot(first_four_windows[i]['gyro_x'])
    ax[i].plot(first_four_windows[i]['gyro_y'])
    ax[i].plot(first_four_windows[i]['gyro_z'])
    ax[i].set_title(f"Window number = {first_four_windows[i].window_id.values[0]}")

# %% [markdown]
# It's also interesting to observe the dimensionality of one window. Considering just the accelerometer and gyroscope signals, with all three axes, the resulting dimensionality of one window is:

# %%
columns_of_interest = ['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

# %%
np.array(first_four_windows[0][columns_of_interest]).shape
# Out:
# (50, 6)

# %% [markdown]
# ## From sliding windows to datapoints

# %% [markdown]
# Each sliding window needs to be further processed in order to represent an appropriate input datapoint. The preprocessing methods might differ depending on which type of model you choose to use.
#
# You can also do further processing on the signal types and axes, for example smooth the signal, apply axis fusion, eliminate noise etc.
#
# Here we will discuss simple examples without any preprocessing.

# %% [markdown]
# ### Feature extraction with tsfresh

# %% [markdown]
# One quick and simple method to consider for HAR is a [Random Forest Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html). It can take a multi-dimensional datapoint as input and can output a classification.
#
# We can transform each window of data into one single, multidimensional datapoint by applying simple computations using the [tsfresh](https://tsfresh.readthedocs.io/en/latest/text/feature_extraction_settings.html) package.

# %%
feature_list = []

for col in columns_of_interest:
    new_features = tsfresh.extract_features(timeseries_container=final_sliding_windows, column_id='window_id',
                        column_value=col, default_fc_parameters=tsfresh.feature_extraction.MinimalFCParameters())
    
    feature_list.append(new_features)
    
feature_list = pd.concat(feature_list, axis=1)

feature_list
# Out:
# Feature Extraction: 100%|██████████| 40/40 [00:00<00:00, 53.07it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:00<00:00, 59.83it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:00<00:00, 59.10it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:01<00:00, 30.59it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:00<00:00, 53.38it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:00<00:00, 50.75it/s]
#       accel_x__sum_values  accel_x__median  accel_x__mean  accel_x__length  \
# 0               -0.422852        -0.027588      -0.008457             50.0
# 1               -0.365479        -0.005249      -0.007310             50.0
# 2               -0.324463        -0.020020      -0.006489             50.0
# 3               -0.848145        -0.032227      -0.016963             50.0
# 4               -1.536621        -0.032837      -0.030732             50.0
# ...                   ...              ...            ...              ...
# 4674            -4.779297        -0.108521      -0.095586             50.0
# 4675            -4.676514        -0.092285      -0.093530             50.0
# 4676            -6.594971        -0.154419      -0.131899             50.0
# 4677            -6.491211        -0.147095      -0.129824             50.0
# 4678            -5.616699        -0.132080      -0.112334             50.0
#
#       accel_x__standard_deviation  accel_x__variance  \
# 0                        0.133998           0.017956
# 1                        0.140565           0.019759
# 2                        0.132175           0.017470
# 3                        0.142832           0.020401
# 4                        0.129519           0.016775
# ...                           ...                ...
# 4674                     0.101038           0.010209
# 4675                     0.103097           0.010629
# 4676                     0.090939           0.008270
# 4677                     0.081392           0.006625
# 4678                     0.096702           0.009351
#
#       accel_x__root_mean_square  accel_x__maximum  accel_x__minimum  \
# 0                      0.134265          0.387939         -0.367432
# 1                      0.140755          0.309082         -0.367432
# 2                      0.132334          0.426514         -0.334717
# 3                      0.143836          0.426514         -0.484375
# 4                      0.133115          0.359863         -0.484375
# ...                         ...               ...               ...
# 4674                   0.139087          0.213135         -0.246582
# 4675                   0.139201          0.213135         -0.277832
# 4676                   0.160210          0.164062         -0.295166
# 4677                   0.153229          0.115723         -0.295166
# 4678                   0.148224          0.144043         -0.253418
#
#       accel_y__sum_values  ...  gyro_y__minimum  gyro_z__sum_values  \
# 0              -50.015991  ...       -16.593750          -23.484375
# 1              -49.590942  ...       -21.968750          -18.390625
# 2              -49.405640  ...       -21.968750          -30.546875
# 3              -50.494019  ...       -18.656250          -72.531250
# 4              -49.048950  ...       -19.359375          -52.765625
# ...                   ...  ...              ...                 ...
# 4674           -46.797730  ...       -14.781250           15.187500
# 4675           -47.789185  ...       -21.468750          -21.781250
# 4676           -47.413452  ...       -21.468750            9.546875
# 4677           -46.274292  ...       -12.843750           29.000000
# 4678           -46.924927  ...       -22.656250          -41.031250
#
#       gyro_z__median  gyro_z__mean  gyro_z__length  \
# 0          -0.062500     -0.469687            50.0
# 1           0.242188     -0.367812            50.0
# 2          -0.296875     -0.610938            50.0
# 3           0.039062     -1.450625            50.0
# 4           0.445312     -1.055313            50.0
# ...              ...           ...             ...
# 4674        0.539062      0.303750            50.0
# 4675       -0.789062     -0.435625            50.0
# 4676       -0.171875      0.190938            50.0
# 4677        0.890625      0.580000            50.0
# 4678        0.601562     -0.820625            50.0
#
#       gyro_z__standard_deviation  gyro_z__variance  gyro_z__root_mean_square  \
# 0                       5.933225         35.203158                  5.951787
# 1                       6.841824         46.810559                  6.851704
# 2                       7.177868         51.521790                  7.203821
# 3                       7.601165         57.777709                  7.738347
# 4                       6.134546         37.632658                  6.224656
# ...                          ...               ...                       ...
# 4674                    4.563631         20.826730                  4.573729
# 4675                    5.314619         28.245172                  5.332442
# 4676                    5.455244         29.759690                  5.458585
# 4677                    5.156752         26.592096                  5.189267
# 4678                    5.282491         27.904709                  5.345852
#
#       gyro_z__maximum  gyro_z__minimum
# 0           13.187500       -20.609375
# 1           14.625000       -20.781250
# 2           14.625000       -21.437500
# 3           14.562500       -21.640625
# 4            7.843750       -21.640625
# ...               ...              ...
# 4674         7.453125       -11.953125
# 4675        11.578125       -13.187500
# 4676        11.578125       -13.187500
# 4677         8.718750       -10.984375
# 4678         7.093750       -16.156250
#
# [4679 rows x 54 columns]

# %% [markdown]
# Now the index represents the window ID, and each row in the DataFrame represents a multi-dimensional datapoint which we can use as input to the RFC.
#
# You can use the window ID to refer back to the initial dataframe and get the class (activity type) for each window.

# %% [markdown]
# We will now process both recordings so that we have two classes for our classifier. For your own work you should only aim to perform classification on data from one sensor.

# %%
window_size = 50 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
step_size = 25 # this is 50% overlap

window_number = 0 # start a counter at 0 to keep track of the window number

all_overlapping_windows = []

for rid, group in base_df.groupby("recording_id"):
    print(f"Processing rid = {rid}")
    
    large_enough_windows = [window for window in group.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]
    
    overlapping_windows = large_enough_windows[::step_size] 
    
    # then we will append a window ID to each window
    for window in overlapping_windows:
        window.loc[:, 'window_id'] = window_number
        window_number += 1
    
    
    all_overlapping_windows.append(pd.concat(overlapping_windows).reset_index(drop=True))
# Out:
# Processing rid = C:\2022\iot\our_branch\Labs\Data\2022_A\day1\Respeck_s1810150_Standing_06-10-2022_20-49-00
# Processing rid = Respeck_s1732873_Climbing stairs_04-10-2022_14-29-16
# Processing rid = Respeck_s1732873_Descending stairs_04-10-2022_14-29-57
# Processing rid = Respeck_s1732873_Desk work_05-10-2022_09-10-44
# Processing rid = Respeck_s1732873_Lying down left_04-10-2022_14-12-42
# Processing rid = Respeck_s1732873_Lying down on back_04-10-2022_14-11-56
# Processing rid = Respeck_s1732873_Lying down on stomach_04-10-2022_14-14-08
# Processing rid = Respeck_s1732873_Lying down right_04-10-2022_14-13-24
# Processing rid = Respeck_s1732873_Movement_05-10-2022_10-08-43
# Processing rid = Respeck_s1732873_Running_04-10-2022_14-32-19
# Processing rid = Respeck_s1732873_Sitting bent backward_04-10-2022_14-09-25
# Processing rid = Respeck_s1732873_Sitting bent forward_04-10-2022_14-08-40
# Processing rid = Respeck_s1732873_Sitting_04-10-2022_14-07-59
# Processing rid = Respeck_s1732873_Standing_04-10-2022_14-10-08
# Processing rid = Respeck_s1732873_Walking at normal speed_04-10-2022_14-31-37
# Processing rid = Respeck_s1800600_Climbing stairs_05-10-2022_14-07-25
# Processing rid = Respeck_s1800600_Descending stairs_05-10-2022_14-09-55
# Processing rid = Respeck_s1800600_Desk work_28-09-2022_13-35-51
# Processing rid = Respeck_s1800600_Lying down left_28-09-2022_13-02-18
# Processing rid = Respeck_s1800600_Lying down on back_28-09-2022_13-06-41
# Processing rid = Respeck_s1800600_Lying down on stomach_28-09-2022_13-05-16
# Processing rid = Respeck_s1800600_Lying down right_28-09-2022_13-03-48
# Processing rid = Respeck_s1800600_Movement_28-09-2022_13-37-54
# Processing rid = Respeck_s1800600_Running_28-09-2022_13-27-08
# Processing rid = Respeck_s1800600_Sitting bent backward_28-09-2022_12-57-52
# Processing rid = Respeck_s1800600_Sitting bent forward_28-09-2022_12-55-52
# Processing rid = Respeck_s1800600_Sitting_28-09-2022_12-49-23
# Processing rid = Respeck_s1800600_Standing_28-09-2022_12-59-33
# Processing rid = Respeck_s1800600_Walking at normal speed_28-09-2022_13-20-53
# Processing rid = Respeck_s1800825_Climbing stairs_30-09-2022_19-49-49
# Processing rid = Respeck_s1800825_Descending stairs_30-09-2022_19-57-49
# Processing rid = Respeck_s1800825_Desk work_28-09-2022_16-22-35
# Processing rid = Respeck_s1800825_Lying down left_28-09-2022_16-13-44
# Processing rid = Respeck_s1800825_Lying down on back_28-09-2022_16-12-08
# Processing rid = Respeck_s1800825_Lying down on stomach_28-09-2022_16-16-27
# Processing rid = Respeck_s1800825_Lying down right_28-09-2022_16-15-03
# Processing rid = Respeck_s1800825_Movement_28-09-2022_16-20-11
# Processing rid = Respeck_s1800825_Running_30-09-2022_20-49-08
# Processing rid = Respeck_s1800825_Sitting bent backward_28-09-2022_16-08-56
# Processing rid = Respeck_s1800825_Sitting bent forward_28-09-2022_16-07-27
# Processing rid = Respeck_s1800825_Sitting_13-10-2022_16-16-45
# Processing rid = Respeck_s1800825_Standing_28-09-2022_16-10-16
# Processing rid = Respeck_s1800825_Walking at normal speed_30-09-2022_20-47-13
# Processing rid = Respeck_s1809887_Climbing stairs_29-09-2022_12-41-55
# Processing rid = Respeck_s1809887_Descending stairs_29-09-2022_12-26-57
# Processing rid = Respeck_s1809887_Desk work_27-09-2022_15-09-34
# Processing rid = Respeck_s1809887_Lying down left_27-09-2022_15-00-55
# Processing rid = Respeck_s1809887_Lying down on back_27-09-2022_14-59-54
# Processing rid = Respeck_s1809887_Lying down on stomach_27-09-2022_15-04-05
# Processing rid = Respeck_s1809887_Lying down right_27-09-2022_15-03-09
# Processing rid = Respeck_s1809887_Movement_27-09-2022_15-11-36
# Processing rid = Respeck_s1809887_Running_29-09-2022_12-37-49
# Processing rid = Respeck_s1809887_Sitting bent backward_27-09-2022_14-56-45
# Processing rid = Respeck_s1809887_Sitting bent forward_27-09-2022_14-55-20
# Processing rid = Respeck_s1809887_Sitting_27-09-2022_14-48-42
# Processing rid = Respeck_s1809887_Standing_27-09-2022_14-51-10
# Processing rid = Respeck_s1809887_Walking at normal speed_27-09-2022_15-39-52
# Processing rid = Respeck_s1810150_Climbing stairs_22-09-2022_19-35-27
# Processing rid = Respeck_s1810150_Descending stairs_22-09-2022_19-49-57
# Processing rid = Respeck_s1810150_Desk work_06-10-2022_20-41-46
# Processing rid = Respeck_s1810150_Lying down left_22-09-2022_11-45-09
# Processing rid = Respeck_s1810150_Lying down on back_22-09-2022_11-44-14
# Processing rid = Respeck_s1810150_Lying down on stomach_22-09-2022_11-46-54
# Processing rid = Respeck_s1810150_Lying down right_22-09-2022_11-46-01
# Processing rid = Respeck_s1810150_Movement_06-10-2022_20-27-45
# Processing rid = Respeck_s1810150_Running_22-09-2022_14-06-03
# Processing rid = Respeck_s1810150_Sitting bent backward_22-09-2022_11-40-46
# Processing rid = Respeck_s1810150_Sitting bent forward_06-10-2022_20-28-47
# Processing rid = Respeck_s1810150_Sitting_22-09-2022_11-49-45
# Processing rid = Respeck_s1810150_Walking at normal speed_22-09-2022_12-28-56
# Processing rid = Respeck_s1817967_Climbing stairs_30-09-2022_16-32-18
# Processing rid = Respeck_s1817967_Descending stairs_30-09-2022_16-32-59
# Processing rid = Respeck_s1817967_Desk work_30-09-2022_16-34-46
# Processing rid = Respeck_s1817967_Lying down left_30-09-2022_16-25-54
# Processing rid = Respeck_s1817967_Lying down on back_30-09-2022_16-24-43
# Processing rid = Respeck_s1817967_Lying down on stomach_30-09-2022_16-27-33
# Processing rid = Respeck_s1817967_Lying down right_30-09-2022_16-26-44
# Processing rid = Respeck_s1817967_Movement_30-09-2022_16-35-29
# Processing rid = Respeck_s1817967_Running_30-09-2022_16-30-26
# Processing rid = Respeck_s1817967_Sitting bent backward_30-09-2022_16-21-38
# Processing rid = Respeck_s1817967_Sitting bent forward_30-09-2022_16-23-28
# Processing rid = Respeck_s1817967_Sitting_30-09-2022_16-19-45
# Processing rid = Respeck_s1817967_Standing_30-09-2022_16-22-44
# Processing rid = Respeck_s1817967_Walking at normal speed_30-09-2022_16-29-44
# Processing rid = Respeck_s1826377_Climbing stairs_07-10-2022_09-28-54
# Processing rid = Respeck_s1826377_Descending stairs_07-10-2022_09-29-45
# Processing rid = Respeck_s1826377_Desk work_30-09-2022_02-05-57
# Processing rid = Respeck_s1826377_Lying down left_28-09-2022_22-20-25
# Processing rid = Respeck_s1826377_Lying down on back_28-09-2022_22-18-43
# Processing rid = Respeck_s1826377_Lying down on stomach_28-09-2022_22-28-16
# Processing rid = Respeck_s1826377_Lying down right_28-09-2022_22-22-54
# Processing rid = Respeck_s1826377_Movement_28-09-2022_22-37-31
# Processing rid = Respeck_s1826377_Running_28-09-2022_23-03-32
# Processing rid = Respeck_s1826377_Sitting bent backward_28-09-2022_22-13-25
# Processing rid = Respeck_s1826377_Sitting bent forward_28-09-2022_22-08-54
# Processing rid = Respeck_s1826377_Sitting_28-09-2022_22-06-13
# Processing rid = Respeck_s1826377_Standing_28-09-2022_22-15-15
# Processing rid = Respeck_s1826377_Walking at normal speed_28-09-2022_22-58-25
# Processing rid = Respeck_s1828233_Climbing stairs_22-09-2022_14-07-52
# Processing rid = Respeck_s1828233_Descending stairs_22-09-2022_14-09-08
# Processing rid = Respeck_s1828233_Desk work_22-09-2022_14-04-14
# Processing rid = Respeck_s1828233_Lying down left_22-09-2022_13-58-53
# Processing rid = Respeck_s1828233_Lying down on back_22-09-2022_13-56-54
# Processing rid = Respeck_s1828233_Lying down on stomach_22-09-2022_14-01-43
# Processing rid = Respeck_s1828233_Lying down right_22-09-2022_14-00-18
# Processing rid = Respeck_s1828233_Movement_22-09-2022_14-05-45
# Processing rid = Respeck_s1828233_Running_22-09-2022_15-01-25
# Processing rid = Respeck_s1828233_Sitting bent backward_22-09-2022_13-53-43
# Processing rid = Respeck_s1828233_Sitting bent forward_22-09-2022_13-52-18
# Processing rid = Respeck_s1828233_Sitting_22-09-2022_13-50-44
# Processing rid = Respeck_s1828233_Standing_22-09-2022_13-55-08
# Processing rid = Respeck_s1828233_Walking at normal speed_22-09-2022_15-00-03
# Processing rid = Respeck_s1832137_Climbing stairs_10-10-2022_17-08-38
# Processing rid = Respeck_s1832137_Descending stairs_10-10-2022_17-09-32
# Processing rid = Respeck_s1832137_Desk work_10-10-2022_17-03-18
# Processing rid = Respeck_s1832137_Lying down left_10-10-2022_16-59-00
# Processing rid = Respeck_s1832137_Lying down on back_10-10-2022_16-57-50
# Processing rid = Respeck_s1832137_Lying down on stomach_10-10-2022_17-01-05
# Processing rid = Respeck_s1832137_Lying down right_10-10-2022_17-00-00
# Processing rid = Respeck_s1832137_Movement_10-10-2022_17-04-40
# Processing rid = Respeck_s1832137_Running_10-10-2022_17-15-45
# Processing rid = Respeck_s1832137_Sitting bent backward_10-10-2022_16-40-01
# Processing rid = Respeck_s1832137_Sitting bent forward_10-10-2022_16-38-35
# Processing rid = Respeck_s1832137_Sitting_10-10-2022_16-37-50
# Processing rid = Respeck_s1832137_Standing_10-10-2022_16-55-55
# Processing rid = Respeck_s1832137_Walking at normal speed_10-10-2022_17-12-43
# Processing rid = Respeck_s1832512_Climbing stairs_05-10-2022_13-42-13
# Processing rid = Respeck_s1832512_Descending stairs_05-10-2022_13-42-59
# Processing rid = Respeck_s1832512_Desk work_02-10-2022_15-29-57
# Processing rid = Respeck_s1832512_Lying down left_05-10-2022_11-39-41
# Processing rid = Respeck_s1832512_Lying down on back_02-10-2022_15-41-05
# Processing rid = Respeck_s1832512_Lying down on stomach_02-10-2022_15-44-18
# Processing rid = Respeck_s1832512_Lying down right_02-10-2022_15-40-15
# Processing rid = Respeck_s1832512_Movement_05-10-2022_11-26-41
# Processing rid = Respeck_s1832512_Running_05-10-2022_11-37-48
# Processing rid = Respeck_s1832512_Sitting bent backward_02-10-2022_15-28-22
# Processing rid = Respeck_s1832512_Sitting bent forward_07-10-2022_10-27-44
# Processing rid = Respeck_s1832512_Sitting_02-10-2022_15-24-49
# Processing rid = Respeck_s1832512_Standing_05-10-2022_11-25-23
# Processing rid = Respeck_s1832512_Walking at normal speed_07-10-2022_10-33-05
# Processing rid = Respeck_s1836526_Climbing stairs_23-09-2022_13-15-49
# Processing rid = Respeck_s1836526_Descending stairs_23-09-2022_13-17-22
# Processing rid = Respeck_s1836526_Desk work_23-09-2022_13-29-40
# Processing rid = Respeck_s1836526_Lying down left_23-09-2022_13-21-48
# Processing rid = Respeck_s1836526_Lying down on back_23-09-2022_13-25-40
# Processing rid = Respeck_s1836526_Lying down on stomach_23-09-2022_13-24-23
# Processing rid = Respeck_s1836526_Lying down right_23-09-2022_13-23-05
# Processing rid = Respeck_s1836526_Movement_23-09-2022_13-08-51
# Processing rid = Respeck_s1836526_Running_23-09-2022_13-07-03
# Processing rid = Respeck_s1836526_Sitting bent backward_23-09-2022_13-33-29
# Processing rid = Respeck_s1836526_Sitting bent forward_23-09-2022_13-32-16
# Processing rid = Respeck_s1836526_Sitting_23-09-2022_13-31-03
# Processing rid = Respeck_s1836526_Standing_23-09-2022_13-34-57
# Processing rid = Respeck_s1836526_Walking at normal speed_23-09-2022_13-05-26
# Processing rid = Respeck_s1837624_Climbing stairs_04-10-2022_17-16-01
# Processing rid = Respeck_s1837624_Descending stairs_04-10-2022_17-02-31
# Processing rid = Respeck_s1837624_Desk work_28-09-2022_15-17-43
# Processing rid = Respeck_s1837624_Lying down left_04-10-2022_20-15-31
# Processing rid = Respeck_s1837624_Lying down on back_28-09-2022_15-14-07
# Processing rid = Respeck_s1837624_Lying down on stomach_04-10-2022_20-14-11
# Processing rid = Respeck_s1837624_Lying down right_04-10-2022_20-12-36
# Processing rid = Respeck_s1837624_Movement_28-09-2022_15-18-58
# Processing rid = Respeck_s1837624_Running_04-10-2022_17-19-09
# Processing rid = Respeck_s1837624_Sitting bent backward_28-09-2022_15-06-46
# Processing rid = Respeck_s1837624_Sitting bent forward_04-10-2022_20-07-59
# Processing rid = Respeck_s1837624_Sitting_04-10-2022_20-06-04
# Processing rid = Respeck_s1837624_Standing_04-10-2022_20-10-08
# Processing rid = Respeck_s1837624_Walking at normal speed_04-10-2022_20-18-34
# Processing rid = Respeck_s1839825_Climbing stairs_22-09-2022_13-42-20
# Processing rid = Respeck_s1839825_Descending stairs_22-09-2022_13-43-38
# Processing rid = Respeck_s1839825_Desk work_22-09-2022_13-37-19
# Processing rid = Respeck_s1839825_Lying down left_22-09-2022_13-30-46
# Processing rid = Respeck_s1839825_Lying down on back_22-09-2022_13-29-01
# Processing rid = Respeck_s1839825_Lying down on stomach_22-09-2022_13-34-28
# Processing rid = Respeck_s1839825_Lying down right_22-09-2022_13-33-01
# Processing rid = Respeck_s1839825_Movement_22-09-2022_13-38-55
# Processing rid = Respeck_s1839825_Running_22-09-2022_14-55-01
# Processing rid = Respeck_s1839825_Sitting bent backward_22-09-2022_13-22-23
# Processing rid = Respeck_s1839825_Sitting bent forward_22-09-2022_13-21-20
# Processing rid = Respeck_s1839825_Sitting_22-09-2022_13-20-18
# Processing rid = Respeck_s1839825_Standing_22-09-2022_13-23-11
# Processing rid = Respeck_s1839825_Walking at normal speed_22-09-2022_14-53-41
# Processing rid = Respeck_s1842855_Climbing stairs_04-10-2022_17-03-32
# Processing rid = Respeck_s1842855_Descending stairs_04-10-2022_17-04-23
# Processing rid = Respeck_s1842855_Desk work_04-10-2022_00-02-30
# Processing rid = Respeck_s1842855_Lying down left_03-10-2022_23-56-47
# Processing rid = Respeck_s1842855_Lying down on back_03-10-2022_23-55-46
# Processing rid = Respeck_s1842855_Lying down on stomach_03-10-2022_23-59-57
# Processing rid = Respeck_s1842855_Lying down right_03-10-2022_23-58-54
# Processing rid = Respeck_s1842855_Movement_04-10-2022_00-05-19
# Processing rid = Respeck_s1842855_Running_04-10-2022_00-13-13
# Processing rid = Respeck_s1842855_Sitting bent backward_03-10-2022_23-48-37
# Processing rid = Respeck_s1842855_Sitting bent forward_03-10-2022_23-47-07
# Processing rid = Respeck_s1842855_Sitting_03-10-2022_23-45-36
# Processing rid = Respeck_s1842855_Standing_03-10-2022_23-50-06
# Processing rid = Respeck_s1842855_Walking at normal speed_04-10-2022_00-16-28
# Processing rid = Respeck_s1852056_Climbing stairs_05-10-2022_14-35-44
# Processing rid = Respeck_s1852056_Descending stairs_05-10-2022_14-39-23
# Processing rid = Respeck_s1852056_Desk work_05-10-2022_15-06-36
# Processing rid = Respeck_s1852056_Lying down left_05-10-2022_15-16-11
# Processing rid = Respeck_s1852056_Lying down on back_05-10-2022_15-11-38
# Processing rid = Respeck_s1852056_Lying down on stomach_05-10-2022_15-13-53
# Processing rid = Respeck_s1852056_Lying down right_05-10-2022_15-17-15
# Processing rid = Respeck_s1852056_Movement_05-10-2022_15-10-01
# Processing rid = Respeck_s1852056_Running_05-10-2022_15-55-29
# Processing rid = Respeck_s1852056_Sitting bent backward_05-10-2022_15-03-21
# Processing rid = Respeck_s1852056_Sitting bent forward_05-10-2022_14-44-04
# Processing rid = Respeck_s1852056_Sitting_05-10-2022_14-43-03
# Processing rid = Respeck_s1852056_Standing_05-10-2022_15-07-34
# Processing rid = Respeck_s1852056_Walking at normal speed_05-10-2022_15-52-26
# Processing rid = Respeck_s1853226_Climbing stairs_28-09-2022_16-38-36
# Processing rid = Respeck_s1853226_Descending stairs_28-09-2022_16-41-08
# Processing rid = Respeck_s1853226_Desk work_28-09-2022_16-36-56
# Processing rid = Respeck_s1853226_Lying down left_28-09-2022_16-22-09
# Processing rid = Respeck_s1853226_Lying down on back_28-09-2022_16-19-43
# Processing rid = Respeck_s1853226_Lying down on stomach_28-09-2022_16-31-43
# Processing rid = Respeck_s1853226_Lying down right_28-09-2022_16-24-19
# Processing rid = Respeck_s1853226_Movement_28-09-2022_16-33-59
# Processing rid = Respeck_s1853226_Running_28-09-2022_16-55-34
# Processing rid = Respeck_s1853226_Sitting bent backward_28-09-2022_16-15-24
# Processing rid = Respeck_s1853226_Sitting bent forward_28-09-2022_16-12-21
# Processing rid = Respeck_s1853226_Sitting_28-09-2022_16-11-24
# Processing rid = Respeck_s1853226_Standing_28-09-2022_16-17-29
# Processing rid = Respeck_s1853226_Walking at normal speed_28-09-2022_16-53-27
# Processing rid = Respeck_s1858629_Climbing stairs_22-09-2022_20-05-01
# Processing rid = Respeck_s1858629_Descending stairs_22-09-2022_20-06-01
# Processing rid = Respeck_s1858629_Desk work_26-09-2022_12-45-36
# Processing rid = Respeck_s1858629_Lying down left_26-09-2022_13-24-23
# Processing rid = Respeck_s1858629_Lying down on back_26-09-2022_13-15-13
# Processing rid = Respeck_s1858629_Lying down on stomach_26-09-2022_13-01-18
# Processing rid = Respeck_s1858629_Lying down right_26-09-2022_13-28-36
# Processing rid = Respeck_s1858629_Movement_26-09-2022_14-00-19
# Processing rid = Respeck_s1858629_Running_07-10-2022_08-52-32
# Processing rid = Respeck_s1858629_Sitting bent backward_26-09-2022_12-40-05
# Processing rid = Respeck_s1858629_Sitting bent forward_26-09-2022_12-17-47
# Processing rid = Respeck_s1858629_Sitting_26-09-2022_12-06-10
# Processing rid = Respeck_s1858629_Standing_26-09-2022_12-56-13
# Processing rid = Respeck_s1858629_Walking at normal speed_07-10-2022_08-46-49
# Processing rid = Respeck_s1862323_Climbing stairs_02-10-2022_00-05-31
# Processing rid = Respeck_s1862323_Descending stairs_02-10-2022_00-13-57
# Processing rid = Respeck_s1862323_Desk work_01-10-2022_23-14-04
# Processing rid = Respeck_s1862323_Lying down left_01-10-2022_22-45-29
# Processing rid = Respeck_s1862323_Lying down on back_01-10-2022_22-39-10
# Processing rid = Respeck_s1862323_Lying down on stomach_01-10-2022_23-05-46
# Processing rid = Respeck_s1862323_Lying down right_01-10-2022_22-54-56
# Processing rid = Respeck_s1862323_Movement_01-10-2022_23-17-54
# Processing rid = Respeck_s1862323_Running_01-10-2022_23-59-27
# Processing rid = Respeck_s1862323_Sitting bent backward_01-10-2022_22-25-45
# Processing rid = Respeck_s1862323_Sitting bent forward_01-10-2022_22-03-29
# Processing rid = Respeck_s1862323_Sitting_01-10-2022_21-57-58
# Processing rid = Respeck_s1862323_Standing_01-10-2022_22-30-55
# Processing rid = Respeck_s1862323_Walking at normal speed_01-10-2022_23-55-56
# Processing rid = Respeck_s1862671_Climbing stairs_22-09-2022_21-02-33
# Processing rid = Respeck_s1862671_Descending stairs_22-09-2022_21-01-44
# Processing rid = Respeck_s1862671_Desk work_22-09-2022_21-58-38
# Processing rid = Respeck_s1862671_Lying down left_05-10-2022_22-56-11
# Processing rid = Respeck_s1862671_Lying down on back_22-09-2022_21-32-19
# Processing rid = Respeck_s1862671_Lying down on stomach_22-09-2022_21-40-51
# Processing rid = Respeck_s1862671_Lying down right_05-10-2022_22-54-41
# Processing rid = Respeck_s1862671_Movement_22-09-2022_22-58-03
# Processing rid = Respeck_s1862671_Running_22-09-2022_22-51-08
# Processing rid = Respeck_s1862671_Sitting bent backward_05-10-2022_22-25-52
# Processing rid = Respeck_s1862671_Sitting bent forward_22-09-2022_21-50-21
# Processing rid = Respeck_s1862671_Sitting_04-10-2022_12-45-29
# Processing rid = Respeck_s1862671_Standing_04-10-2022_12-43-00
# Processing rid = Respeck_s1862671_Walking at normal speed_22-09-2022_21-09-24
# Processing rid = Respeck_s1863792_Climbing stairs_05-10-2022_16-17-08
# Processing rid = Respeck_s1863792_Descending stairs_05-10-2022_16-18-15
# Processing rid = Respeck_s1863792_Desk work_23-09-2022_15-49-23
# Processing rid = Respeck_s1863792_Lying down left_23-09-2022_15-34-31
# Processing rid = Respeck_s1863792_Lying down on back_23-09-2022_15-39-05
# Processing rid = Respeck_s1863792_Lying down on stomach_23-09-2022_15-37-42
# Processing rid = Respeck_s1863792_Lying down right_23-09-2022_15-36-02
# Processing rid = Respeck_s1863792_Movement_23-09-2022_15-53-04
# Processing rid = Respeck_s1863792_Running_23-09-2022_17-09-20
# Processing rid = Respeck_s1863792_Sitting bent backward_23-09-2022_15-28-43
# Processing rid = Respeck_s1863792_Sitting bent forward_23-09-2022_15-27-38
# Processing rid = Respeck_s1863792_Sitting_30-09-2022_16-06-38
# Processing rid = Respeck_s1863792_Standing_30-09-2022_16-07-41
# Processing rid = Respeck_s1863792_Walking at normal speed_23-09-2022_15-42-20
# Processing rid = Respeck_s1892493_Climbing stairs_28-09-2022_14-51-30
# Processing rid = Respeck_s1892493_Descending stairs_28-09-2022_14-53-01
# Processing rid = Respeck_s1892493_Desk work_28-09-2022_14-36-16
# Processing rid = Respeck_s1892493_Lying down left_28-09-2022_14-48-34
# Processing rid = Respeck_s1892493_Lying down on back_28-09-2022_14-38-02
# Processing rid = Respeck_s1892493_Lying down on stomach_28-09-2022_14-44-29
# Processing rid = Respeck_s1892493_Lying down right_28-09-2022_14-49-57
# Processing rid = Respeck_s1892493_Movement_28-09-2022_15-13-44
# Processing rid = Respeck_s1892493_Running_28-09-2022_15-06-19
# Processing rid = Respeck_s1892493_Sitting bent backward_28-09-2022_14-33-02
# Processing rid = Respeck_s1892493_Sitting bent forward_28-09-2022_14-30-54
# Processing rid = Respeck_s1892493_Sitting_28-09-2022_14-30-05
# Processing rid = Respeck_s1892493_Standing_28-09-2022_14-33-59
# Processing rid = Respeck_s1892493_Walking at normal speed_28-09-2022_15-02-22
# Processing rid = Respeck_s1901843_Climbing stairs_06-10-2022_18-17-51
# Processing rid = Respeck_s1901843_Descending stairs_06-10-2022_18-18-51
# Processing rid = Respeck_s1901843_Desk work_24-09-2022_16-43-27
# Processing rid = Respeck_s1901843_Lying down left_24-09-2022_16-46-19
# Processing rid = Respeck_s1901843_Lying down on back_24-09-2022_16-45-35
# Processing rid = Respeck_s1901843_Lying down on stomach_24-09-2022_16-47-53
# Processing rid = Respeck_s1901843_Lying down right_24-09-2022_16-47-10
# Processing rid = Respeck_s1901843_Movement_24-09-2022_16-42-44
# Processing rid = Respeck_s1901843_Running_24-09-2022_16-40-20
# Processing rid = Respeck_s1901843_Sitting bent backward_24-09-2022_16-37-06
# Processing rid = Respeck_s1901843_Sitting bent forward_24-09-2022_16-36-24
# Processing rid = Respeck_s1901843_Sitting_24-09-2022_16-35-40
# Processing rid = Respeck_s1901843_Standing_24-09-2022_16-37-55
# Processing rid = Respeck_s1901843_Walking at normal speed_24-09-2022_16-39-24
# Processing rid = Respeck_s1904845_Climbing stairs_05-10-2022_19-15-41
# Processing rid = Respeck_s1904845_Descending stairs_05-10-2022_19-14-28
# Processing rid = Respeck_s1904845_Desk work_05-10-2022_19-23-56
# Processing rid = Respeck_s1904845_Lying down left_05-10-2022_18-56-06
# Processing rid = Respeck_s1904845_Lying down on back_05-10-2022_18-53-54
# Processing rid = Respeck_s1904845_Lying down on stomach_03-10-2022_16-55-53
# Processing rid = Respeck_s1904845_Lying down right_05-10-2022_18-58-12
# Processing rid = Respeck_s1904845_Movement_03-10-2022_17-10-01
# Processing rid = Respeck_s1904845_Running_05-10-2022_19-11-23
# Processing rid = Respeck_s1904845_Sitting bent backward_05-10-2022_18-49-52
# Processing rid = Respeck_s1904845_Sitting bent forward_05-10-2022_18-48-50
# Processing rid = Respeck_s1904845_Sitting_03-10-2022_16-49-45
# Processing rid = Respeck_s1904845_Standing_03-10-2022_16-52-27
# Processing rid = Respeck_s1904845_Walking at normal speed_05-10-2022_19-07-00
# Processing rid = Respeck_s1908422_Climbing stairs_05-10-2022_16-23-16
# Processing rid = Respeck_s1908422_Descending stairs_05-10-2022_16-24-12
# Processing rid = Respeck_s1908422_Desk work_23-09-2022_16-21-33
# Processing rid = Respeck_s1908422_Lying down left_30-09-2022_16-14-37
# Processing rid = Respeck_s1908422_Lying down on back_23-09-2022_16-17-41
# Processing rid = Respeck_s1908422_Lying down on stomach_30-09-2022_16-15-34
# Processing rid = Respeck_s1908422_Lying down right_30-09-2022_16-16-38
# Processing rid = Respeck_s1908422_Movement_23-09-2022_16-23-08
# Processing rid = Respeck_s1908422_Running_23-09-2022_17-06-43
# Processing rid = Respeck_s1908422_Sitting bent backward_30-09-2022_16-19-42
# Processing rid = Respeck_s1908422_Sitting bent forward_30-09-2022_16-20-33
# Processing rid = Respeck_s1908422_Sitting_30-09-2022_16-21-46
# Processing rid = Respeck_s1908422_Standing_30-09-2022_16-24-06
# Processing rid = Respeck_s1908422_Walking at normal speed_23-09-2022_16-19-23
# Processing rid = Respeck_s1909083_Climbing stairs_30-09-2022_02-35-55
# Processing rid = Respeck_s1909083_Descending stairs_30-09-2022_02-36-44
# Processing rid = Respeck_s1909083_Desk work_30-09-2022_03-19-32
# Processing rid = Respeck_s1909083_Lying down left_30-09-2022_02-04-31
# Processing rid = Respeck_s1909083_Lying down on back_30-09-2022_02-00-26
# Processing rid = Respeck_s1909083_Lying down on stomach_30-09-2022_02-07-45
# Processing rid = Respeck_s1909083_Lying down right_30-09-2022_02-06-48
# Processing rid = Respeck_s1909083_Movement_30-09-2022_03-24-27
# Processing rid = Respeck_s1909083_Running_30-09-2022_02-18-24
# Processing rid = Respeck_s1909083_Sitting bent backward_30-09-2022_01-52-16
# Processing rid = Respeck_s1909083_Sitting bent forward_30-09-2022_01-39-13
# Processing rid = Respeck_s1909083_Sitting_30-09-2022_01-51-02
# Processing rid = Respeck_s1909083_Standing_30-09-2022_01-57-02
# Processing rid = Respeck_s1909083_Walking at normal speed_30-09-2022_02-13-45
# Processing rid = Respeck_s1910268_Climbing stairs_03-10-2022_18-12-57
# Processing rid = Respeck_s1910268_Descending stairs_03-10-2022_18-11-42
# Processing rid = Respeck_s1910268_Desk work_24-09-2022_16-57-34
# Processing rid = Respeck_s1910268_Lying down left_24-09-2022_16-30-49
# Processing rid = Respeck_s1910268_Lying down on back_24-09-2022_16-29-08
# Processing rid = Respeck_s1910268_Lying down on stomach_24-09-2022_16-33-56
# Processing rid = Respeck_s1910268_Lying down right_24-09-2022_16-32-24
# Processing rid = Respeck_s1910268_Movement_24-09-2022_16-59-51
# Processing rid = Respeck_s1910268_Running_24-09-2022_16-43-26
# Processing rid = Respeck_s1910268_Sitting bent backward_24-09-2022_17-04-34
# Processing rid = Respeck_s1910268_Sitting bent forward_24-09-2022_16-22-25
# Processing rid = Respeck_s1910268_Sitting_24-09-2022_16-21-35
# Processing rid = Respeck_s1910268_Standing_24-09-2022_16-25-25
# Processing rid = Respeck_s1910268_Walking at normal speed_24-09-2022_16-40-45
# Processing rid = Respeck_s1911027_Climbing stairs_04-10-2022_15-11-39
# Processing rid = Respeck_s1911027_Descending stairs_04-10-2022_15-14-05
# Processing rid = Respeck_s1911027_Desk work_04-10-2022_15-51-21
# Processing rid = Respeck_s1911027_Lying down left_04-10-2022_15-53-33
# Processing rid = Respeck_s1911027_Lying down on back_27-09-2022_11-29-45
# Processing rid = Respeck_s1911027_Lying down on stomach_27-09-2022_11-33-55
# Processing rid = Respeck_s1911027_Lying down right_27-09-2022_11-32-21
# Processing rid = Respeck_s1911027_Movement_27-09-2022_11-38-42
# Processing rid = Respeck_s1911027_Running_04-10-2022_15-26-46
# Processing rid = Respeck_s1911027_Sitting bent backward_27-09-2022_11-24-30
# Processing rid = Respeck_s1911027_Sitting bent forward_04-10-2022_15-52-16
# Processing rid = Respeck_s1911027_Sitting_04-10-2022_16-03-16
# Processing rid = Respeck_s1911027_Standing_04-10-2022_15-50-05
# Processing rid = Respeck_s1911027_Walking at normal speed_27-09-2022_11-35-30
# Processing rid = Respeck_s1911455_Climbing stairs_04-10-2022_15-18-24
# Processing rid = Respeck_s1911455_Descending stairs_04-10-2022_15-17-25
# Processing rid = Respeck_s1911455_Desk work_23-09-2022_17-17-39
# Processing rid = Respeck_s1911455_Lying down left_23-09-2022_17-22-47
# Processing rid = Respeck_s1911455_Lying down on back_23-09-2022_17-22-09
# Processing rid = Respeck_s1911455_Lying down on stomach_04-10-2022_15-13-28
# Processing rid = Respeck_s1911455_Lying down right_23-09-2022_17-21-29
# Processing rid = Respeck_s1911455_Movement_23-09-2022_17-24-15
# Processing rid = Respeck_s1911455_Running_23-09-2022_17-34-41
# Processing rid = Respeck_s1911455_Sitting bent backward_23-09-2022_17-18-20
# Processing rid = Respeck_s1911455_Sitting bent forward_23-09-2022_17-18-58
# Processing rid = Respeck_s1911455_Sitting_23-09-2022_17-16-52
# Processing rid = Respeck_s1911455_Standing_23-09-2022_17-19-41
# Processing rid = Respeck_s1911455_Walking at normal speed_04-10-2022_15-14-50
# Processing rid = Respeck_s1912558_Climbing stairs_30-09-2022_19-39-30
# Processing rid = Respeck_s1912558_Descending stairs_12-10-2022_23-23-43
# Processing rid = Respeck_s1912558_Desk work_13-10-2022_08-07-07
# Processing rid = Respeck_s1912558_Lying down left_13-10-2022_08-55-47
# Processing rid = Respeck_s1912558_Lying down on back_13-10-2022_09-02-17
# Processing rid = Respeck_s1912558_Lying down on stomach_13-10-2022_09-00-17
# Processing rid = Respeck_s1912558_Lying down right_13-10-2022_08-57-38
# Processing rid = Respeck_s1912558_Movement_28-09-2022_22-58-59
# Processing rid = Respeck_s1912558_Running_13-10-2022_00-01-35
# Processing rid = Respeck_s1912558_Sitting bent backward_28-09-2022_22-37-02
# Processing rid = Respeck_s1912558_Sitting bent forward_28-09-2022_22-36-15
# Processing rid = Respeck_s1912558_Sitting_13-10-2022_18-00-06
# Processing rid = Respeck_s1912558_Standing_28-09-2022_22-37-43
# Processing rid = Respeck_s1912558_Walking at normal speed_12-10-2022_23-59-25
# Processing rid = Respeck_s1912575_Climbing stairs_01-10-2022_02-20-46
# Processing rid = Respeck_s1912575_Descending stairs_01-10-2022_02-21-34
# Processing rid = Respeck_s1912575_Desk work_28-09-2022_22-07-05
# Processing rid = Respeck_s1912575_Lying down left_28-09-2022_22-04-22
# Processing rid = Respeck_s1912575_Lying down on back_28-09-2022_21-44-25
# Processing rid = Respeck_s1912575_Lying down on stomach_28-09-2022_22-05-58
# Processing rid = Respeck_s1912575_Lying down right_28-09-2022_22-05-10
# Processing rid = Respeck_s1912575_Movement_04-10-2022_23-20-53
# Processing rid = Respeck_s1912575_Running_01-10-2022_03-54-07
# Processing rid = Respeck_s1912575_Sitting bent backward_05-10-2022_09-44-38
# Processing rid = Respeck_s1912575_Sitting bent forward_05-10-2022_09-43-43
# Processing rid = Respeck_s1912575_Sitting_04-10-2022_23-02-40
# Processing rid = Respeck_s1912575_Standing_04-10-2022_23-12-47
# Processing rid = Respeck_s1912575_Walking at normal speed_01-10-2022_03-52-37
# Processing rid = Respeck_s1912614_Climbing stairs_02-10-2022_18-32-13
# Processing rid = Respeck_s1912614_Descending stairs_02-10-2022_18-47-13
# Processing rid = Respeck_s1912614_Desk work_01-10-2022_14-27-46
# Processing rid = Respeck_s1912614_Lying down left_01-10-2022_15-11-07
# Processing rid = Respeck_s1912614_Lying down on back_01-10-2022_14-41-13
# Processing rid = Respeck_s1912614_Lying down on stomach_01-10-2022_15-16-18
# Processing rid = Respeck_s1912614_Lying down right_03-10-2022_20-49-17
# Processing rid = Respeck_s1912614_Movement_03-10-2022_20-46-28
# Processing rid = Respeck_s1912614_Running_03-10-2022_21-16-46
# Processing rid = Respeck_s1912614_Sitting bent backward_01-10-2022_13-58-23
# Processing rid = Respeck_s1912614_Sitting bent forward_01-10-2022_14-28-38
# Processing rid = Respeck_s1912614_Sitting_01-10-2022_15-19-35
# Processing rid = Respeck_s1912614_Standing_03-10-2022_20-52-19
# Processing rid = Respeck_s1912614_Walking at normal speed_02-10-2022_19-19-18
# Processing rid = Respeck_s1915425_Climbing stairs_28-09-2022_14-02-24
# Processing rid = Respeck_s1915425_Descending stairs_28-09-2022_14-01-32
# Processing rid = Respeck_s1915425_Desk work_28-09-2022_18-52-16
# Processing rid = Respeck_s1915425_Lying down left_28-09-2022_12-21-54
# Processing rid = Respeck_s1915425_Lying down on back_28-09-2022_12-20-03
# Processing rid = Respeck_s1915425_Lying down on stomach_28-09-2022_12-24-28
# Processing rid = Respeck_s1915425_Lying down right_28-09-2022_18-53-31
# Processing rid = Respeck_s1915425_Movement_28-09-2022_12-32-18
# Processing rid = Respeck_s1915425_Running_28-09-2022_14-29-29
# Processing rid = Respeck_s1915425_Sitting bent backward_28-09-2022_12-29-11
# Processing rid = Respeck_s1915425_Sitting bent forward_28-09-2022_18-51-27
# Processing rid = Respeck_s1915425_Sitting_28-09-2022_18-48-53
# Processing rid = Respeck_s1915425_Standing_28-09-2022_18-49-53
# Processing rid = Respeck_s1915425_Walking at normal speed_28-09-2022_14-30-49
# Processing rid = Respeck_s1918258_Climbing stairs_29-09-2022_17-42-07
# Processing rid = Respeck_s1918258_Descending stairs_29-09-2022_17-42-55
# Processing rid = Respeck_s1918258_Desk work_05-10-2022_10-58-05
# Processing rid = Respeck_s1918258_Lying down left_28-09-2022_15-43-20
# Processing rid = Respeck_s1918258_Lying down on back_28-09-2022_15-42-21
# Processing rid = Respeck_s1918258_Lying down on stomach_28-09-2022_15-45-27
# Processing rid = Respeck_s1918258_Lying down right_05-10-2022_11-10-46
# Processing rid = Respeck_s1918258_Movement_28-09-2022_15-49-31
# Processing rid = Respeck_s1918258_Running_28-09-2022_16-04-54
# Processing rid = Respeck_s1918258_Sitting bent backward_29-09-2022_15-52-32
# Processing rid = Respeck_s1918258_Sitting bent forward_29-09-2022_15-51-43
# Processing rid = Respeck_s1918258_Sitting_29-09-2022_15-50-55
# Processing rid = Respeck_s1918258_Standing_28-09-2022_15-40-51
# Processing rid = Respeck_s1918258_Walking at normal speed_28-09-2022_16-03-29
# Processing rid = Respeck_s1918275_Climbing stairs_05-10-2022_17-00-41
# Processing rid = Respeck_s1918275_Descending stairs_05-10-2022_16-59-52
# Processing rid = Respeck_s1918275_Desk work_06-10-2022_09-01-20
# Processing rid = Respeck_s1918275_Lying down left_01-10-2022_13-47-27
# Processing rid = Respeck_s1918275_Lying down on back_01-10-2022_13-43-54
# Processing rid = Respeck_s1918275_Lying down on stomach_01-10-2022_13-50-24
# Processing rid = Respeck_s1918275_Lying down right_01-10-2022_13-48-16
# Processing rid = Respeck_s1918275_Movement_01-10-2022_14-11-39
# Processing rid = Respeck_s1918275_Running_01-10-2022_13-56-24
# Processing rid = Respeck_s1918275_Sitting bent backward_01-10-2022_13-35-58
# Processing rid = Respeck_s1918275_Sitting bent forward_01-10-2022_13-34-35
# Processing rid = Respeck_s1918275_Sitting_04-10-2022_14-16-41
# Processing rid = Respeck_s1918275_Standing_01-10-2022_13-40-11
# Processing rid = Respeck_s1918275_Walking at normal speed_01-10-2022_13-54-09
# Processing rid = Respeck_s1920337_Climbing stairs_23-09-2022_12-36-38
# Processing rid = Respeck_s1920337_Descending stairs_23-09-2022_12-37-17
# Processing rid = Respeck_s1920337_Desk work_23-09-2022_12-22-16
# Processing rid = Respeck_s1920337_Lying down left_23-09-2022_12-24-44
# Processing rid = Respeck_s1920337_Lying down on back_23-09-2022_12-29-29
# Processing rid = Respeck_s1920337_Lying down on stomach_23-09-2022_12-28-13
# Processing rid = Respeck_s1920337_Lying down right_23-09-2022_12-26-01
# Processing rid = Respeck_s1920337_Movement_23-09-2022_13-00-58
# Processing rid = Respeck_s1920337_Running_23-09-2022_12-45-08
# Processing rid = Respeck_s1920337_Sitting bent backward_23-09-2022_12-19-09
# Processing rid = Respeck_s1920337_Sitting bent forward_23-09-2022_12-18-28
# Processing rid = Respeck_s1920337_Sitting_23-09-2022_12-17-12
# Processing rid = Respeck_s1920337_Standing_23-09-2022_12-20-37
# Processing rid = Respeck_s1920337_Walking at normal speed_23-09-2022_12-43-33
# Processing rid = Respeck_s1921856_Climbing stairs_29-09-2022_16-53-01
# Processing rid = Respeck_s1921856_Descending stairs_29-09-2022_16-52-01
# Processing rid = Respeck_s1921856_Desk work_29-09-2022_15-39-01
# Processing rid = Respeck_s1921856_Lying down left_03-10-2022_19-08-16
# Processing rid = Respeck_s1921856_Lying down on back_29-09-2022_15-33-23
# Processing rid = Respeck_s1921856_Lying down on stomach_29-09-2022_15-35-38
# Processing rid = Respeck_s1921856_Lying down right_03-10-2022_19-09-11
# Processing rid = Respeck_s1921856_Movement_29-09-2022_15-37-13
# Processing rid = Respeck_s1921856_Running_29-09-2022_16-09-39
# Processing rid = Respeck_s1921856_Sitting bent backward_29-09-2022_15-31-44
# Processing rid = Respeck_s1921856_Sitting bent forward_29-09-2022_15-30-59
# Processing rid = Respeck_s1921856_Sitting_03-10-2022_18-57-36
# Processing rid = Respeck_s1921856_Standing_29-09-2022_15-32-32
# Processing rid = Respeck_s1921856_Walking at normal speed_29-09-2022_15-51-52
# Processing rid = Respeck_s1923449_Climbing stairs_28-09-2022_15-53-00
# Processing rid = Respeck_s1923449_Descending stairs_28-09-2022_15-53-52
# Processing rid = Respeck_s1923449_Desk work_28-09-2022_14-12-35
# Processing rid = Respeck_s1923449_Lying down left_28-09-2022_14-18-32
# Processing rid = Respeck_s1923449_Lying down on back_28-09-2022_14-16-36
# Processing rid = Respeck_s1923449_Lying down on stomach_28-09-2022_14-22-42
# Processing rid = Respeck_s1923449_Lying down right_28-09-2022_14-20-13
# Processing rid = Respeck_s1923449_Movement_28-09-2022_15-59-29
# Processing rid = Respeck_s1923449_Running_28-09-2022_15-41-21
# Processing rid = Respeck_s1923449_Sitting bent backward_28-09-2022_14-07-57
# Processing rid = Respeck_s1923449_Sitting bent forward_28-09-2022_14-05-44
# Processing rid = Respeck_s1923449_Sitting_28-09-2022_14-03-34
# Processing rid = Respeck_s1923449_Standing_28-09-2022_14-10-59
# Processing rid = Respeck_s1923449_Walking at normal speed_28-09-2022_15-39-53
# Processing rid = Respeck_s1923493_Climbing stairs_02-10-2022_15-16-09
# Processing rid = Respeck_s1923493_Descending stairs_02-10-2022_15-15-07
# Processing rid = Respeck_s1923493_Desk work_02-10-2022_16-00-59
# Processing rid = Respeck_s1923493_Lying down left_02-10-2022_16-07-03
# Processing rid = Respeck_s1923493_Lying down on back_02-10-2022_16-04-08
# Processing rid = Respeck_s1923493_Lying down on stomach_02-10-2022_16-12-59
# Processing rid = Respeck_s1923493_Lying down right_02-10-2022_16-09-11
# Processing rid = Respeck_s1923493_Movement_02-10-2022_13-15-35
# Processing rid = Respeck_s1923493_Running_02-10-2022_13-37-42
# Processing rid = Respeck_s1923493_Sitting bent backward_02-10-2022_15-57-00
# Processing rid = Respeck_s1923493_Sitting bent forward_02-10-2022_12-42-43
# Processing rid = Respeck_s1923493_Sitting_02-10-2022_12-39-58
# Processing rid = Respeck_s1923493_Standing_02-10-2022_12-52-25
# Processing rid = Respeck_s1923493_Walking at normal speed_02-10-2022_13-11-05
# Processing rid = Respeck_s1925182_Climbing stairs_13-10-2022_21-42-46
# Processing rid = Respeck_s1925182_Descending stairs_13-10-2022_21-47-32
# Processing rid = Respeck_s1925182_Desk work_14-10-2022_10-28-38
# Processing rid = Respeck_s1925182_Lying down left_13-10-2022_11-00-46
# Processing rid = Respeck_s1925182_Lying down on back_13-10-2022_10-58-28
# Processing rid = Respeck_s1925182_Lying down on stomach_14-10-2022_10-25-29
# Processing rid = Respeck_s1925182_Lying down right_13-10-2022_23-08-27
# Processing rid = Respeck_s1925182_Movement_13-10-2022_11-25-14
# Processing rid = Respeck_s1925182_Running_13-10-2022_21-50-49
# Processing rid = Respeck_s1925182_Sitting bent backward_13-10-2022_10-53-27
# Processing rid = Respeck_s1925182_Sitting bent forward_13-10-2022_23-10-03
# Processing rid = Respeck_s1925182_Sitting_13-10-2022_10-50-01
# Processing rid = Respeck_s1925182_Standing_13-10-2022_23-05-50
# Processing rid = Respeck_s1925182_Walking at normal speed_13-10-2022_21-48-34
# Processing rid = Respeck_s1925695_Climbing stairs_28-09-2022_15-41-22
# Processing rid = Respeck_s1925695_Descending stairs_28-09-2022_15-42-28
# Processing rid = Respeck_s1925695_Desk work_28-09-2022_16-00-36
# Processing rid = Respeck_s1925695_Lying down left_28-09-2022_15-37-26
# Processing rid = Respeck_s1925695_Lying down on back_28-09-2022_15-33-35
# Processing rid = Respeck_s1925695_Lying down on stomach_28-09-2022_15-36-36
# Processing rid = Respeck_s1925695_Lying down right_28-09-2022_15-34-20
# Processing rid = Respeck_s1925695_Movement_28-09-2022_15-58-02
# Processing rid = Respeck_s1925695_Running_28-09-2022_15-52-31
# Processing rid = Respeck_s1925695_Sitting bent backward_28-09-2022_15-29-53
# Processing rid = Respeck_s1925695_Sitting bent forward_28-09-2022_15-27-41
# Processing rid = Respeck_s1925695_Sitting_28-09-2022_15-26-51
# Processing rid = Respeck_s1925695_Standing_28-09-2022_15-30-57
# Processing rid = Respeck_s1925695_Walking at normal speed_28-09-2022_15-49-42
# Processing rid = Respeck_s1925709_Climbing stairs_02-10-2022_18-26-14
# Processing rid = Respeck_s1925709_Descending stairs_02-10-2022_18-26-57
# Processing rid = Respeck_s1925709_Desk work_02-10-2022_22-41-34
# Processing rid = Respeck_s1925709_Lying down left_01-10-2022_21-27-14
# Processing rid = Respeck_s1925709_Lying down on back_01-10-2022_21-26-02
# Processing rid = Respeck_s1925709_Lying down on stomach_02-10-2022_22-30-43
# Processing rid = Respeck_s1925709_Lying down right_01-10-2022_21-28-39
# Processing rid = Respeck_s1925709_Movement_01-10-2022_21-21-50
# Processing rid = Respeck_s1925709_Running_03-10-2022_22-01-57
# Processing rid = Respeck_s1925709_Sitting bent backward_01-10-2022_21-19-58
# Processing rid = Respeck_s1925709_Sitting bent forward_01-10-2022_21-18-15
# Processing rid = Respeck_s1925709_Sitting_02-10-2022_22-40-16
# Processing rid = Respeck_s1925709_Standing_03-10-2022_21-46-19
# Processing rid = Respeck_s1925709_Walking at normal speed_03-10-2022_21-58-52
# Processing rid = Respeck_s1925715_Climbing stairs_28-09-2022_13-57-42
# Processing rid = Respeck_s1925715_Descending stairs_28-09-2022_13-56-59
# Processing rid = Respeck_s1925715_Desk work_27-09-2022_11-54-35
# Processing rid = Respeck_s1925715_Lying down left_28-09-2022_12-13-09
# Processing rid = Respeck_s1925715_Lying down on back_28-09-2022_12-08-38
# Processing rid = Respeck_s1925715_Lying down on stomach_28-09-2022_17-00-45
# Processing rid = Respeck_s1925715_Lying down right_28-09-2022_12-14-33
# Processing rid = Respeck_s1925715_Movement_27-09-2022_11-55-57
# Processing rid = Respeck_s1925715_Running_28-09-2022_14-24-20
# Processing rid = Respeck_s1925715_Sitting bent backward_27-09-2022_11-51-30
# Processing rid = Respeck_s1925715_Sitting bent forward_28-09-2022_17-22-23
# Processing rid = Respeck_s1925715_Sitting_28-09-2022_17-24-21
# Processing rid = Respeck_s1925715_Standing_28-09-2022_16-57-28
# Processing rid = Respeck_s1925715_Walking at normal speed_28-09-2022_14-26-03
# Processing rid = Respeck_s1926989_Climbing stairs_03-10-2022_17-15-49
# Processing rid = Respeck_s1926989_Descending stairs_03-10-2022_17-10-22
# Processing rid = Respeck_s1926989_Desk work_03-10-2022_17-08-04
# Processing rid = Respeck_s1926989_Lying down left_03-10-2022_17-04-42
# Processing rid = Respeck_s1926989_Lying down on back_03-10-2022_17-04-02
# Processing rid = Respeck_s1926989_Lying down on stomach_03-10-2022_17-06-19
# Processing rid = Respeck_s1926989_Lying down right_03-10-2022_17-05-36
# Processing rid = Respeck_s1926989_Movement_03-10-2022_17-07-08
# Processing rid = Respeck_s1926989_Running_03-10-2022_17-13-11
# Processing rid = Respeck_s1926989_Sitting bent backward_03-10-2022_17-02-32
# Processing rid = Respeck_s1926989_Sitting bent forward_03-10-2022_17-01-54
# Processing rid = Respeck_s1926989_Sitting_03-10-2022_17-01-17
# Processing rid = Respeck_s1926989_Standing_03-10-2022_17-03-12
# Processing rid = Respeck_s1926989_Walking at normal speed_03-10-2022_17-11-41
# Processing rid = Respeck_s1927811_Climbing stairs_01-10-2022_20-41-41
# Processing rid = Respeck_s1927811_Descending stairs_01-10-2022_20-42-41
# Processing rid = Respeck_s1927811_Desk work_29-09-2022_12-15-27
# Processing rid = Respeck_s1927811_Lying down left_29-09-2022_12-09-34
# Processing rid = Respeck_s1927811_Lying down on back_29-09-2022_12-08-50
# Processing rid = Respeck_s1927811_Lying down on stomach_29-09-2022_12-10-59
# Processing rid = Respeck_s1927811_Lying down right_29-09-2022_12-10-17
# Processing rid = Respeck_s1927811_Movement_02-10-2022_20-46-08
# Processing rid = Respeck_s1927811_Running_29-09-2022_12-56-28
# Processing rid = Respeck_s1927811_Sitting bent backward_29-09-2022_12-07-18
# Processing rid = Respeck_s1927811_Sitting bent forward_29-09-2022_12-06-09
# Processing rid = Respeck_s1927811_Sitting_29-09-2022_12-05-07
# Processing rid = Respeck_s1927811_Standing_29-09-2022_12-08-01
# Processing rid = Respeck_s1927811_Walking at normal speed_29-09-2022_12-53-45
# Processing rid = Respeck_s1931698_Climbing stairs_26-09-2022_17-34-21
# Processing rid = Respeck_s1931698_Descending stairs_26-09-2022_17-35-13
# Processing rid = Respeck_s1931698_Desk work_03-10-2022_22-27-55
# Processing rid = Respeck_s1931698_Lying down left_02-10-2022_16-43-46
# Processing rid = Respeck_s1931698_Lying down on back_02-10-2022_16-40-38
# Processing rid = Respeck_s1931698_Lying down on stomach_02-10-2022_16-49-26
# Processing rid = Respeck_s1931698_Lying down right_03-10-2022_22-22-49
# Processing rid = Respeck_s1931698_Movement_03-10-2022_22-29-26
# Processing rid = Respeck_s1931698_Running_03-10-2022_22-35-55
# Processing rid = Respeck_s1931698_Sitting bent backward_03-10-2022_22-09-06
# Processing rid = Respeck_s1931698_Sitting bent forward_03-10-2022_22-07-40
# Processing rid = Respeck_s1931698_Sitting_03-10-2022_22-06-06
# Processing rid = Respeck_s1931698_Standing_03-10-2022_22-10-32
# Processing rid = Respeck_s1931698_Walking at normal speed_03-10-2022_22-33-49
# Processing rid = Respeck_s1931736_Climbing stairs_29-09-2022_16-58-39
# Processing rid = Respeck_s1931736_Descending stairs_29-09-2022_16-57-47
# Processing rid = Respeck_s1931736_Desk work_04-10-2022_22-26-14
# Processing rid = Respeck_s1931736_Lying down left_04-10-2022_21-17-37
# Processing rid = Respeck_s1931736_Lying down on back_04-10-2022_21-16-42
# Processing rid = Respeck_s1931736_Lying down on stomach_04-10-2022_21-19-35
# Processing rid = Respeck_s1931736_Lying down right_04-10-2022_21-18-29
# Processing rid = Respeck_s1931736_Movement_04-10-2022_21-20-18
# Processing rid = Respeck_s1931736_Running_29-09-2022_18-24-05
# Processing rid = Respeck_s1931736_Sitting bent backward_04-10-2022_21-24-50
# Processing rid = Respeck_s1931736_Sitting bent forward_04-10-2022_21-23-31
# Processing rid = Respeck_s1931736_Sitting_04-10-2022_21-22-46
# Processing rid = Respeck_s1931736_Standing_04-10-2022_21-15-50
# Processing rid = Respeck_s1931736_Walking at normal speed_29-09-2022_18-16-14
# Processing rid = Respeck_s1935680_Climbing stairs_14-10-2022_10-48-50
# Processing rid = Respeck_s1935680_Descending stairs_13-10-2022_21-30-32
# Processing rid = Respeck_s1935680_Desk work_13-10-2022_20-20-27
# Processing rid = Respeck_s1935680_Lying down left_14-10-2022_11-23-11
# Processing rid = Respeck_s1935680_Lying down on back_14-10-2022_11-18-51
# Processing rid = Respeck_s1935680_Lying down on stomach_14-10-2022_11-12-55
# Processing rid = Respeck_s1935680_Lying down right_14-10-2022_11-27-47
# Processing rid = Respeck_s1935680_Movement_13-10-2022_20-23-04
# Processing rid = Respeck_s1935680_Running_14-10-2022_10-37-59
# Processing rid = Respeck_s1935680_Sitting bent backward_14-10-2022_10-02-19
# Processing rid = Respeck_s1935680_Sitting bent forward_13-10-2022_20-06-41
# Processing rid = Respeck_s1935680_Sitting_13-10-2022_20-04-46
# Processing rid = Respeck_s1935680_Standing_14-10-2022_11-03-43
# Processing rid = Respeck_s1935680_Walking at normal speed_14-10-2022_10-35-59
# Processing rid = Respeck_s1941321_Climbing stairs_26-09-2022_17-36-38
# Processing rid = Respeck_s1941321_Descending stairs_26-09-2022_17-37-30
# Processing rid = Respeck_s1941321_Desk work_04-10-2022_10-58-10
# Processing rid = Respeck_s1941321_Lying down left_02-10-2022_17-34-13
# Processing rid = Respeck_s1941321_Lying down on back_02-10-2022_17-31-58
# Processing rid = Respeck_s1941321_Lying down on stomach_02-10-2022_17-38-58
# Processing rid = Respeck_s1941321_Lying down right_02-10-2022_17-36-14
# Processing rid = Respeck_s1941321_Movement_04-10-2022_10-59-19
# Processing rid = Respeck_s1941321_Running_04-10-2022_11-10-47
# Processing rid = Respeck_s1941321_Sitting bent backward_04-10-2022_10-54-23
# Processing rid = Respeck_s1941321_Sitting bent forward_04-10-2022_10-53-18
# Processing rid = Respeck_s1941321_Sitting_04-10-2022_10-52-21
# Processing rid = Respeck_s1941321_Standing_04-10-2022_10-56-06
# Processing rid = Respeck_s1941321_Walking at normal speed_04-10-2022_11-09-11
# Processing rid = Respeck_s1948094_Climbing stairs_23-09-2022_12-51-37
# Processing rid = Respeck_s1948094_Descending stairs_23-09-2022_12-53-24
# Processing rid = Respeck_s1948094_Desk work_23-09-2022_12-01-53
# Processing rid = Respeck_s1948094_Lying down left_23-09-2022_11-54-37
# Processing rid = Respeck_s1948094_Lying down on back_23-09-2022_11-59-08
# Processing rid = Respeck_s1948094_Lying down on stomach_23-09-2022_11-57-49
# Processing rid = Respeck_s1948094_Lying down right_23-09-2022_11-56-22
# Processing rid = Respeck_s1948094_Movement_23-09-2022_12-58-07
# Processing rid = Respeck_s1948094_Running_23-09-2022_12-54-29
# Processing rid = Respeck_s1948094_Sitting bent backward_23-09-2022_11-50-08
# Processing rid = Respeck_s1948094_Sitting bent forward_23-09-2022_11-48-20
# Processing rid = Respeck_s1948094_Sitting_23-09-2022_11-45-44
# Processing rid = Respeck_s1948094_Standing_23-09-2022_11-51-34
# Processing rid = Respeck_s1948094_Walking at normal speed_23-09-2022_12-49-50
# Processing rid = Respeck_s1951693_Climbing stairs_05-10-2022_16-29-06
# Processing rid = Respeck_s1951693_Descending stairs_05-10-2022_16-30-17
# ...
# Processing rid = Thingy_s1973235_Lying down right_23-09-2022_15-57-01
# Processing rid = Thingy_s1973235_Movement_23-09-2022_15-52-02
# Processing rid = Thingy_s1973235_Running_23-09-2022_15-59-18
# Processing rid = Thingy_s1973235_Sitting bent backward_23-09-2022_15-02-01
# Processing rid = Thingy_s1973235_Sitting bent forward_23-09-2022_15-01-18
# Processing rid = Thingy_s1973235_Sitting_23-09-2022_15-00-40
# Processing rid = Thingy_s1973235_Standing_23-09-2022_15-02-40
# Processing rid = Thingy_s1973235_Walking at normal speed_23-09-2022_15-06-37
# Processing rid = Thingy_s1974565_Climbing stairs_28-09-2022_14-52-06
# Processing rid = Thingy_s1974565_Descending stairs_28-09-2022_14-53-57
# Processing rid = Thingy_s1974565_Desk work_28-09-2022_14-37-33
# Processing rid = Thingy_s1974565_Lying down left_28-09-2022_14-28-00
# Processing rid = Thingy_s1974565_Lying down on back_28-09-2022_14-35-07
# Processing rid = Thingy_s1974565_Lying down on stomach_28-09-2022_14-33-03
# Processing rid = Thingy_s1974565_Lying down right_28-09-2022_14-30-27
# Processing rid = Thingy_s1974565_Movement_28-09-2022_14-40-05
# Processing rid = Thingy_s1974565_Running_28-09-2022_15-01-38
# Processing rid = Thingy_s1974565_Sitting bent backward_28-09-2022_14-23-15
# Processing rid = Thingy_s1974565_Sitting bent forward_28-09-2022_14-21-32
# Processing rid = Thingy_s1974565_Sitting_28-09-2022_14-19-16
# Processing rid = Thingy_s1974565_Standing_28-09-2022_14-25-09
# Processing rid = Thingy_s1974565_Walking at normal speed_28-09-2022_14-46-40
# Processing rid = Thingy_s1976098_Climbing stairs_28-09-2022_14-35-41
# Processing rid = Thingy_s1976098_Descending stairs_28-09-2022_14-43-56
# Processing rid = Thingy_s1976098_Desk work_04-10-2022_14-30-44
# Processing rid = Thingy_s1976098_Lying down left_04-10-2022_14-26-04
# Processing rid = Thingy_s1976098_Lying down on back_28-09-2022_14-07-30
# Processing rid = Thingy_s1976098_Lying down on stomach_28-09-2022_14-12-36
# Processing rid = Thingy_s1976098_Lying down right_28-09-2022_14-10-56
# Processing rid = Thingy_s1976098_Movement_28-09-2022_14-47-51
# Processing rid = Thingy_s1976098_Running_28-09-2022_14-29-02
# Processing rid = Thingy_s1976098_Sitting bent backward_05-10-2022_15-40-56
# Processing rid = Thingy_s1976098_Sitting bent forward_05-10-2022_15-40-14
# Processing rid = Thingy_s1976098_Sitting_05-10-2022_15-39-30
# Processing rid = Thingy_s1976098_Standing_28-09-2022_13-59-56
# Processing rid = Thingy_s1976098_Walking at normal speed_28-09-2022_15-13-28
# Processing rid = Thingy_s1977764_Climbing stairs_24-09-2022_15-47-30
# Processing rid = Thingy_s1977764_Descending stairs_24-09-2022_15-48-13
# Processing rid = Thingy_s1977764_Desk work_24-09-2022_15-51-39
# Processing rid = Thingy_s1977764_Lying down left_24-09-2022_15-42-18
# Processing rid = Thingy_s1977764_Lying down on back_24-09-2022_15-41-29
# Processing rid = Thingy_s1977764_Lying down on stomach_24-09-2022_15-44-00
# Processing rid = Thingy_s1977764_Lying down right_24-09-2022_15-43-08
# Processing rid = Thingy_s1977764_Movement_24-09-2022_15-50-34
# Processing rid = Thingy_s1977764_Running_24-09-2022_15-46-22
# Processing rid = Thingy_s1977764_Sitting bent backward_24-09-2022_15-38-52
# Processing rid = Thingy_s1977764_Sitting bent forward_24-09-2022_15-37-50
# Processing rid = Thingy_s1977764_Sitting_24-09-2022_15-36-43
# Processing rid = Thingy_s1977764_Standing_24-09-2022_15-39-49
# Processing rid = Thingy_s1977764_Walking at normal speed_24-09-2022_15-45-25
# Processing rid = Thingy_s1992413_Climbing stairs_29-09-2022_17-30-03
# Processing rid = Thingy_s1992413_Descending stairs_29-09-2022_17-32-58
# Processing rid = Thingy_s1992413_Desk work_28-09-2022_16-09-14
# Processing rid = Thingy_s1992413_Lying down left_28-09-2022_16-05-05
# Processing rid = Thingy_s1992413_Lying down on back_05-10-2022_01-39-31
# Processing rid = Thingy_s1992413_Lying down on stomach_05-10-2022_01-08-22
# Processing rid = Thingy_s1992413_Lying down right_05-10-2022_01-42-48
# Processing rid = Thingy_s1992413_Movement_28-09-2022_16-08-24
# Processing rid = Thingy_s1992413_Running_29-09-2022_18-51-57
# Processing rid = Thingy_s1992413_Sitting bent backward_05-10-2022_02-13-32
# Processing rid = Thingy_s1992413_Sitting bent forward_05-10-2022_02-12-51
# Processing rid = Thingy_s1992413_Sitting_05-10-2022_01-05-34
# Processing rid = Thingy_s1992413_Standing_28-09-2022_16-04-07
# Processing rid = Thingy_s1992413_Walking at normal speed_28-09-2022_18-49-14
# Processing rid = Thingy_s1996403_Climbing stairs_28-09-2022_15-19-26
# Processing rid = Thingy_s1996403_Descending stairs_28-09-2022_15-20-35
# Processing rid = Thingy_s1996403_Desk work_04-10-2022_11-20-02
# Processing rid = Thingy_s1996403_Lying down left_02-10-2022_18-04-42
# Processing rid = Thingy_s1996403_Lying down on back_28-09-2022_12-54-01
# Processing rid = Thingy_s1996403_Lying down on stomach_28-09-2022_15-01-55
# Processing rid = Thingy_s1996403_Lying down right_28-09-2022_15-01-04
# Processing rid = Thingy_s1996403_Movement_28-09-2022_15-05-40
# Processing rid = Thingy_s1996403_Running_28-09-2022_15-16-23
# Processing rid = Thingy_s1996403_Sitting bent backward_04-10-2022_11-18-36
# Processing rid = Thingy_s1996403_Sitting bent forward_28-09-2022_12-49-15
# Processing rid = Thingy_s1996403_Sitting_28-09-2022_12-48-27
# Processing rid = Thingy_s1996403_Standing_02-10-2022_18-01-55
# Processing rid = Thingy_s1996403_Walking at normal speed_28-09-2022_15-15-29
# Processing rid = Thingy_s1998909_Climbing stairs_04-10-2022_15-40-02
# Processing rid = Thingy_s1998909_Descending stairs_04-10-2022_15-42-51
# Processing rid = Thingy_s1998909_Desk work_05-10-2022_13-04-58
# Processing rid = Thingy_s1998909_Lying down left_03-10-2022_16-18-47
# Processing rid = Thingy_s1998909_Lying down on back_03-10-2022_16-15-05
# Processing rid = Thingy_s1998909_Lying down on stomach_05-10-2022_13-07-05
# Processing rid = Thingy_s1998909_Lying down right_03-10-2022_16-20-25
# Processing rid = Thingy_s1998909_Movement_03-10-2022_16-43-21
# Processing rid = Thingy_s1998909_Running_03-10-2022_16-35-31
# Processing rid = Thingy_s1998909_Sitting bent backward_03-10-2022_16-07-33
# Processing rid = Thingy_s1998909_Sitting bent forward_03-10-2022_16-05-01
# Processing rid = Thingy_s1998909_Sitting_03-10-2022_16-03-03
# Processing rid = Thingy_s1998909_Standing_03-10-2022_16-11-19
# Processing rid = Thingy_s1998909_Walking at normal speed_03-10-2022_16-32-54
# Processing rid = Thingy_s2255740_Climbing stairs_01-10-2022_18-57-43
# Processing rid = Thingy_s2255740_Descending stairs_01-10-2022_18-58-24
# Processing rid = Thingy_s2255740_Desk work_01-10-2022_20-30-11
# Processing rid = Thingy_s2255740_Lying down left_01-10-2022_21-01-19
# Processing rid = Thingy_s2255740_Lying down on back_01-10-2022_21-00-03
# Processing rid = Thingy_s2255740_Lying down on stomach_01-10-2022_21-14-37
# Processing rid = Thingy_s2255740_Lying down right_01-10-2022_21-11-58
# Processing rid = Thingy_s2255740_Movement_01-10-2022_21-22-08
# Processing rid = Thingy_s2255740_Running_01-10-2022_19-40-09
# Processing rid = Thingy_s2255740_Sitting bent backward_01-10-2022_20-23-54
# Processing rid = Thingy_s2255740_Sitting bent forward_01-10-2022_20-19-44
# Processing rid = Thingy_s2255740_Sitting_01-10-2022_20-15-37
# Processing rid = Thingy_s2255740_Standing_01-10-2022_19-51-40
# Processing rid = Thingy_s2255740_Walking at normal speed_01-10-2022_18-48-31
# Processing rid = Thingy_s2269664_Climbing stairs_03-10-2022_17-53-44
# Processing rid = Thingy_s2269664_Descending stairs_03-10-2022_17-51-55
# Processing rid = Thingy_s2269664_Desk work_24-09-2022_15-57-00
# Processing rid = Thingy_s2269664_Lying down left_24-09-2022_15-17-58
# Processing rid = Thingy_s2269664_Lying down on back_24-09-2022_15-25-31
# Processing rid = Thingy_s2269664_Lying down on stomach_24-09-2022_15-27-32
# Processing rid = Thingy_s2269664_Lying down right_24-09-2022_15-20-06
# Processing rid = Thingy_s2269664_Movement_24-09-2022_16-00-27
# Processing rid = Thingy_s2269664_Running_24-09-2022_15-34-50
# Processing rid = Thingy_s2269664_Sitting bent backward_03-10-2022_20-44-53
# Processing rid = Thingy_s2269664_Sitting bent forward_24-09-2022_15-05-57
# Processing rid = Thingy_s2269664_Sitting_24-09-2022_15-03-16
# Processing rid = Thingy_s2269664_Standing_03-10-2022_20-46-46
# Processing rid = Thingy_s2269664_Walking at normal speed_24-09-2022_15-32-33
# Processing rid = Thingy_s2298733_Climbing stairs_30-09-2022_17-34-34
# Processing rid = Thingy_s2298733_Descending stairs_30-09-2022_17-35-11
# Processing rid = Thingy_s2298733_Desk work_30-09-2022_17-33-12
# Processing rid = Thingy_s2298733_Lying down left_30-09-2022_17-27-49
# Processing rid = Thingy_s2298733_Lying down on back_30-09-2022_17-27-07
# Processing rid = Thingy_s2298733_Lying down on stomach_30-09-2022_17-29-10
# Processing rid = Thingy_s2298733_Lying down right_30-09-2022_17-28-29
# Processing rid = Thingy_s2298733_Movement_30-09-2022_17-32-30
# Processing rid = Thingy_s2298733_Running_30-09-2022_17-31-00
# Processing rid = Thingy_s2298733_Sitting bent backward_30-09-2022_17-25-23
# Processing rid = Thingy_s2298733_Sitting bent forward_30-09-2022_17-24-44
# Processing rid = Thingy_s2298733_Sitting_30-09-2022_17-24-05
# Processing rid = Thingy_s2298733_Standing_30-09-2022_17-26-02
# Processing rid = Thingy_s2298733_Walking at normal speed_30-09-2022_17-30-15
# Processing rid = Thingy_s2299270_Climbing stairs_03-10-2022_19-38-36
# Processing rid = Thingy_s2299270_Descending stairs_03-10-2022_19-40-08
# Processing rid = Thingy_s2299270_Desk work_03-10-2022_17-29-12
# Processing rid = Thingy_s2299270_Lying down left_03-10-2022_16-01-10
# Processing rid = Thingy_s2299270_Lying down on back_03-10-2022_15-58-59
# Processing rid = Thingy_s2299270_Lying down on stomach_03-10-2022_16-04-53
# Processing rid = Thingy_s2299270_Lying down right_03-10-2022_16-03-02
# Processing rid = Thingy_s2299270_Movement_03-10-2022_17-25-44
# Processing rid = Thingy_s2299270_Running_03-10-2022_16-55-33
# Processing rid = Thingy_s2299270_Sitting bent backward_03-10-2022_15-57-05
# Processing rid = Thingy_s2299270_Sitting bent forward_03-10-2022_15-55-22
# Processing rid = Thingy_s2299270_Sitting_03-10-2022_12-09-59
# Processing rid = Thingy_s2299270_Standing_03-10-2022_10-56-30
# Processing rid = Thingy_s2299270_Walking at normal speed_03-10-2022_16-53-56
# Processing rid = Thingy_s2303353_Climbing stairs_22-09-2022_14-33-26
# Processing rid = Thingy_s2303353_Descending stairs_22-09-2022_14-34-40
# Processing rid = Thingy_s2303353_Desk work_22-09-2022_14-29-58
# Processing rid = Thingy_s2303353_Lying down left_22-09-2022_14-25-27
# Processing rid = Thingy_s2303353_Lying down on back_22-09-2022_14-23-50
# Processing rid = Thingy_s2303353_Lying down on stomach_22-09-2022_14-28-18
# Processing rid = Thingy_s2303353_Lying down right_22-09-2022_14-26-48
# Processing rid = Thingy_s2303353_Movement_22-09-2022_14-31-26
# Processing rid = Thingy_s2303353_Running_22-09-2022_14-47-59
# Processing rid = Thingy_s2303353_Sitting bent backward_22-09-2022_14-20-58
# Processing rid = Thingy_s2303353_Sitting bent forward_22-09-2022_14-19-43
# Processing rid = Thingy_s2303353_Sitting_22-09-2022_14-18-20
# Processing rid = Thingy_s2303353_Standing_22-09-2022_14-22-18
# Processing rid = Thingy_s2303353_Walking at normal speed_22-09-2022_14-45-46
# Processing rid = Thingy_s2303866_Climbing stairs_29-09-2022_13-13-32
# Processing rid = Thingy_s2303866_Descending stairs_29-09-2022_13-14-18
# Processing rid = Thingy_s2303866_Desk work_29-09-2022_13-06-20
# Processing rid = Thingy_s2303866_Lying down left_29-09-2022_12-57-44
# Processing rid = Thingy_s2303866_Lying down on back_29-09-2022_12-56-52
# Processing rid = Thingy_s2303866_Lying down on stomach_29-09-2022_13-00-44
# Processing rid = Thingy_s2303866_Lying down right_29-09-2022_12-59-58
# Processing rid = Thingy_s2303866_Movement_29-09-2022_13-20-19
# Processing rid = Thingy_s2303866_Running_29-09-2022_13-24-27
# Processing rid = Thingy_s2303866_Sitting bent backward_29-09-2022_12-50-27
# Processing rid = Thingy_s2303866_Sitting bent forward_29-09-2022_12-48-41
# Processing rid = Thingy_s2303866_Sitting_29-09-2022_12-46-56
# Processing rid = Thingy_s2303866_Standing_29-09-2022_12-54-56
# Processing rid = Thingy_s2303866_Walking at normal speed_29-09-2022_13-03-34
# Processing rid = Thingy_s2308859_Climbing stairs_05-10-2022_13-00-00
# Processing rid = Thingy_s2308859_Descending stairs_05-10-2022_12-55-02
# Processing rid = Thingy_s2308859_Desk work_05-10-2022_11-54-06
# Processing rid = Thingy_s2308859_Lying down left_05-10-2022_11-35-10
# Processing rid = Thingy_s2308859_Lying down on back_05-10-2022_11-28-33
# Processing rid = Thingy_s2308859_Lying down on stomach_05-10-2022_11-29-53
# Processing rid = Thingy_s2308859_Lying down right_05-10-2022_11-37-13
# Processing rid = Thingy_s2308859_Move_05-10-2022_11-56-00
# Processing rid = Thingy_s2308859_Running_05-10-2022_13-08-55
# Processing rid = Thingy_s2308859_Sitting bent backward_05-10-2022_11-24-25
# Processing rid = Thingy_s2308859_Sitting bent forward_05-10-2022_11-22-26
# Processing rid = Thingy_s2308859_Sitting_05-10-2022_11-20-16
# Processing rid = Thingy_s2308859_Standing_05-10-2022_11-26-26
# Processing rid = Thingy_s2308859_Walking at normal speed_05-10-2022_13-06-50
# Processing rid = Thingy_s2342658_Climbing stairs_04-10-2022_17-09-26
# Processing rid = Thingy_s2342658_Descending stairs_04-10-2022_17-10-09
# Processing rid = Thingy_s2342658_Desk work_04-10-2022_14-31-26
# Processing rid = Thingy_s2342658_Lying down left_04-10-2022_14-26-16
# Processing rid = Thingy_s2342658_Lying down on back_04-10-2022_14-25-08
# Processing rid = Thingy_s2342658_Lying down on stomach_04-10-2022_14-29-05
# Processing rid = Thingy_s2342658_Lying down right_04-10-2022_14-28-10
# Processing rid = Thingy_s2342658_Movement_04-10-2022_14-33-58
# Processing rid = Thingy_s2342658_Running_04-10-2022_14-55-06
# Processing rid = Thingy_s2342658_Sitting bent backward_04-10-2022_14-21-50
# Processing rid = Thingy_s2342658_Sitting bent forward_04-10-2022_14-18-28
# Processing rid = Thingy_s2342658_Sitting_04-10-2022_14-17-29
# Processing rid = Thingy_s2342658_Standing_04-10-2022_14-22-37
# Processing rid = Thingy_s2342658_Walking at normal speed_04-10-2022_14-53-43
# Processing rid = files\Respeck_s1834237_Desk work_30-09-2022_17-49-52
# Processing rid = files\Respeck_s1834237_Lying down left_30-09-2022_17-14-37
# Processing rid = files\Respeck_s1834237_Lying down on back_30-09-2022_17-09-25
# Processing rid = files\Respeck_s1834237_Lying down on stomach_30-09-2022_17-17-45
# Processing rid = files\Respeck_s1834237_Lying down right_30-09-2022_17-12-08
# Processing rid = files\Respeck_s1834237_Movement_30-09-2022_17-59-29
# Processing rid = files\Respeck_s1834237_Running_30-09-2022_17-44-40
# Processing rid = files\Respeck_s1834237_Sitting bent backward_30-09-2022_16-59-23
# Processing rid = files\Respeck_s1834237_Sitting bent forward_30-09-2022_16-58-23
# Processing rid = files\Respeck_s1834237_Sitting_30-09-2022_16-55-17
# Processing rid = files\Respeck_s1834237_Standing_30-09-2022_17-02-21
# Processing rid = files\Respeck_s1834237_Walking at normal speed_30-09-2022_17-39-29
# Processing rid = files\Thingy_s1834237_Climbing stairs_30-09-2022_17-54-34
# Processing rid = files\Thingy_s1834237_Descending stairs_30-09-2022_17-55-23
# Processing rid = files\Thingy_s1834237_Desk work_30-09-2022_17-51-25
# Processing rid = files\Thingy_s1834237_Lying down left_30-09-2022_17-15-26
# Processing rid = files\Thingy_s1834237_Lying down on back_30-09-2022_17-10-14
# Processing rid = files\Thingy_s1834237_Lying down on stomach_30-09-2022_17-16-56
# Processing rid = files\Thingy_s1834237_Lying down right_30-09-2022_17-11-19
# Processing rid = files\Thingy_s1834237_Movement_30-09-2022_18-00-09
# Processing rid = files\Thingy_s1834237_Running_30-09-2022_17-43-00
# Processing rid = files\Thingy_s1834237_Sitting bent backward_30-09-2022_17-00-14
# Processing rid = files\Thingy_s1834237_Sitting bent forward_30-09-2022_16-57-34
# Processing rid = files\Thingy_s1834237_Sitting_30-09-2022_16-56-22
# Processing rid = files\Thingy_s1834237_Standing_30-09-2022_17-01-21
# Processing rid = files\Thingy_s1834237_Walking at normal speed_30-09-2022_17-40-21

# %%
final_sliding_windows = pd.concat(all_overlapping_windows).reset_index(drop=True)

# %%
# now extract all features
feature_list = []

for col in columns_of_interest:
    new_features = tsfresh.extract_features(timeseries_container=final_sliding_windows, column_id='window_id',
                        column_value=col, default_fc_parameters=tsfresh.feature_extraction.MinimalFCParameters())
    
    feature_list.append(new_features)
    
feature_list = pd.concat(feature_list, axis=1)

feature_list
# Out:
# Feature Extraction: 100%|██████████| 40/40 [00:14<00:00,  2.73it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:16<00:00,  2.50it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:14<00:00,  2.70it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:15<00:00,  2.65it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:14<00:00,  2.82it/s]
# Feature Extraction: 100%|██████████| 40/40 [00:14<00:00,  2.79it/s]
#        accel_x__sum_values  accel_x__median  accel_x__mean  accel_x__length  \
# 0               -10.845703        -0.216675      -0.216914             50.0
# 1               -10.818604        -0.216187      -0.216372             50.0
# 2               -10.489502        -0.210693      -0.209790             50.0
# 3               -10.311279        -0.206665      -0.206226             50.0
# 4               -10.548584        -0.211182      -0.210972             50.0
# ...                    ...              ...            ...              ...
# 62647           -46.262695        -0.854004      -0.925254             50.0
# 62648           -45.315430        -0.844727      -0.906309             50.0
# 62649           -45.810547        -0.851074      -0.916211             50.0
# 62650           -47.112305        -0.860352      -0.942246             50.0
# 62651           -45.827148        -0.831543      -0.916543             50.0
#
#        accel_x__standard_deviation  accel_x__variance  \
# 0                         0.010934           0.000120
# 1                         0.008302           0.000069
# 2                         0.010663           0.000114
# 3                         0.010581           0.000112
# 4                         0.007953           0.000063
# ...                            ...                ...
# 62647                     0.412701           0.170322
# 62648                     0.424313           0.180042
# 62649                     0.407624           0.166157
# 62650                     0.393781           0.155063
# 62651                     0.392667           0.154187
#
#        accel_x__root_mean_square  accel_x__maximum  accel_x__minimum  \
# 0                       0.217189         -0.190186         -0.248779
# 1                       0.216531         -0.190186         -0.239746
# 2                       0.210061         -0.185547         -0.238525
# 3                       0.206497         -0.185547         -0.238525
# 4                       0.211122         -0.190186         -0.225586
# ...                          ...               ...               ...
# 62647                   1.013122         -0.155273         -2.000000
# 62648                   1.000718         -0.144531         -2.000000
# 62649                   1.002796         -0.144531         -2.000000
# 62650                   1.021220         -0.305664         -1.714844
# 62651                   0.997115         -0.365234         -2.000000
#
#        accel_y__sum_values  ...  gyro_y__minimum  gyro_z__sum_values  \
# 0               -48.698120  ...        -1.281250            0.515625
# 1               -48.696411  ...        -1.656250            4.562500
# 2               -48.782104  ...        -2.015625           17.546875
# 3               -48.825561  ...        -2.015625            3.859375
# 4               -48.705688  ...        -1.875000           -8.687500
# ...                    ...  ...              ...                 ...
# 62647           -20.803711  ...      -138.718750         -131.500000
# 62648           -20.762695  ...      -138.656250         -113.781250
# 62649           -19.991211  ...      -138.656250          -57.437500
# 62650           -20.725586  ...      -127.968750          -19.750000
# 62651           -20.885742  ...      -129.750000          -57.000000
#
#        gyro_z__median  gyro_z__mean  gyro_z__length  \
# 0           -0.078125      0.010313            50.0
# 1            0.132812      0.091250            50.0
# 2            0.359375      0.350938            50.0
# 3            0.078125      0.077188            50.0
# 4           -0.140625     -0.173750            50.0
# ...               ...           ...             ...
# 62647      -10.296875     -2.630000            50.0
# 62648       -3.062500     -2.275625            50.0
# 62649        7.031250     -1.148750            50.0
# 62650        4.812500     -0.395000            50.0
# 62651        7.312500     -1.140000            50.0
#
#        gyro_z__standard_deviation  gyro_z__variance  gyro_z__root_mean_square  \
# 0                        0.522030          0.272516                  0.522132
# 1                        0.360790          0.130170                  0.372151
# 2                        0.449296          0.201867                  0.570109
# 3                        0.621501          0.386264                  0.626276
# 4                        0.367990          0.135416                  0.406947
# ...                           ...               ...                       ...
# 62647                   41.732476       1741.599584                 41.815266
# 62648                   42.033507       1766.815730                 42.095061
# 62649                   40.105461       1608.447991                 40.121909
# 62650                   40.741633       1659.880655                 40.743548
# 62651                   43.747910       1913.879658                 43.762761
#
#        gyro_z__maximum  gyro_z__minimum
# 0             1.359375        -1.281250
# 1             1.046875        -0.687500
# 2             1.390625        -0.937500
# 3             1.390625        -1.234375
# 4             0.625000        -1.234375
# ...                ...              ...
# 62647        57.531250      -106.812500
# 62648        58.875000      -106.812500
# 62649        58.875000      -103.343750
# 62650        61.281250       -82.593750
# 62651        61.281250      -125.250000
#
# [62652 rows x 54 columns]

# %% [markdown]
# Now we also extract the classes from each window

# %%
final_sliding_windows.groupby("window_id")[['activity_type']].agg(np.min)
# Out:
#                      activity_type
# window_id
# 0                         Standing
# 1                         Standing
# 2                         Standing
# 3                         Standing
# 4                         Standing
# ...                            ...
# 62647      Walking at normal speed
# 62648      Walking at normal speed
# 62649      Walking at normal speed
# 62650      Walking at normal speed
# 62651      Walking at normal speed
#
# [62652 rows x 1 columns]

# %% [markdown]
# We need to assign a number to each categorical class for the Random Forest Classifer. It is mainly up to you how you categorise your classes. In this example, we will use the labels:
# - 0 for Desk work
# - 1 for Walking at normal speed
#
# Bear in mind that your classification task will be multi-class, not binary.

# %%
class_labels = {
    'Desk work': 0,
    'Walking at normal speed': 1,
    'Standing': 2 ,
    'Sitting bent forward': 3,
    'Sitting': 4,
    'Sitting bent backward': 5,
    'Lying down right': 6,
    'Lying down left':7 ,
    'Lying down on back':8 ,
    'Lying down on stomach': 9, 
    'Movement': 10, 
    'Running': 11, 
    'Climbing stairs':12,
    'Descending stairs': 13
}

# %%
window_id_class_labels = final_sliding_windows.groupby("window_id")[['activity_type']].agg(np.min).replace(class_labels)
window_id_class_labels
# Out:
#            activity_type
# window_id
# 0                      2
# 1                      2
# 2                      2
# 3                      2
# 4                      2
# ...                  ...
# 62647                  1
# 62648                  1
# 62649                  1
# 62650                  1
# 62651                  1
#
# [62652 rows x 1 columns]

# %% [markdown]
# ### Quickly training a Random Forest Classifier

# %% [markdown]
# We now have all the tools to start training a Random Forest Classifier. We will use the feature_list as inputs and window_id_class_labels as outputs. We will do a basic 80/20 split of the data for demonstration purposes.
#
# In your project you should split the data into training and tests sets by excluding entire subjects from the training set. This is discussed later on in this notebook.

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_list, window_id_class_labels,
                                                    test_size=0.2, train_size=0.8)

# %%
print(f"Training set: X_train = {X_train.shape}, y_train = {y_train.shape}")
print(f"Test set: X_test = {X_test.shape}, y_test = {y_test.shape}")
# Out:
# Training set: X_train = (50121, 54), y_train = (50121, 1)
# Test set: X_test = (12531, 54), y_test = (12531, 1)

# %% [markdown]
# Now we can build and train the random forest classifier

# %%
rfc = RandomForestClassifier(n_estimators=10)

rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)
# Out:
# /Users/ascarshen/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(classification_report(y_pred=y_pred, y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       861
#            1       0.87      0.95      0.91       844
#            2       0.97      0.98      0.97       905
#            3       0.98      0.98      0.98       868
#            4       0.98      0.95      0.96       909
#            5       0.98      0.98      0.98       881
#            6       1.00      1.00      1.00       942
#            7       1.00      0.99      0.99       898
#            8       0.99      0.99      0.99       956
#            9       1.00      1.00      1.00       922
#           10       0.87      0.85      0.86       899
#           11       0.98      0.99      0.99       892
#           12       0.91      0.88      0.89       879
#           13       0.91      0.87      0.89       875
#
#     accuracy                           0.95     12531
#    macro avg       0.95      0.95      0.95     12531
# weighted avg       0.95      0.95      0.95     12531

# %% [markdown]
# This is a very easy problem so the classifier learns very quickly. Your actual problem of classifying multiple activities will be much harder.

# %% [markdown]
# ## Leave-one-subject-out cross-validation

# %% [markdown]
# One of the other reason our previous classifier functions so well is that each person performs activities in a very consistent manner. If a subject's data is both in the training set and the test set, it provides the model with an unfair advantage. Moreover, the results that your model will output will be falsely high. When you test your model on a completely new, unseen subject, your accuracy will drop considerably.
#
# This is why when training a HAR model you will want to do a special kind of cross-validation: Leave-One-Subject-Out (LOSOXV), where we leave one (or more) subject(s) in the testing set at each iteration.
#
# ![losoxv](../Images/LOOCV.png "losoxv")
#
# This ensures that the results we get from our classifier are consistent to what we would get in real life, if we were to test the model on a new user.

# %% [markdown]
# ## Training a simple CNN

# %% [markdown]
# There are some different preprocessing techniques you can apply when the resulting "datapoint" is an input to a convolutional neural network.
#
# You can use two types of convolutional layers:
# * 1D Conv Layers - which will work on 1D data, for example a single axis from one single sensor (accel, gyro or mag)
# * 2D Conv Layers - suitable if the input data is in the form of an image, for example
#
# We will be demonstrating how to build a simple 1D CNN using 6 channels: the 3 axes of the accelerometer and the 3 axes of the gyroscope.

# %% [markdown]
# ### Setting up the model

# %%
filters = 64
kernel_size = 3
n_features = 6
activation='relu'
n_classes = 14

# %%
model = Sequential()

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear', 
                 input_shape=(window_size, n_features)))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(n_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 48, 64)            1216
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 48, 64)            256
# _________________________________________________________________
# activation_6 (Activation)    (None, 48, 64)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 46, 64)            12352
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 46, 64)            256
# _________________________________________________________________
# activation_7 (Activation)    (None, 46, 64)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 44, 64)            12352
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 44, 64)            256
# _________________________________________________________________
# activation_8 (Activation)    (None, 44, 64)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2816)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               281700
# _________________________________________________________________
# dense_5 (Dense)              (None, 14)                1414
# =================================================================
# Total params: 309,802
# Trainable params: 309,418
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Re-generating the data in the appropriate format

# %% [markdown]
# We need to do a bit more work with our data to bring it into a format fit for training a CNN.
#
# A CNN will take multi-dimensional arrays as input. We have already specified that the input shape is (window_size, n_features), i.e. (50, 6).

# %% [markdown]
# Remember that we generated sliding windows before. Now we just need to take the raw values from each window and create a training set.

# %%
columns_of_interest
# Out:
# ['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

# %%
X = []
y = []

for window_id, group in final_sliding_windows.groupby('window_id'):
    print(f"window_id = {window_id}")
    
    shape = group[columns_of_interest].values.shape
    print(f"shape = {shape}")
    
    X.append(group[columns_of_interest].values)
    y.append(class_labels[group["activity_type"].values[0]])
# Out:
# window_id = 0
# shape = (50, 6)
# window_id = 1
# shape = (50, 6)
# window_id = 2
# shape = (50, 6)
# window_id = 3
# shape = (50, 6)
# window_id = 4
# shape = (50, 6)
# window_id = 5
# shape = (50, 6)
# window_id = 6
# shape = (50, 6)
# window_id = 7
# shape = (50, 6)
# window_id = 8
# shape = (50, 6)
# window_id = 9
# shape = (50, 6)
# window_id = 10
# shape = (50, 6)
# window_id = 11
# shape = (50, 6)
# window_id = 12
# shape = (50, 6)
# window_id = 13
# shape = (50, 6)
# window_id = 14
# shape = (50, 6)
# window_id = 15
# shape = (50, 6)
# window_id = 16
# shape = (50, 6)
# window_id = 17
# shape = (50, 6)
# window_id = 18
# shape = (50, 6)
# window_id = 19
# shape = (50, 6)
# window_id = 20
# shape = (50, 6)
# window_id = 21
# shape = (50, 6)
# window_id = 22
# shape = (50, 6)
# window_id = 23
# shape = (50, 6)
# window_id = 24
# shape = (50, 6)
# window_id = 25
# shape = (50, 6)
# window_id = 26
# shape = (50, 6)
# window_id = 27
# shape = (50, 6)
# window_id = 28
# shape = (50, 6)
# window_id = 29
# shape = (50, 6)
# window_id = 30
# shape = (50, 6)
# window_id = 31
# shape = (50, 6)
# window_id = 32
# shape = (50, 6)
# window_id = 33
# shape = (50, 6)
# window_id = 34
# shape = (50, 6)
# window_id = 35
# shape = (50, 6)
# window_id = 36
# shape = (50, 6)
# window_id = 37
# shape = (50, 6)
# window_id = 38
# shape = (50, 6)
# window_id = 39
# shape = (50, 6)
# window_id = 40
# shape = (50, 6)
# window_id = 41
# shape = (50, 6)
# window_id = 42
# shape = (50, 6)
# window_id = 43
# shape = (50, 6)
# window_id = 44
# shape = (50, 6)
# window_id = 45
# shape = (50, 6)
# window_id = 46
# shape = (50, 6)
# window_id = 47
# shape = (50, 6)
# window_id = 48
# shape = (50, 6)
# window_id = 49
# shape = (50, 6)
# window_id = 50
# shape = (50, 6)
# window_id = 51
# shape = (50, 6)
# window_id = 52
# shape = (50, 6)
# window_id = 53
# shape = (50, 6)
# window_id = 54
# shape = (50, 6)
# window_id = 55
# shape = (50, 6)
# window_id = 56
# shape = (50, 6)
# window_id = 57
# shape = (50, 6)
# window_id = 58
# shape = (50, 6)
# window_id = 59
# shape = (50, 6)
# window_id = 60
# shape = (50, 6)
# window_id = 61
# shape = (50, 6)
# window_id = 62
# shape = (50, 6)
# window_id = 63
# shape = (50, 6)
# window_id = 64
# shape = (50, 6)
# window_id = 65
# shape = (50, 6)
# window_id = 66
# shape = (50, 6)
# window_id = 67
# shape = (50, 6)
# window_id = 68
# shape = (50, 6)
# window_id = 69
# shape = (50, 6)
# window_id = 70
# shape = (50, 6)
# window_id = 71
# shape = (50, 6)
# window_id = 72
# shape = (50, 6)
# window_id = 73
# shape = (50, 6)
# window_id = 74
# shape = (50, 6)
# window_id = 75
# shape = (50, 6)
# window_id = 76
# shape = (50, 6)
# window_id = 77
# shape = (50, 6)
# window_id = 78
# shape = (50, 6)
# window_id = 79
# shape = (50, 6)
# window_id = 80
# shape = (50, 6)
# window_id = 81
# shape = (50, 6)
# window_id = 82
# shape = (50, 6)
# window_id = 83
# shape = (50, 6)
# window_id = 84
# shape = (50, 6)
# window_id = 85
# shape = (50, 6)
# window_id = 86
# shape = (50, 6)
# window_id = 87
# shape = (50, 6)
# window_id = 88
# shape = (50, 6)
# window_id = 89
# shape = (50, 6)
# window_id = 90
# shape = (50, 6)
# window_id = 91
# shape = (50, 6)
# window_id = 92
# shape = (50, 6)
# window_id = 93
# shape = (50, 6)
# window_id = 94
# shape = (50, 6)
# window_id = 95
# shape = (50, 6)
# window_id = 96
# shape = (50, 6)
# window_id = 97
# shape = (50, 6)
# window_id = 98
# shape = (50, 6)
# window_id = 99
# shape = (50, 6)
# window_id = 100
# shape = (50, 6)
# window_id = 101
# shape = (50, 6)
# window_id = 102
# shape = (50, 6)
# window_id = 103
# shape = (50, 6)
# window_id = 104
# shape = (50, 6)
# window_id = 105
# shape = (50, 6)
# window_id = 106
# shape = (50, 6)
# window_id = 107
# shape = (50, 6)
# window_id = 108
# shape = (50, 6)
# window_id = 109
# shape = (50, 6)
# window_id = 110
# shape = (50, 6)
# window_id = 111
# shape = (50, 6)
# window_id = 112
# shape = (50, 6)
# window_id = 113
# shape = (50, 6)
# window_id = 114
# shape = (50, 6)
# window_id = 115
# shape = (50, 6)
# window_id = 116
# shape = (50, 6)
# window_id = 117
# shape = (50, 6)
# window_id = 118
# shape = (50, 6)
# window_id = 119
# shape = (50, 6)
# window_id = 120
# shape = (50, 6)
# window_id = 121
# shape = (50, 6)
# window_id = 122
# shape = (50, 6)
# window_id = 123
# shape = (50, 6)
# window_id = 124
# shape = (50, 6)
# window_id = 125
# shape = (50, 6)
# window_id = 126
# shape = (50, 6)
# window_id = 127
# shape = (50, 6)
# window_id = 128
# shape = (50, 6)
# window_id = 129
# shape = (50, 6)
# window_id = 130
# shape = (50, 6)
# window_id = 131
# shape = (50, 6)
# window_id = 132
# shape = (50, 6)
# window_id = 133
# shape = (50, 6)
# window_id = 134
# shape = (50, 6)
# window_id = 135
# shape = (50, 6)
# window_id = 136
# shape = (50, 6)
# window_id = 137
# shape = (50, 6)
# window_id = 138
# shape = (50, 6)
# window_id = 139
# shape = (50, 6)
# window_id = 140
# shape = (50, 6)
# window_id = 141
# shape = (50, 6)
# window_id = 142
# shape = (50, 6)
# window_id = 143
# shape = (50, 6)
# window_id = 144
# shape = (50, 6)
# window_id = 145
# shape = (50, 6)
# window_id = 146
# shape = (50, 6)
# window_id = 147
# shape = (50, 6)
# window_id = 148
# shape = (50, 6)
# window_id = 149
# shape = (50, 6)
# window_id = 150
# shape = (50, 6)
# window_id = 151
# shape = (50, 6)
# window_id = 152
# shape = (50, 6)
# window_id = 153
# shape = (50, 6)
# window_id = 154
# shape = (50, 6)
# window_id = 155
# shape = (50, 6)
# window_id = 156
# shape = (50, 6)
# window_id = 157
# shape = (50, 6)
# window_id = 158
# shape = (50, 6)
# window_id = 159
# shape = (50, 6)
# window_id = 160
# shape = (50, 6)
# window_id = 161
# shape = (50, 6)
# window_id = 162
# shape = (50, 6)
# window_id = 163
# shape = (50, 6)
# window_id = 164
# shape = (50, 6)
# window_id = 165
# shape = (50, 6)
# window_id = 166
# shape = (50, 6)
# window_id = 167
# shape = (50, 6)
# window_id = 168
# shape = (50, 6)
# window_id = 169
# shape = (50, 6)
# window_id = 170
# shape = (50, 6)
# window_id = 171
# shape = (50, 6)
# window_id = 172
# shape = (50, 6)
# window_id = 173
# shape = (50, 6)
# window_id = 174
# shape = (50, 6)
# window_id = 175
# shape = (50, 6)
# window_id = 176
# shape = (50, 6)
# window_id = 177
# shape = (50, 6)
# window_id = 178
# shape = (50, 6)
# window_id = 179
# shape = (50, 6)
# window_id = 180
# shape = (50, 6)
# window_id = 181
# shape = (50, 6)
# window_id = 182
# shape = (50, 6)
# window_id = 183
# shape = (50, 6)
# window_id = 184
# shape = (50, 6)
# window_id = 185
# shape = (50, 6)
# window_id = 186
# shape = (50, 6)
# window_id = 187
# shape = (50, 6)
# window_id = 188
# shape = (50, 6)
# window_id = 189
# shape = (50, 6)
# window_id = 190
# shape = (50, 6)
# window_id = 191
# shape = (50, 6)
# window_id = 192
# shape = (50, 6)
# window_id = 193
# shape = (50, 6)
# window_id = 194
# shape = (50, 6)
# window_id = 195
# shape = (50, 6)
# window_id = 196
# shape = (50, 6)
# window_id = 197
# shape = (50, 6)
# window_id = 198
# shape = (50, 6)
# window_id = 199
# shape = (50, 6)
# window_id = 200
# shape = (50, 6)
# window_id = 201
# shape = (50, 6)
# window_id = 202
# shape = (50, 6)
# window_id = 203
# shape = (50, 6)
# window_id = 204
# shape = (50, 6)
# window_id = 205
# shape = (50, 6)
# window_id = 206
# shape = (50, 6)
# window_id = 207
# shape = (50, 6)
# window_id = 208
# shape = (50, 6)
# window_id = 209
# shape = (50, 6)
# window_id = 210
# shape = (50, 6)
# window_id = 211
# shape = (50, 6)
# window_id = 212
# shape = (50, 6)
# window_id = 213
# shape = (50, 6)
# window_id = 214
# shape = (50, 6)
# window_id = 215
# shape = (50, 6)
# window_id = 216
# shape = (50, 6)
# window_id = 217
# shape = (50, 6)
# window_id = 218
# shape = (50, 6)
# window_id = 219
# shape = (50, 6)
# window_id = 220
# shape = (50, 6)
# window_id = 221
# shape = (50, 6)
# window_id = 222
# shape = (50, 6)
# window_id = 223
# shape = (50, 6)
# window_id = 224
# shape = (50, 6)
# window_id = 225
# shape = (50, 6)
# window_id = 226
# shape = (50, 6)
# window_id = 227
# shape = (50, 6)
# window_id = 228
# shape = (50, 6)
# window_id = 229
# shape = (50, 6)
# window_id = 230
# shape = (50, 6)
# window_id = 231
# shape = (50, 6)
# window_id = 232
# shape = (50, 6)
# window_id = 233
# shape = (50, 6)
# window_id = 234
# shape = (50, 6)
# window_id = 235
# shape = (50, 6)
# window_id = 236
# shape = (50, 6)
# window_id = 237
# shape = (50, 6)
# window_id = 238
# shape = (50, 6)
# window_id = 239
# shape = (50, 6)
# window_id = 240
# shape = (50, 6)
# window_id = 241
# shape = (50, 6)
# window_id = 242
# shape = (50, 6)
# window_id = 243
# shape = (50, 6)
# window_id = 244
# shape = (50, 6)
# window_id = 245
# shape = (50, 6)
# window_id = 246
# shape = (50, 6)
# window_id = 247
# shape = (50, 6)
# window_id = 248
# shape = (50, 6)
# window_id = 249
# shape = (50, 6)
# window_id = 250
# shape = (50, 6)
# window_id = 251
# shape = (50, 6)
# window_id = 252
# shape = (50, 6)
# window_id = 253
# shape = (50, 6)
# window_id = 254
# shape = (50, 6)
# window_id = 255
# shape = (50, 6)
# window_id = 256
# shape = (50, 6)
# window_id = 257
# shape = (50, 6)
# window_id = 258
# shape = (50, 6)
# window_id = 259
# shape = (50, 6)
# window_id = 260
# shape = (50, 6)
# window_id = 261
# shape = (50, 6)
# window_id = 262
# shape = (50, 6)
# window_id = 263
# shape = (50, 6)
# window_id = 264
# shape = (50, 6)
# window_id = 265
# shape = (50, 6)
# window_id = 266
# shape = (50, 6)
# window_id = 267
# shape = (50, 6)
# window_id = 268
# shape = (50, 6)
# window_id = 269
# shape = (50, 6)
# window_id = 270
# shape = (50, 6)
# window_id = 271
# shape = (50, 6)
# window_id = 272
# shape = (50, 6)
# window_id = 273
# shape = (50, 6)
# window_id = 274
# shape = (50, 6)
# window_id = 275
# shape = (50, 6)
# window_id = 276
# shape = (50, 6)
# window_id = 277
# shape = (50, 6)
# window_id = 278
# shape = (50, 6)
# window_id = 279
# shape = (50, 6)
# window_id = 280
# shape = (50, 6)
# window_id = 281
# shape = (50, 6)
# window_id = 282
# shape = (50, 6)
# window_id = 283
# shape = (50, 6)
# window_id = 284
# shape = (50, 6)
# window_id = 285
# shape = (50, 6)
# window_id = 286
# shape = (50, 6)
# window_id = 287
# shape = (50, 6)
# window_id = 288
# shape = (50, 6)
# window_id = 289
# shape = (50, 6)
# window_id = 290
# shape = (50, 6)
# window_id = 291
# shape = (50, 6)
# window_id = 292
# shape = (50, 6)
# window_id = 293
# shape = (50, 6)
# window_id = 294
# shape = (50, 6)
# window_id = 295
# shape = (50, 6)
# window_id = 296
# shape = (50, 6)
# window_id = 297
# shape = (50, 6)
# window_id = 298
# shape = (50, 6)
# window_id = 299
# shape = (50, 6)
# window_id = 300
# shape = (50, 6)
# window_id = 301
# shape = (50, 6)
# window_id = 302
# shape = (50, 6)
# window_id = 303
# shape = (50, 6)
# window_id = 304
# shape = (50, 6)
# window_id = 305
# shape = (50, 6)
# window_id = 306
# shape = (50, 6)
# window_id = 307
# shape = (50, 6)
# window_id = 308
# shape = (50, 6)
# window_id = 309
# shape = (50, 6)
# window_id = 310
# shape = (50, 6)
# window_id = 311
# shape = (50, 6)
# window_id = 312
# shape = (50, 6)
# window_id = 313
# shape = (50, 6)
# window_id = 314
# shape = (50, 6)
# window_id = 315
# shape = (50, 6)
# window_id = 316
# shape = (50, 6)
# window_id = 317
# shape = (50, 6)
# window_id = 318
# shape = (50, 6)
# window_id = 319
# shape = (50, 6)
# window_id = 320
# shape = (50, 6)
# window_id = 321
# shape = (50, 6)
# window_id = 322
# shape = (50, 6)
# window_id = 323
# shape = (50, 6)
# window_id = 324
# shape = (50, 6)
# window_id = 325
# shape = (50, 6)
# window_id = 326
# shape = (50, 6)
# window_id = 327
# shape = (50, 6)
# window_id = 328
# shape = (50, 6)
# window_id = 329
# shape = (50, 6)
# window_id = 330
# shape = (50, 6)
# window_id = 331
# shape = (50, 6)
# window_id = 332
# shape = (50, 6)
# window_id = 333
# shape = (50, 6)
# window_id = 334
# shape = (50, 6)
# window_id = 335
# shape = (50, 6)
# window_id = 336
# shape = (50, 6)
# window_id = 337
# shape = (50, 6)
# window_id = 338
# shape = (50, 6)
# window_id = 339
# shape = (50, 6)
# window_id = 340
# shape = (50, 6)
# window_id = 341
# shape = (50, 6)
# window_id = 342
# shape = (50, 6)
# window_id = 343
# shape = (50, 6)
# window_id = 344
# shape = (50, 6)
# window_id = 345
# shape = (50, 6)
# window_id = 346
# shape = (50, 6)
# window_id = 347
# shape = (50, 6)
# window_id = 348
# shape = (50, 6)
# window_id = 349
# shape = (50, 6)
# window_id = 350
# shape = (50, 6)
# window_id = 351
# shape = (50, 6)
# window_id = 352
# shape = (50, 6)
# window_id = 353
# shape = (50, 6)
# window_id = 354
# shape = (50, 6)
# window_id = 355
# shape = (50, 6)
# window_id = 356
# shape = (50, 6)
# window_id = 357
# shape = (50, 6)
# window_id = 358
# shape = (50, 6)
# window_id = 359
# shape = (50, 6)
# window_id = 360
# shape = (50, 6)
# window_id = 361
# shape = (50, 6)
# window_id = 362
# shape = (50, 6)
# window_id = 363
# shape = (50, 6)
# window_id = 364
# shape = (50, 6)
# window_id = 365
# shape = (50, 6)
# window_id = 366
# shape = (50, 6)
# window_id = 367
# shape = (50, 6)
# window_id = 368
# shape = (50, 6)
# window_id = 369
# shape = (50, 6)
# window_id = 370
# shape = (50, 6)
# window_id = 371
# shape = (50, 6)
# window_id = 372
# shape = (50, 6)
# window_id = 373
# shape = (50, 6)
# window_id = 374
# shape = (50, 6)
# window_id = 375
# shape = (50, 6)
# window_id = 376
# shape = (50, 6)
# window_id = 377
# shape = (50, 6)
# window_id = 378
# shape = (50, 6)
# window_id = 379
# shape = (50, 6)
# window_id = 380
# shape = (50, 6)
# window_id = 381
# shape = (50, 6)
# window_id = 382
# shape = (50, 6)
# window_id = 383
# shape = (50, 6)
# window_id = 384
# shape = (50, 6)
# window_id = 385
# shape = (50, 6)
# window_id = 386
# shape = (50, 6)
# window_id = 387
# shape = (50, 6)
# window_id = 388
# shape = (50, 6)
# window_id = 389
# shape = (50, 6)
# window_id = 390
# shape = (50, 6)
# window_id = 391
# shape = (50, 6)
# window_id = 392
# shape = (50, 6)
# window_id = 393
# shape = (50, 6)
# window_id = 394
# shape = (50, 6)
# window_id = 395
# shape = (50, 6)
# window_id = 396
# shape = (50, 6)
# window_id = 397
# shape = (50, 6)
# window_id = 398
# shape = (50, 6)
# window_id = 399
# shape = (50, 6)
# window_id = 400
# shape = (50, 6)
# window_id = 401
# shape = (50, 6)
# window_id = 402
# shape = (50, 6)
# window_id = 403
# shape = (50, 6)
# window_id = 404
# shape = (50, 6)
# window_id = 405
# shape = (50, 6)
# window_id = 406
# shape = (50, 6)
# window_id = 407
# shape = (50, 6)
# window_id = 408
# shape = (50, 6)
# window_id = 409
# shape = (50, 6)
# window_id = 410
# shape = (50, 6)
# window_id = 411
# shape = (50, 6)
# window_id = 412
# shape = (50, 6)
# window_id = 413
# shape = (50, 6)
# window_id = 414
# shape = (50, 6)
# window_id = 415
# shape = (50, 6)
# window_id = 416
# shape = (50, 6)
# window_id = 417
# shape = (50, 6)
# window_id = 418
# shape = (50, 6)
# window_id = 419
# shape = (50, 6)
# window_id = 420
# shape = (50, 6)
# window_id = 421
# shape = (50, 6)
# window_id = 422
# shape = (50, 6)
# window_id = 423
# shape = (50, 6)
# window_id = 424
# shape = (50, 6)
# window_id = 425
# shape = (50, 6)
# window_id = 426
# shape = (50, 6)
# window_id = 427
# shape = (50, 6)
# window_id = 428
# shape = (50, 6)
# window_id = 429
# shape = (50, 6)
# window_id = 430
# shape = (50, 6)
# window_id = 431
# shape = (50, 6)
# window_id = 432
# shape = (50, 6)
# window_id = 433
# shape = (50, 6)
# window_id = 434
# shape = (50, 6)
# window_id = 435
# shape = (50, 6)
# window_id = 436
# shape = (50, 6)
# window_id = 437
# shape = (50, 6)
# window_id = 438
# shape = (50, 6)
# window_id = 439
# shape = (50, 6)
# window_id = 440
# shape = (50, 6)
# window_id = 441
# shape = (50, 6)
# window_id = 442
# shape = (50, 6)
# window_id = 443
# shape = (50, 6)
# window_id = 444
# shape = (50, 6)
# window_id = 445
# shape = (50, 6)
# window_id = 446
# shape = (50, 6)
# window_id = 447
# shape = (50, 6)
# window_id = 448
# shape = (50, 6)
# window_id = 449
# shape = (50, 6)
# window_id = 450
# shape = (50, 6)
# window_id = 451
# shape = (50, 6)
# window_id = 452
# shape = (50, 6)
# window_id = 453
# shape = (50, 6)
# window_id = 454
# shape = (50, 6)
# window_id = 455
# shape = (50, 6)
# window_id = 456
# shape = (50, 6)
# window_id = 457
# shape = (50, 6)
# window_id = 458
# shape = (50, 6)
# window_id = 459
# shape = (50, 6)
# window_id = 460
# shape = (50, 6)
# window_id = 461
# shape = (50, 6)
# window_id = 462
# shape = (50, 6)
# window_id = 463
# shape = (50, 6)
# window_id = 464
# shape = (50, 6)
# window_id = 465
# shape = (50, 6)
# window_id = 466
# shape = (50, 6)
# window_id = 467
# shape = (50, 6)
# window_id = 468
# shape = (50, 6)
# window_id = 469
# shape = (50, 6)
# window_id = 470
# shape = (50, 6)
# window_id = 471
# shape = (50, 6)
# window_id = 472
# shape = (50, 6)
# window_id = 473
# shape = (50, 6)
# window_id = 474
# shape = (50, 6)
# window_id = 475
# shape = (50, 6)
# window_id = 476
# shape = (50, 6)
# window_id = 477
# shape = (50, 6)
# window_id = 478
# shape = (50, 6)
# window_id = 479
# shape = (50, 6)
# window_id = 480
# shape = (50, 6)
# window_id = 481
# shape = (50, 6)
# window_id = 482
# shape = (50, 6)
# window_id = 483
# shape = (50, 6)
# window_id = 484
# shape = (50, 6)
# window_id = 485
# shape = (50, 6)
# window_id = 486
# shape = (50, 6)
# window_id = 487
# shape = (50, 6)
# window_id = 488
# shape = (50, 6)
# window_id = 489
# shape = (50, 6)
# window_id = 490
# shape = (50, 6)
# window_id = 491
# shape = (50, 6)
# window_id = 492
# shape = (50, 6)
# window_id = 493
# shape = (50, 6)
# window_id = 494
# shape = (50, 6)
# window_id = 495
# shape = (50, 6)
# window_id = 496
# shape = (50, 6)
# window_id = 497
# shape = (50, 6)
# window_id = 498
# shape = (50, 6)
# window_id = 499
# shape = (50, 6)
# window_id = 500
# shape = (50, 6)
# window_id = 501
# shape = (50, 6)
# window_id = 502
# shape = (50, 6)
# window_id = 503
# shape = (50, 6)
# window_id = 504
# shape = (50, 6)
# window_id = 505
# shape = (50, 6)
# window_id = 506
# shape = (50, 6)
# window_id = 507
# shape = (50, 6)
# window_id = 508
# shape = (50, 6)
# window_id = 509
# shape = (50, 6)
# window_id = 510
# shape = (50, 6)
# window_id = 511
# shape = (50, 6)
# window_id = 512
# shape = (50, 6)
# window_id = 513
# shape = (50, 6)
# window_id = 514
# shape = (50, 6)
# window_id = 515
# shape = (50, 6)
# window_id = 516
# shape = (50, 6)
# window_id = 517
# shape = (50, 6)
# window_id = 518
# shape = (50, 6)
# window_id = 519
# shape = (50, 6)
# window_id = 520
# shape = (50, 6)
# window_id = 521
# shape = (50, 6)
# window_id = 522
# shape = (50, 6)
# window_id = 523
# shape = (50, 6)
# window_id = 524
# shape = (50, 6)
# window_id = 525
# shape = (50, 6)
# window_id = 526
# shape = (50, 6)
# window_id = 527
# shape = (50, 6)
# window_id = 528
# shape = (50, 6)
# window_id = 529
# shape = (50, 6)
# window_id = 530
# shape = (50, 6)
# window_id = 531
# shape = (50, 6)
# window_id = 532
# shape = (50, 6)
# window_id = 533
# shape = (50, 6)
# window_id = 534
# shape = (50, 6)
# window_id = 535
# shape = (50, 6)
# window_id = 536
# shape = (50, 6)
# window_id = 537
# shape = (50, 6)
# window_id = 538
# shape = (50, 6)
# window_id = 539
# shape = (50, 6)
# window_id = 540
# shape = (50, 6)
# window_id = 541
# shape = (50, 6)
# window_id = 542
# shape = (50, 6)
# window_id = 543
# shape = (50, 6)
# window_id = 544
# shape = (50, 6)
# window_id = 545
# shape = (50, 6)
# window_id = 546
# shape = (50, 6)
# window_id = 547
# shape = (50, 6)
# window_id = 548
# shape = (50, 6)
# window_id = 549
# shape = (50, 6)
# window_id = 550
# shape = (50, 6)
# window_id = 551
# shape = (50, 6)
# window_id = 552
# shape = (50, 6)
# window_id = 553
# shape = (50, 6)
# window_id = 554
# shape = (50, 6)
# window_id = 555
# shape = (50, 6)
# window_id = 556
# shape = (50, 6)
# window_id = 557
# shape = (50, 6)
# window_id = 558
# shape = (50, 6)
# window_id = 559
# shape = (50, 6)
# window_id = 560
# shape = (50, 6)
# window_id = 561
# shape = (50, 6)
# window_id = 562
# shape = (50, 6)
# window_id = 563
# shape = (50, 6)
# window_id = 564
# shape = (50, 6)
# window_id = 565
# shape = (50, 6)
# window_id = 566
# shape = (50, 6)
# window_id = 567
# shape = (50, 6)
# window_id = 568
# shape = (50, 6)
# window_id = 569
# shape = (50, 6)
# window_id = 570
# shape = (50, 6)
# window_id = 571
# shape = (50, 6)
# window_id = 572
# shape = (50, 6)
# window_id = 573
# shape = (50, 6)
# window_id = 574
# shape = (50, 6)
# window_id = 575
# shape = (50, 6)
# window_id = 576
# shape = (50, 6)
# window_id = 577
# shape = (50, 6)
# window_id = 578
# shape = (50, 6)
# window_id = 579
# shape = (50, 6)
# window_id = 580
# shape = (50, 6)
# window_id = 581
# shape = (50, 6)
# window_id = 582
# shape = (50, 6)
# window_id = 583
# shape = (50, 6)
# window_id = 584
# shape = (50, 6)
# window_id = 585
# shape = (50, 6)
# window_id = 586
# shape = (50, 6)
# window_id = 587
# shape = (50, 6)
# window_id = 588
# shape = (50, 6)
# window_id = 589
# shape = (50, 6)
# window_id = 590
# shape = (50, 6)
# window_id = 591
# shape = (50, 6)
# window_id = 592
# shape = (50, 6)
# window_id = 593
# shape = (50, 6)
# window_id = 594
# shape = (50, 6)
# window_id = 595
# shape = (50, 6)
# window_id = 596
# shape = (50, 6)
# window_id = 597
# shape = (50, 6)
# window_id = 598
# shape = (50, 6)
# window_id = 599
# shape = (50, 6)
# window_id = 600
# shape = (50, 6)
# window_id = 601
# shape = (50, 6)
# window_id = 602
# shape = (50, 6)
# window_id = 603
# shape = (50, 6)
# window_id = 604
# shape = (50, 6)
# window_id = 605
# shape = (50, 6)
# window_id = 606
# shape = (50, 6)
# window_id = 607
# shape = (50, 6)
# window_id = 608
# shape = (50, 6)
# window_id = 609
# shape = (50, 6)
# window_id = 610
# shape = (50, 6)
# window_id = 611
# shape = (50, 6)
# window_id = 612
# shape = (50, 6)
# window_id = 613
# shape = (50, 6)
# window_id = 614
# shape = (50, 6)
# window_id = 615
# shape = (50, 6)
# window_id = 616
# shape = (50, 6)
# window_id = 617
# shape = (50, 6)
# window_id = 618
# shape = (50, 6)
# window_id = 619
# shape = (50, 6)
# window_id = 620
# shape = (50, 6)
# window_id = 621
# shape = (50, 6)
# window_id = 622
# shape = (50, 6)
# window_id = 623
# shape = (50, 6)
# window_id = 624
# shape = (50, 6)
# window_id = 625
# shape = (50, 6)
# window_id = 626
# shape = (50, 6)
# window_id = 627
# shape = (50, 6)
# window_id = 628
# shape = (50, 6)
# window_id = 629
# shape = (50, 6)
# window_id = 630
# shape = (50, 6)
# window_id = 631
# shape = (50, 6)
# window_id = 632
# shape = (50, 6)
# window_id = 633
# shape = (50, 6)
# window_id = 634
# shape = (50, 6)
# window_id = 635
# shape = (50, 6)
# window_id = 636
# shape = (50, 6)
# window_id = 637
# shape = (50, 6)
# window_id = 638
# shape = (50, 6)
# window_id = 639
# shape = (50, 6)
# window_id = 640
# shape = (50, 6)
# window_id = 641
# shape = (50, 6)
# window_id = 642
# shape = (50, 6)
# window_id = 643
# shape = (50, 6)
# window_id = 644
# shape = (50, 6)
# window_id = 645
# shape = (50, 6)
# window_id = 646
# shape = (50, 6)
# window_id = 647
# shape = (50, 6)
# window_id = 648
# shape = (50, 6)
# window_id = 649
# shape = (50, 6)
# window_id = 650
# shape = (50, 6)
# window_id = 651
# shape = (50, 6)
# window_id = 652
# shape = (50, 6)
# window_id = 653
# shape = (50, 6)
# window_id = 654
# shape = (50, 6)
# window_id = 655
# shape = (50, 6)
# window_id = 656
# shape = (50, 6)
# window_id = 657
# shape = (50, 6)
# window_id = 658
# shape = (50, 6)
# window_id = 659
# shape = (50, 6)
# window_id = 660
# shape = (50, 6)
# window_id = 661
# shape = (50, 6)
# window_id = 662
# shape = (50, 6)
# window_id = 663
# shape = (50, 6)
# window_id = 664
# shape = (50, 6)
# window_id = 665
# shape = (50, 6)
# window_id = 666
# shape = (50, 6)
# window_id = 667
# shape = (50, 6)
# window_id = 668
# shape = (50, 6)
# window_id = 669
# shape = (50, 6)
# window_id = 670
# shape = (50, 6)
# window_id = 671
# shape = (50, 6)
# window_id = 672
# shape = (50, 6)
# window_id = 673
# shape = (50, 6)
# window_id = 674
# shape = (50, 6)
# window_id = 675
# shape = (50, 6)
# window_id = 676
# shape = (50, 6)
# window_id = 677
# shape = (50, 6)
# window_id = 678
# shape = (50, 6)
# window_id = 679
# shape = (50, 6)
# window_id = 680
# shape = (50, 6)
# window_id = 681
# shape = (50, 6)
# window_id = 682
# shape = (50, 6)
# window_id = 683
# shape = (50, 6)
# window_id = 684
# shape = (50, 6)
# window_id = 685
# shape = (50, 6)
# window_id = 686
# shape = (50, 6)
# window_id = 687
# shape = (50, 6)
# window_id = 688
# shape = (50, 6)
# window_id = 689
# shape = (50, 6)
# window_id = 690
# shape = (50, 6)
# window_id = 691
# shape = (50, 6)
# window_id = 692
# shape = (50, 6)
# window_id = 693
# shape = (50, 6)
# window_id = 694
# shape = (50, 6)
# window_id = 695
# shape = (50, 6)
# window_id = 696
# shape = (50, 6)
# window_id = 697
# shape = (50, 6)
# window_id = 698
# shape = (50, 6)
# window_id = 699
# shape = (50, 6)
# window_id = 700
# shape = (50, 6)
# window_id = 701
# shape = (50, 6)
# window_id = 702
# shape = (50, 6)
# window_id = 703
# shape = (50, 6)
# window_id = 704
# shape = (50, 6)
# window_id = 705
# shape = (50, 6)
# window_id = 706
# shape = (50, 6)
# window_id = 707
# shape = (50, 6)
# window_id = 708
# shape = (50, 6)
# window_id = 709
# shape = (50, 6)
# window_id = 710
# shape = (50, 6)
# window_id = 711
# shape = (50, 6)
# window_id = 712
# shape = (50, 6)
# window_id = 713
# shape = (50, 6)
# window_id = 714
# shape = (50, 6)
# window_id = 715
# shape = (50, 6)
# window_id = 716
# shape = (50, 6)
# window_id = 717
# shape = (50, 6)
# window_id = 718
# shape = (50, 6)
# window_id = 719
# shape = (50, 6)
# window_id = 720
# shape = (50, 6)
# window_id = 721
# shape = (50, 6)
# window_id = 722
# shape = (50, 6)
# window_id = 723
# shape = (50, 6)
# window_id = 724
# shape = (50, 6)
# window_id = 725
# shape = (50, 6)
# window_id = 726
# shape = (50, 6)
# window_id = 727
# shape = (50, 6)
# window_id = 728
# shape = (50, 6)
# window_id = 729
# shape = (50, 6)
# window_id = 730
# shape = (50, 6)
# window_id = 731
# shape = (50, 6)
# window_id = 732
# shape = (50, 6)
# window_id = 733
# shape = (50, 6)
# window_id = 734
# shape = (50, 6)
# window_id = 735
# shape = (50, 6)
# window_id = 736
# shape = (50, 6)
# window_id = 737
# shape = (50, 6)
# window_id = 738
# shape = (50, 6)
# window_id = 739
# shape = (50, 6)
# window_id = 740
# shape = (50, 6)
# window_id = 741
# shape = (50, 6)
# window_id = 742
# shape = (50, 6)
# window_id = 743
# shape = (50, 6)
# window_id = 744
# shape = (50, 6)
# window_id = 745
# shape = (50, 6)
# window_id = 746
# shape = (50, 6)
# window_id = 747
# shape = (50, 6)
# window_id = 748
# shape = (50, 6)
# window_id = 749
# shape = (50, 6)
# window_id = 750
# shape = (50, 6)
# window_id = 751
# shape = (50, 6)
# window_id = 752
# shape = (50, 6)
# window_id = 753
# shape = (50, 6)
# window_id = 754
# shape = (50, 6)
# window_id = 755
# shape = (50, 6)
# window_id = 756
# shape = (50, 6)
# window_id = 757
# shape = (50, 6)
# window_id = 758
# shape = (50, 6)
# window_id = 759
# shape = (50, 6)
# window_id = 760
# shape = (50, 6)
# window_id = 761
# shape = (50, 6)
# window_id = 762
# shape = (50, 6)
# window_id = 763
# shape = (50, 6)
# window_id = 764
# shape = (50, 6)
# window_id = 765
# shape = (50, 6)
# window_id = 766
# shape = (50, 6)
# window_id = 767
# shape = (50, 6)
# window_id = 768
# shape = (50, 6)
# window_id = 769
# shape = (50, 6)
# window_id = 770
# shape = (50, 6)
# window_id = 771
# shape = (50, 6)
# window_id = 772
# shape = (50, 6)
# window_id = 773
# shape = (50, 6)
# window_id = 774
# shape = (50, 6)
# window_id = 775
# shape = (50, 6)
# window_id = 776
# shape = (50, 6)
# window_id = 777
# shape = (50, 6)
# window_id = 778
# shape = (50, 6)
# window_id = 779
# shape = (50, 6)
# window_id = 780
# shape = (50, 6)
# window_id = 781
# shape = (50, 6)
# window_id = 782
# shape = (50, 6)
# window_id = 783
# shape = (50, 6)
# window_id = 784
# shape = (50, 6)
# window_id = 785
# shape = (50, 6)
# window_id = 786
# shape = (50, 6)
# window_id = 787
# shape = (50, 6)
# window_id = 788
# shape = (50, 6)
# window_id = 789
# shape = (50, 6)
# window_id = 790
# shape = (50, 6)
# window_id = 791
# shape = (50, 6)
# window_id = 792
# shape = (50, 6)
# window_id = 793
# shape = (50, 6)
# window_id = 794
# shape = (50, 6)
# window_id = 795
# shape = (50, 6)
# window_id = 796
# shape = (50, 6)
# window_id = 797
# shape = (50, 6)
# window_id = 798
# shape = (50, 6)
# window_id = 799
# shape = (50, 6)
# window_id = 800
# shape = (50, 6)
# window_id = 801
# shape = (50, 6)
# window_id = 802
# shape = (50, 6)
# window_id = 803
# shape = (50, 6)
# window_id = 804
# shape = (50, 6)
# window_id = 805
# shape = (50, 6)
# window_id = 806
# shape = (50, 6)
# window_id = 807
# shape = (50, 6)
# window_id = 808
# shape = (50, 6)
# window_id = 809
# shape = (50, 6)
# window_id = 810
# shape = (50, 6)
# window_id = 811
# shape = (50, 6)
# window_id = 812
# shape = (50, 6)
# window_id = 813
# shape = (50, 6)
# window_id = 814
# shape = (50, 6)
# window_id = 815
# shape = (50, 6)
# window_id = 816
# shape = (50, 6)
# window_id = 817
# shape = (50, 6)
# window_id = 818
# shape = (50, 6)
# window_id = 819
# shape = (50, 6)
# window_id = 820
# shape = (50, 6)
# window_id = 821
# shape = (50, 6)
# window_id = 822
# shape = (50, 6)
# window_id = 823
# shape = (50, 6)
# window_id = 824
# shape = (50, 6)
# window_id = 825
# shape = (50, 6)
# window_id = 826
# shape = (50, 6)
# window_id = 827
# shape = (50, 6)
# window_id = 828
# shape = (50, 6)
# window_id = 829
# shape = (50, 6)
# window_id = 830
# shape = (50, 6)
# window_id = 831
# shape = (50, 6)
# window_id = 832
# shape = (50, 6)
# window_id = 833
# shape = (50, 6)
# window_id = 834
# shape = (50, 6)
# window_id = 835
# shape = (50, 6)
# window_id = 836
# shape = (50, 6)
# window_id = 837
# shape = (50, 6)
# window_id = 838
# shape = (50, 6)
# window_id = 839
# shape = (50, 6)
# window_id = 840
# shape = (50, 6)
# window_id = 841
# shape = (50, 6)
# window_id = 842
# shape = (50, 6)
# window_id = 843
# shape = (50, 6)
# window_id = 844
# shape = (50, 6)
# window_id = 845
# shape = (50, 6)
# window_id = 846
# shape = (50, 6)
# window_id = 847
# shape = (50, 6)
# window_id = 848
# shape = (50, 6)
# window_id = 849
# shape = (50, 6)
# window_id = 850
# shape = (50, 6)
# window_id = 851
# shape = (50, 6)
# window_id = 852
# shape = (50, 6)
# window_id = 853
# shape = (50, 6)
# window_id = 854
# shape = (50, 6)
# window_id = 855
# shape = (50, 6)
# window_id = 856
# shape = (50, 6)
# window_id = 857
# shape = (50, 6)
# window_id = 858
# shape = (50, 6)
# window_id = 859
# shape = (50, 6)
# window_id = 860
# shape = (50, 6)
# window_id = 861
# shape = (50, 6)
# window_id = 862
# shape = (50, 6)
# window_id = 863
# shape = (50, 6)
# window_id = 864
# shape = (50, 6)
# window_id = 865
# shape = (50, 6)
# window_id = 866
# shape = (50, 6)
# window_id = 867
# shape = (50, 6)
# window_id = 868
# shape = (50, 6)
# window_id = 869
# shape = (50, 6)
# window_id = 870
# shape = (50, 6)
# window_id = 871
# shape = (50, 6)
# window_id = 872
# shape = (50, 6)
# window_id = 873
# shape = (50, 6)
# window_id = 874
# shape = (50, 6)
# window_id = 875
# shape = (50, 6)
# window_id = 876
# shape = (50, 6)
# window_id = 877
# shape = (50, 6)
# window_id = 878
# shape = (50, 6)
# window_id = 879
# shape = (50, 6)
# window_id = 880
# shape = (50, 6)
# window_id = 881
# shape = (50, 6)
# window_id = 882
# shape = (50, 6)
# window_id = 883
# shape = (50, 6)
# window_id = 884
# shape = (50, 6)
# window_id = 885
# shape = (50, 6)
# window_id = 886
# shape = (50, 6)
# window_id = 887
# shape = (50, 6)
# window_id = 888
# shape = (50, 6)
# window_id = 889
# shape = (50, 6)
# window_id = 890
# shape = (50, 6)
# window_id = 891
# shape = (50, 6)
# window_id = 892
# shape = (50, 6)
# window_id = 893
# shape = (50, 6)
# window_id = 894
# shape = (50, 6)
# window_id = 895
# shape = (50, 6)
# window_id = 896
# shape = (50, 6)
# window_id = 897
# shape = (50, 6)
# window_id = 898
# shape = (50, 6)
# window_id = 899
# shape = (50, 6)
# window_id = 900
# shape = (50, 6)
# window_id = 901
# shape = (50, 6)
# window_id = 902
# shape = (50, 6)
# window_id = 903
# shape = (50, 6)
# window_id = 904
# shape = (50, 6)
# window_id = 905
# shape = (50, 6)
# window_id = 906
# shape = (50, 6)
# window_id = 907
# shape = (50, 6)
# window_id = 908
# shape = (50, 6)
# window_id = 909
# shape = (50, 6)
# window_id = 910
# shape = (50, 6)
# window_id = 911
# shape = (50, 6)
# window_id = 912
# shape = (50, 6)
# window_id = 913
# shape = (50, 6)
# window_id = 914
# shape = (50, 6)
# window_id = 915
# shape = (50, 6)
# window_id = 916
# shape = (50, 6)
# window_id = 917
# shape = (50, 6)
# window_id = 918
# shape = (50, 6)
# window_id = 919
# shape = (50, 6)
# window_id = 920
# shape = (50, 6)
# window_id = 921
# shape = (50, 6)
# window_id = 922
# shape = (50, 6)
# window_id = 923
# shape = (50, 6)
# window_id = 924
# shape = (50, 6)
# window_id = 925
# shape = (50, 6)
# window_id = 926
# shape = (50, 6)
# window_id = 927
# shape = (50, 6)
# window_id = 928
# shape = (50, 6)
# window_id = 929
# shape = (50, 6)
# window_id = 930
# shape = (50, 6)
# window_id = 931
# shape = (50, 6)
# window_id = 932
# shape = (50, 6)
# window_id = 933
# shape = (50, 6)
# window_id = 934
# shape = (50, 6)
# window_id = 935
# shape = (50, 6)
# window_id = 936
# shape = (50, 6)
# window_id = 937
# shape = (50, 6)
# window_id = 938
# shape = (50, 6)
# window_id = 939
# shape = (50, 6)
# window_id = 940
# shape = (50, 6)
# window_id = 941
# shape = (50, 6)
# window_id = 942
# shape = (50, 6)
# window_id = 943
# shape = (50, 6)
# window_id = 944
# shape = (50, 6)
# window_id = 945
# shape = (50, 6)
# window_id = 946
# shape = (50, 6)
# window_id = 947
# shape = (50, 6)
# window_id = 948
# shape = (50, 6)
# window_id = 949
# shape = (50, 6)
# window_id = 950
# shape = (50, 6)
# window_id = 951
# shape = (50, 6)
# window_id = 952
# shape = (50, 6)
# window_id = 953
# shape = (50, 6)
# window_id = 954
# shape = (50, 6)
# window_id = 955
# shape = (50, 6)
# window_id = 956
# shape = (50, 6)
# window_id = 957
# shape = (50, 6)
# window_id = 958
# shape = (50, 6)
# window_id = 959
# shape = (50, 6)
# window_id = 960
# shape = (50, 6)
# window_id = 961
# shape = (50, 6)
# window_id = 962
# shape = (50, 6)
# window_id = 963
# shape = (50, 6)
# window_id = 964
# shape = (50, 6)
# window_id = 965
# shape = (50, 6)
# window_id = 966
# shape = (50, 6)
# window_id = 967
# shape = (50, 6)
# window_id = 968
# shape = (50, 6)
# window_id = 969
# shape = (50, 6)
# window_id = 970
# shape = (50, 6)
# window_id = 971
# shape = (50, 6)
# window_id = 972
# shape = (50, 6)
# window_id = 973
# shape = (50, 6)
# window_id = 974
# shape = (50, 6)
# window_id = 975
# shape = (50, 6)
# window_id = 976
# shape = (50, 6)
# window_id = 977
# shape = (50, 6)
# window_id = 978
# shape = (50, 6)
# window_id = 979
# shape = (50, 6)
# window_id = 980
# shape = (50, 6)
# window_id = 981
# shape = (50, 6)
# window_id = 982
# shape = (50, 6)
# window_id = 983
# shape = (50, 6)
# window_id = 984
# shape = (50, 6)
# window_id = 985
# shape = (50, 6)
# window_id = 986
# shape = (50, 6)
# window_id = 987
# shape = (50, 6)
# window_id = 988
# shape = (50, 6)
# window_id = 989
# shape = (50, 6)
# window_id = 990
# shape = (50, 6)
# window_id = 991
# shape = (50, 6)
# window_id = 992
# shape = (50, 6)
# window_id = 993
# shape = (50, 6)
# window_id = 994
# shape = (50, 6)
# window_id = 995
# shape = (50, 6)
# window_id = 996
# shape = (50, 6)
# window_id = 997
# shape = (50, 6)
# window_id = 998
# shape = (50, 6)
# window_id = 999
# shape = (50, 6)
# window_id = 1000
# shape = (50, 6)
# window_id = 1001
# shape = (50, 6)
# window_id = 1002
# shape = (50, 6)
# window_id = 1003
# shape = (50, 6)
# window_id = 1004
# shape = (50, 6)
# window_id = 1005
# shape = (50, 6)
# window_id = 1006
# shape = (50, 6)
# window_id = 1007
# shape = (50, 6)
# window_id = 1008
# shape = (50, 6)
# window_id = 1009
# shape = (50, 6)
# window_id = 1010
# shape = (50, 6)
# window_id = 1011
# shape = (50, 6)
# window_id = 1012
# shape = (50, 6)
# window_id = 1013
# shape = (50, 6)
# window_id = 1014
# shape = (50, 6)
# window_id = 1015
# shape = (50, 6)
# window_id = 1016
# shape = (50, 6)
# window_id = 1017
# shape = (50, 6)
# window_id = 1018
# shape = (50, 6)
# window_id = 1019
# shape = (50, 6)
# window_id = 1020
# shape = (50, 6)
# window_id = 1021
# shape = (50, 6)
# window_id = 1022
# shape = (50, 6)
# window_id = 1023
# shape = (50, 6)
# window_id = 1024
# shape = (50, 6)
# window_id = 1025
# shape = (50, 6)
# window_id = 1026
# shape = (50, 6)
# window_id = 1027
# shape = (50, 6)
# window_id = 1028
# shape = (50, 6)
# window_id = 1029
# shape = (50, 6)
# window_id = 1030
# shape = (50, 6)
# window_id = 1031
# shape = (50, 6)
# window_id = 1032
# shape = (50, 6)
# window_id = 1033
# shape = (50, 6)
# window_id = 1034
# shape = (50, 6)
# window_id = 1035
# shape = (50, 6)
# window_id = 1036
# shape = (50, 6)
# window_id = 1037
# shape = (50, 6)
# window_id = 1038
# shape = (50, 6)
# window_id = 1039
# shape = (50, 6)
# window_id = 1040
# shape = (50, 6)
# window_id = 1041
# shape = (50, 6)
# window_id = 1042
# shape = (50, 6)
# window_id = 1043
# shape = (50, 6)
# window_id = 1044
# shape = (50, 6)
# window_id = 1045
# shape = (50, 6)
# window_id = 1046
# shape = (50, 6)
# window_id = 1047
# shape = (50, 6)
# window_id = 1048
# shape = (50, 6)
# window_id = 1049
# shape = (50, 6)
# window_id = 1050
# shape = (50, 6)
# window_id = 1051
# shape = (50, 6)
# window_id = 1052
# shape = (50, 6)
# window_id = 1053
# shape = (50, 6)
# window_id = 1054
# shape = (50, 6)
# window_id = 1055
# shape = (50, 6)
# window_id = 1056
# shape = (50, 6)
# window_id = 1057
# shape = (50, 6)
# window_id = 1058
# shape = (50, 6)
# window_id = 1059
# shape = (50, 6)
# window_id = 1060
# shape = (50, 6)
# window_id = 1061
# shape = (50, 6)
# window_id = 1062
# shape = (50, 6)
# window_id = 1063
# shape = (50, 6)
# window_id = 1064
# shape = (50, 6)
# window_id = 1065
# shape = (50, 6)
# window_id = 1066
# shape = (50, 6)
# window_id = 1067
# shape = (50, 6)
# window_id = 1068
# shape = (50, 6)
# window_id = 1069
# shape = (50, 6)
# window_id = 1070
# shape = (50, 6)
# window_id = 1071
# shape = (50, 6)
# window_id = 1072
# shape = (50, 6)
# window_id = 1073
# shape = (50, 6)
# window_id = 1074
# shape = (50, 6)
# window_id = 1075
# shape = (50, 6)
# window_id = 1076
# shape = (50, 6)
# window_id = 1077
# shape = (50, 6)
# window_id = 1078
# shape = (50, 6)
# window_id = 1079
# shape = (50, 6)
# window_id = 1080
# shape = (50, 6)
# window_id = 1081
# shape = (50, 6)
# window_id = 1082
# shape = (50, 6)
# window_id = 1083
# shape = (50, 6)
# window_id = 1084
# shape = (50, 6)
# window_id = 1085
# shape = (50, 6)
# window_id = 1086
# shape = (50, 6)
# window_id = 1087
# shape = (50, 6)
# window_id = 1088
# shape = (50, 6)
# window_id = 1089
# shape = (50, 6)
# window_id = 1090
# shape = (50, 6)
# window_id = 1091
# shape = (50, 6)
# window_id = 1092
# shape = (50, 6)
# window_id = 1093
# shape = (50, 6)
# window_id = 1094
# shape = (50, 6)
# window_id = 1095
# shape = (50, 6)
# window_id = 1096
# shape = (50, 6)
# window_id = 1097
# shape = (50, 6)
# window_id = 1098
# shape = (50, 6)
# window_id = 1099
# shape = (50, 6)
# window_id = 1100
# shape = (50, 6)
# window_id = 1101
# shape = (50, 6)
# window_id = 1102
# shape = (50, 6)
# window_id = 1103
# shape = (50, 6)
# window_id = 1104
# shape = (50, 6)
# window_id = 1105
# shape = (50, 6)
# window_id = 1106
# shape = (50, 6)
# window_id = 1107
# shape = (50, 6)
# window_id = 1108
# shape = (50, 6)
# window_id = 1109
# shape = (50, 6)
# window_id = 1110
# shape = (50, 6)
# window_id = 1111
# shape = (50, 6)
# window_id = 1112
# shape = (50, 6)
# window_id = 1113
# shape = (50, 6)
# window_id = 1114
# shape = (50, 6)
# window_id = 1115
# shape = (50, 6)
# window_id = 1116
# shape = (50, 6)
# window_id = 1117
# shape = (50, 6)
# window_id = 1118
# shape = (50, 6)
# window_id = 1119
# shape = (50, 6)
# window_id = 1120
# shape = (50, 6)
# window_id = 1121
# shape = (50, 6)
# window_id = 1122
# shape = (50, 6)
# window_id = 1123
# shape = (50, 6)
# window_id = 1124
# shape = (50, 6)
# window_id = 1125
# shape = (50, 6)
# window_id = 1126
# shape = (50, 6)
# window_id = 1127
# shape = (50, 6)
# window_id = 1128
# shape = (50, 6)
# window_id = 1129
# shape = (50, 6)
# window_id = 1130
# shape = (50, 6)
# window_id = 1131
# shape = (50, 6)
# window_id = 1132
# shape = (50, 6)
# window_id = 1133
# shape = (50, 6)
# window_id = 1134
# shape = (50, 6)
# window_id = 1135
# shape = (50, 6)
# window_id = 1136
# shape = (50, 6)
# window_id = 1137
# shape = (50, 6)
# window_id = 1138
# shape = (50, 6)
# window_id = 1139
# shape = (50, 6)
# window_id = 1140
# shape = (50, 6)
# window_id = 1141
# shape = (50, 6)
# window_id = 1142
# shape = (50, 6)
# window_id = 1143
# shape = (50, 6)
# window_id = 1144
# shape = (50, 6)
# window_id = 1145
# shape = (50, 6)
# window_id = 1146
# shape = (50, 6)
# window_id = 1147
# shape = (50, 6)
# window_id = 1148
# shape = (50, 6)
# window_id = 1149
# shape = (50, 6)
# window_id = 1150
# shape = (50, 6)
# window_id = 1151
# shape = (50, 6)
# window_id = 1152
# shape = (50, 6)
# window_id = 1153
# shape = (50, 6)
# window_id = 1154
# shape = (50, 6)
# window_id = 1155
# shape = (50, 6)
# window_id = 1156
# shape = (50, 6)
# window_id = 1157
# shape = (50, 6)
# window_id = 1158
# shape = (50, 6)
# window_id = 1159
# shape = (50, 6)
# window_id = 1160
# shape = (50, 6)
# window_id = 1161
# shape = (50, 6)
# window_id = 1162
# shape = (50, 6)
# window_id = 1163
# shape = (50, 6)
# window_id = 1164
# shape = (50, 6)
# window_id = 1165
# shape = (50, 6)
# window_id = 1166
# shape = (50, 6)
# window_id = 1167
# shape = (50, 6)
# window_id = 1168
# shape = (50, 6)
# window_id = 1169
# shape = (50, 6)
# window_id = 1170
# shape = (50, 6)
# window_id = 1171
# shape = (50, 6)
# window_id = 1172
# shape = (50, 6)
# window_id = 1173
# shape = (50, 6)
# window_id = 1174
# shape = (50, 6)
# window_id = 1175
# shape = (50, 6)
# window_id = 1176
# shape = (50, 6)
# window_id = 1177
# shape = (50, 6)
# window_id = 1178
# shape = (50, 6)
# window_id = 1179
# shape = (50, 6)
# window_id = 1180
# shape = (50, 6)
# window_id = 1181
# shape = (50, 6)
# window_id = 1182
# shape = (50, 6)
# window_id = 1183
# shape = (50, 6)
# window_id = 1184
# shape = (50, 6)
# window_id = 1185
# shape = (50, 6)
# window_id = 1186
# shape = (50, 6)
# window_id = 1187
# shape = (50, 6)
# window_id = 1188
# shape = (50, 6)
# window_id = 1189
# shape = (50, 6)
# window_id = 1190
# shape = (50, 6)
# window_id = 1191
# shape = (50, 6)
# window_id = 1192
# shape = (50, 6)
# window_id = 1193
# shape = (50, 6)
# window_id = 1194
# shape = (50, 6)
# window_id = 1195
# shape = (50, 6)
# window_id = 1196
# shape = (50, 6)
# window_id = 1197
# shape = (50, 6)
# window_id = 1198
# shape = (50, 6)
# window_id = 1199
# shape = (50, 6)
# window_id = 1200
# shape = (50, 6)
# window_id = 1201
# shape = (50, 6)
# window_id = 1202
# shape = (50, 6)
# window_id = 1203
# shape = (50, 6)
# window_id = 1204
# shape = (50, 6)
# window_id = 1205
# shape = (50, 6)
# window_id = 1206
# shape = (50, 6)
# window_id = 1207
# shape = (50, 6)
# window_id = 1208
# shape = (50, 6)
# window_id = 1209
# shape = (50, 6)
# window_id = 1210
# shape = (50, 6)
# window_id = 1211
# shape = (50, 6)
# window_id = 1212
# shape = (50, 6)
# window_id = 1213
# shape = (50, 6)
# window_id = 1214
# shape = (50, 6)
# window_id = 1215
# shape = (50, 6)
# window_id = 1216
# shape = (50, 6)
# window_id = 1217
# shape = (50, 6)
# window_id = 1218
# shape = (50, 6)
# window_id = 1219
# shape = (50, 6)
# window_id = 1220
# shape = (50, 6)
# window_id = 1221
# shape = (50, 6)
# window_id = 1222
# shape = (50, 6)
# window_id = 1223
# shape = (50, 6)
# window_id = 1224
# shape = (50, 6)
# window_id = 1225
# shape = (50, 6)
# window_id = 1226
# shape = (50, 6)
# window_id = 1227
# shape = (50, 6)
# window_id = 1228
# shape = (50, 6)
# window_id = 1229
# shape = (50, 6)
# window_id = 1230
# shape = (50, 6)
# window_id = 1231
# shape = (50, 6)
# window_id = 1232
# shape = (50, 6)
# window_id = 1233
# shape = (50, 6)
# window_id = 1234
# shape = (50, 6)
# window_id = 1235
# shape = (50, 6)
# window_id = 1236
# shape = (50, 6)
# window_id = 1237
# shape = (50, 6)
# window_id = 1238
# shape = (50, 6)
# window_id = 1239
# shape = (50, 6)
# window_id = 1240
# shape = (50, 6)
# window_id = 1241
# shape = (50, 6)
# window_id = 1242
# shape = (50, 6)
# window_id = 1243
# shape = (50, 6)
# window_id = 1244
# shape = (50, 6)
# window_id = 1245
# shape = (50, 6)
# window_id = 1246
# shape = (50, 6)
# window_id = 1247
# shape = (50, 6)
# window_id = 1248
# shape = (50, 6)
# window_id = 1249
# shape = (50, 6)
# window_id = 1250
# shape = (50, 6)
# window_id = 1251
# shape = (50, 6)
# window_id = 1252
# shape = (50, 6)
# window_id = 1253
# shape = (50, 6)
# window_id = 1254
# shape = (50, 6)
# window_id = 1255
# shape = (50, 6)
# window_id = 1256
# shape = (50, 6)
# window_id = 1257
# shape = (50, 6)
# window_id = 1258
# shape = (50, 6)
# window_id = 1259
# shape = (50, 6)
# window_id = 1260
# shape = (50, 6)
# window_id = 1261
# shape = (50, 6)
# window_id = 1262
# shape = (50, 6)
# window_id = 1263
# shape = (50, 6)
# window_id = 1264
# shape = (50, 6)
# window_id = 1265
# shape = (50, 6)
# window_id = 1266
# shape = (50, 6)
# window_id = 1267
# shape = (50, 6)
# window_id = 1268
# shape = (50, 6)
# window_id = 1269
# shape = (50, 6)
# window_id = 1270
# shape = (50, 6)
# window_id = 1271
# shape = (50, 6)
# window_id = 1272
# shape = (50, 6)
# window_id = 1273
# shape = (50, 6)
# window_id = 1274
# shape = (50, 6)
# window_id = 1275
# shape = (50, 6)
# window_id = 1276
# shape = (50, 6)
# window_id = 1277
# shape = (50, 6)
# window_id = 1278
# shape = (50, 6)
# window_id = 1279
# shape = (50, 6)
# window_id = 1280
# shape = (50, 6)
# window_id = 1281
# shape = (50, 6)
# window_id = 1282
# shape = (50, 6)
# window_id = 1283
# shape = (50, 6)
# window_id = 1284
# shape = (50, 6)
# window_id = 1285
# shape = (50, 6)
# window_id = 1286
# shape = (50, 6)
# window_id = 1287
# shape = (50, 6)
# window_id = 1288
# shape = (50, 6)
# window_id = 1289
# shape = (50, 6)
# window_id = 1290
# shape = (50, 6)
# window_id = 1291
# shape = (50, 6)
# window_id = 1292
# shape = (50, 6)
# window_id = 1293
# shape = (50, 6)
# window_id = 1294
# shape = (50, 6)
# window_id = 1295
# shape = (50, 6)
# window_id = 1296
# shape = (50, 6)
# window_id = 1297
# shape = (50, 6)
# window_id = 1298
# shape = (50, 6)
# window_id = 1299
# shape = (50, 6)
# window_id = 1300
# shape = (50, 6)
# window_id = 1301
# shape = (50, 6)
# window_id = 1302
# shape = (50, 6)
# window_id = 1303
# shape = (50, 6)
# window_id = 1304
# shape = (50, 6)
# window_id = 1305
# shape = (50, 6)
# window_id = 1306
# shape = (50, 6)
# window_id = 1307
# shape = (50, 6)
# window_id = 1308
# shape = (50, 6)
# window_id = 1309
# shape = (50, 6)
# window_id = 1310
# shape = (50, 6)
# window_id = 1311
# shape = (50, 6)
# window_id = 1312
# shape = (50, 6)
# window_id = 1313
# shape = (50, 6)
# window_id = 1314
# shape = (50, 6)
# window_id = 1315
# shape = (50, 6)
# window_id = 1316
# shape = (50, 6)
# window_id = 1317
# shape = (50, 6)
# window_id = 1318
# shape = (50, 6)
# window_id = 1319
# shape = (50, 6)
# window_id = 1320
# shape = (50, 6)
# window_id = 1321
# shape = (50, 6)
# window_id = 1322
# shape = (50, 6)
# window_id = 1323
# shape = (50, 6)
# window_id = 1324
# shape = (50, 6)
# window_id = 1325
# shape = (50, 6)
# window_id = 1326
# shape = (50, 6)
# window_id = 1327
# shape = (50, 6)
# window_id = 1328
# shape = (50, 6)
# window_id = 1329
# shape = (50, 6)
# window_id = 1330
# shape = (50, 6)
# window_id = 1331
# shape = (50, 6)
# window_id = 1332
# shape = (50, 6)
# window_id = 1333
# shape = (50, 6)
# window_id = 1334
# shape = (50, 6)
# window_id = 1335
# shape = (50, 6)
# window_id = 1336
# shape = (50, 6)
# window_id = 1337
# shape = (50, 6)
# window_id = 1338
# shape = (50, 6)
# window_id = 1339
# shape = (50, 6)
# window_id = 1340
# shape = (50, 6)
# window_id = 1341
# shape = (50, 6)
# window_id = 1342
# shape = (50, 6)
# window_id = 1343
# shape = (50, 6)
# window_id = 1344
# shape = (50, 6)
# window_id = 1345
# shape = (50, 6)
# window_id = 1346
# shape = (50, 6)
# window_id = 1347
# shape = (50, 6)
# window_id = 1348
# shape = (50, 6)
# window_id = 1349
# shape = (50, 6)
# window_id = 1350
# shape = (50, 6)
# window_id = 1351
# shape = (50, 6)
# window_id = 1352
# shape = (50, 6)
# window_id = 1353
# shape = (50, 6)
# window_id = 1354
# shape = (50, 6)
# window_id = 1355
# shape = (50, 6)
# window_id = 1356
# shape = (50, 6)
# window_id = 1357
# shape = (50, 6)
# window_id = 1358
# shape = (50, 6)
# window_id = 1359
# shape = (50, 6)
# window_id = 1360
# shape = (50, 6)
# window_id = 1361
# shape = (50, 6)
# window_id = 1362
# shape = (50, 6)
# window_id = 1363
# shape = (50, 6)
# window_id = 1364
# shape = (50, 6)
# window_id = 1365
# shape = (50, 6)
# window_id = 1366
# shape = (50, 6)
# window_id = 1367
# shape = (50, 6)
# window_id = 1368
# shape = (50, 6)
# window_id = 1369
# shape = (50, 6)
# window_id = 1370
# shape = (50, 6)
# window_id = 1371
# shape = (50, 6)
# window_id = 1372
# shape = (50, 6)
# window_id = 1373
# shape = (50, 6)
# window_id = 1374
# shape = (50, 6)
# window_id = 1375
# shape = (50, 6)
# window_id = 1376
# shape = (50, 6)
# window_id = 1377
# shape = (50, 6)
# window_id = 1378
# shape = (50, 6)
# window_id = 1379
# shape = (50, 6)
# window_id = 1380
# shape = (50, 6)
# window_id = 1381
# shape = (50, 6)
# window_id = 1382
# shape = (50, 6)
# window_id = 1383
# shape = (50, 6)
# window_id = 1384
# shape = (50, 6)
# window_id = 1385
# shape = (50, 6)
# window_id = 1386
# shape = (50, 6)
# window_id = 1387
# shape = (50, 6)
# window_id = 1388
# shape = (50, 6)
# window_id = 1389
# shape = (50, 6)
# window_id = 1390
# shape = (50, 6)
# window_id = 1391
# shape = (50, 6)
# window_id = 1392
# shape = (50, 6)
# window_id = 1393
# shape = (50, 6)
# window_id = 1394
# shape = (50, 6)
# window_id = 1395
# shape = (50, 6)
# window_id = 1396
# shape = (50, 6)
# window_id = 1397
# shape = (50, 6)
# window_id = 1398
# shape = (50, 6)
# window_id = 1399
# shape = (50, 6)
# window_id = 1400
# shape = (50, 6)
# window_id = 1401
# shape = (50, 6)
# window_id = 1402
# shape = (50, 6)
# window_id = 1403
# shape = (50, 6)
# window_id = 1404
# shape = (50, 6)
# window_id = 1405
# shape = (50, 6)
# window_id = 1406
# shape = (50, 6)
# window_id = 1407
# shape = (50, 6)
# window_id = 1408
# shape = (50, 6)
# window_id = 1409
# shape = (50, 6)
# window_id = 1410
# shape = (50, 6)
# window_id = 1411
# shape = (50, 6)
# window_id = 1412
# shape = (50, 6)
# window_id = 1413
# shape = (50, 6)
# window_id = 1414
# shape = (50, 6)
# window_id = 1415
# shape = (50, 6)
# window_id = 1416
# shape = (50, 6)
# window_id = 1417
# shape = (50, 6)
# window_id = 1418
# shape = (50, 6)
# window_id = 1419
# shape = (50, 6)
# window_id = 1420
# shape = (50, 6)
# window_id = 1421
# shape = (50, 6)
# window_id = 1422
# shape = (50, 6)
# window_id = 1423
# shape = (50, 6)
# window_id = 1424
# shape = (50, 6)
# window_id = 1425
# shape = (50, 6)
# window_id = 1426
# shape = (50, 6)
# window_id = 1427
# shape = (50, 6)
# window_id = 1428
# shape = (50, 6)
# window_id = 1429
# shape = (50, 6)
# window_id = 1430
# shape = (50, 6)
# window_id = 1431
# shape = (50, 6)
# window_id = 1432
# shape = (50, 6)
# window_id = 1433
# shape = (50, 6)
# window_id = 1434
# shape = (50, 6)
# window_id = 1435
# shape = (50, 6)
# window_id = 1436
# shape = (50, 6)
# window_id = 1437
# shape = (50, 6)
# window_id = 1438
# shape = (50, 6)
# window_id = 1439
# shape = (50, 6)
# window_id = 1440
# shape = (50, 6)
# window_id = 1441
# shape = (50, 6)
# window_id = 1442
# shape = (50, 6)
# window_id = 1443
# shape = (50, 6)
# window_id = 1444
# shape = (50, 6)
# window_id = 1445
# shape = (50, 6)
# window_id = 1446
# shape = (50, 6)
# window_id = 1447
# shape = (50, 6)
# window_id = 1448
# shape = (50, 6)
# window_id = 1449
# shape = (50, 6)
# window_id = 1450
# shape = (50, 6)
# window_id = 1451
# shape = (50, 6)
# window_id = 1452
# shape = (50, 6)
# window_id = 1453
# shape = (50, 6)
# window_id = 1454
# shape = (50, 6)
# window_id = 1455
# shape = (50, 6)
# window_id = 1456
# shape = (50, 6)
# window_id = 1457
# shape = (50, 6)
# window_id = 1458
# shape = (50, 6)
# window_id = 1459
# shape = (50, 6)
# window_id = 1460
# shape = (50, 6)
# window_id = 1461
# shape = (50, 6)
# window_id = 1462
# shape = (50, 6)
# window_id = 1463
# shape = (50, 6)
# window_id = 1464
# shape = (50, 6)
# window_id = 1465
# shape = (50, 6)
# window_id = 1466
# shape = (50, 6)
# window_id = 1467
# shape = (50, 6)
# window_id = 1468
# shape = (50, 6)
# window_id = 1469
# shape = (50, 6)
# window_id = 1470
# shape = (50, 6)
# window_id = 1471
# shape = (50, 6)
# window_id = 1472
# shape = (50, 6)
# window_id = 1473
# shape = (50, 6)
# window_id = 1474
# shape = (50, 6)
# window_id = 1475
# shape = (50, 6)
# window_id = 1476
# shape = (50, 6)
# window_id = 1477
# shape = (50, 6)
# window_id = 1478
# shape = (50, 6)
# window_id = 1479
# shape = (50, 6)
# window_id = 1480
# shape = (50, 6)
# window_id = 1481
# shape = (50, 6)
# window_id = 1482
# shape = (50, 6)
# window_id = 1483
# shape = (50, 6)
# window_id = 1484
# shape = (50, 6)
# window_id = 1485
# shape = (50, 6)
# window_id = 1486
# shape = (50, 6)
# window_id = 1487
# shape = (50, 6)
# ...
# shape = (50, 6)
# window_id = 62182
# shape = (50, 6)
# window_id = 62183
# shape = (50, 6)
# window_id = 62184
# shape = (50, 6)
# window_id = 62185
# shape = (50, 6)
# window_id = 62186
# shape = (50, 6)
# window_id = 62187
# shape = (50, 6)
# window_id = 62188
# shape = (50, 6)
# window_id = 62189
# shape = (50, 6)
# window_id = 62190
# shape = (50, 6)
# window_id = 62191
# shape = (50, 6)
# window_id = 62192
# shape = (50, 6)
# window_id = 62193
# shape = (50, 6)
# window_id = 62194
# shape = (50, 6)
# window_id = 62195
# shape = (50, 6)
# window_id = 62196
# shape = (50, 6)
# window_id = 62197
# shape = (50, 6)
# window_id = 62198
# shape = (50, 6)
# window_id = 62199
# shape = (50, 6)
# window_id = 62200
# shape = (50, 6)
# window_id = 62201
# shape = (50, 6)
# window_id = 62202
# shape = (50, 6)
# window_id = 62203
# shape = (50, 6)
# window_id = 62204
# shape = (50, 6)
# window_id = 62205
# shape = (50, 6)
# window_id = 62206
# shape = (50, 6)
# window_id = 62207
# shape = (50, 6)
# window_id = 62208
# shape = (50, 6)
# window_id = 62209
# shape = (50, 6)
# window_id = 62210
# shape = (50, 6)
# window_id = 62211
# shape = (50, 6)
# window_id = 62212
# shape = (50, 6)
# window_id = 62213
# shape = (50, 6)
# window_id = 62214
# shape = (50, 6)
# window_id = 62215
# shape = (50, 6)
# window_id = 62216
# shape = (50, 6)
# window_id = 62217
# shape = (50, 6)
# window_id = 62218
# shape = (50, 6)
# window_id = 62219
# shape = (50, 6)
# window_id = 62220
# shape = (50, 6)
# window_id = 62221
# shape = (50, 6)
# window_id = 62222
# shape = (50, 6)
# window_id = 62223
# shape = (50, 6)
# window_id = 62224
# shape = (50, 6)
# window_id = 62225
# shape = (50, 6)
# window_id = 62226
# shape = (50, 6)
# window_id = 62227
# shape = (50, 6)
# window_id = 62228
# shape = (50, 6)
# window_id = 62229
# shape = (50, 6)
# window_id = 62230
# shape = (50, 6)
# window_id = 62231
# shape = (50, 6)
# window_id = 62232
# shape = (50, 6)
# window_id = 62233
# shape = (50, 6)
# window_id = 62234
# shape = (50, 6)
# window_id = 62235
# shape = (50, 6)
# window_id = 62236
# shape = (50, 6)
# window_id = 62237
# shape = (50, 6)
# window_id = 62238
# shape = (50, 6)
# window_id = 62239
# shape = (50, 6)
# window_id = 62240
# shape = (50, 6)
# window_id = 62241
# shape = (50, 6)
# window_id = 62242
# shape = (50, 6)
# window_id = 62243
# shape = (50, 6)
# window_id = 62244
# shape = (50, 6)
# window_id = 62245
# shape = (50, 6)
# window_id = 62246
# shape = (50, 6)
# window_id = 62247
# shape = (50, 6)
# window_id = 62248
# shape = (50, 6)
# window_id = 62249
# shape = (50, 6)
# window_id = 62250
# shape = (50, 6)
# window_id = 62251
# shape = (50, 6)
# window_id = 62252
# shape = (50, 6)
# window_id = 62253
# shape = (50, 6)
# window_id = 62254
# shape = (50, 6)
# window_id = 62255
# shape = (50, 6)
# window_id = 62256
# shape = (50, 6)
# window_id = 62257
# shape = (50, 6)
# window_id = 62258
# shape = (50, 6)
# window_id = 62259
# shape = (50, 6)
# window_id = 62260
# shape = (50, 6)
# window_id = 62261
# shape = (50, 6)
# window_id = 62262
# shape = (50, 6)
# window_id = 62263
# shape = (50, 6)
# window_id = 62264
# shape = (50, 6)
# window_id = 62265
# shape = (50, 6)
# window_id = 62266
# shape = (50, 6)
# window_id = 62267
# shape = (50, 6)
# window_id = 62268
# shape = (50, 6)
# window_id = 62269
# shape = (50, 6)
# window_id = 62270
# shape = (50, 6)
# window_id = 62271
# shape = (50, 6)
# window_id = 62272
# shape = (50, 6)
# window_id = 62273
# shape = (50, 6)
# window_id = 62274
# shape = (50, 6)
# window_id = 62275
# shape = (50, 6)
# window_id = 62276
# shape = (50, 6)
# window_id = 62277
# shape = (50, 6)
# window_id = 62278
# shape = (50, 6)
# window_id = 62279
# shape = (50, 6)
# window_id = 62280
# shape = (50, 6)
# window_id = 62281
# shape = (50, 6)
# window_id = 62282
# shape = (50, 6)
# window_id = 62283
# shape = (50, 6)
# window_id = 62284
# shape = (50, 6)
# window_id = 62285
# shape = (50, 6)
# window_id = 62286
# shape = (50, 6)
# window_id = 62287
# shape = (50, 6)
# window_id = 62288
# shape = (50, 6)
# window_id = 62289
# shape = (50, 6)
# window_id = 62290
# shape = (50, 6)
# window_id = 62291
# shape = (50, 6)
# window_id = 62292
# shape = (50, 6)
# window_id = 62293
# shape = (50, 6)
# window_id = 62294
# shape = (50, 6)
# window_id = 62295
# shape = (50, 6)
# window_id = 62296
# shape = (50, 6)
# window_id = 62297
# shape = (50, 6)
# window_id = 62298
# shape = (50, 6)
# window_id = 62299
# shape = (50, 6)
# window_id = 62300
# shape = (50, 6)
# window_id = 62301
# shape = (50, 6)
# window_id = 62302
# shape = (50, 6)
# window_id = 62303
# shape = (50, 6)
# window_id = 62304
# shape = (50, 6)
# window_id = 62305
# shape = (50, 6)
# window_id = 62306
# shape = (50, 6)
# window_id = 62307
# shape = (50, 6)
# window_id = 62308
# shape = (50, 6)
# window_id = 62309
# shape = (50, 6)
# window_id = 62310
# shape = (50, 6)
# window_id = 62311
# shape = (50, 6)
# window_id = 62312
# shape = (50, 6)
# window_id = 62313
# shape = (50, 6)
# window_id = 62314
# shape = (50, 6)
# window_id = 62315
# shape = (50, 6)
# window_id = 62316
# shape = (50, 6)
# window_id = 62317
# shape = (50, 6)
# window_id = 62318
# shape = (50, 6)
# window_id = 62319
# shape = (50, 6)
# window_id = 62320
# shape = (50, 6)
# window_id = 62321
# shape = (50, 6)
# window_id = 62322
# shape = (50, 6)
# window_id = 62323
# shape = (50, 6)
# window_id = 62324
# shape = (50, 6)
# window_id = 62325
# shape = (50, 6)
# window_id = 62326
# shape = (50, 6)
# window_id = 62327
# shape = (50, 6)
# window_id = 62328
# shape = (50, 6)
# window_id = 62329
# shape = (50, 6)
# window_id = 62330
# shape = (50, 6)
# window_id = 62331
# shape = (50, 6)
# window_id = 62332
# shape = (50, 6)
# window_id = 62333
# shape = (50, 6)
# window_id = 62334
# shape = (50, 6)
# window_id = 62335
# shape = (50, 6)
# window_id = 62336
# shape = (50, 6)
# window_id = 62337
# shape = (50, 6)
# window_id = 62338
# shape = (50, 6)
# window_id = 62339
# shape = (50, 6)
# window_id = 62340
# shape = (50, 6)
# window_id = 62341
# shape = (50, 6)
# window_id = 62342
# shape = (50, 6)
# window_id = 62343
# shape = (50, 6)
# window_id = 62344
# shape = (50, 6)
# window_id = 62345
# shape = (50, 6)
# window_id = 62346
# shape = (50, 6)
# window_id = 62347
# shape = (50, 6)
# window_id = 62348
# shape = (50, 6)
# window_id = 62349
# shape = (50, 6)
# window_id = 62350
# shape = (50, 6)
# window_id = 62351
# shape = (50, 6)
# window_id = 62352
# shape = (50, 6)
# window_id = 62353
# shape = (50, 6)
# window_id = 62354
# shape = (50, 6)
# window_id = 62355
# shape = (50, 6)
# window_id = 62356
# shape = (50, 6)
# window_id = 62357
# shape = (50, 6)
# window_id = 62358
# shape = (50, 6)
# window_id = 62359
# shape = (50, 6)
# window_id = 62360
# shape = (50, 6)
# window_id = 62361
# shape = (50, 6)
# window_id = 62362
# shape = (50, 6)
# window_id = 62363
# shape = (50, 6)
# window_id = 62364
# shape = (50, 6)
# window_id = 62365
# shape = (50, 6)
# window_id = 62366
# shape = (50, 6)
# window_id = 62367
# shape = (50, 6)
# window_id = 62368
# shape = (50, 6)
# window_id = 62369
# shape = (50, 6)
# window_id = 62370
# shape = (50, 6)
# window_id = 62371
# shape = (50, 6)
# window_id = 62372
# shape = (50, 6)
# window_id = 62373
# shape = (50, 6)
# window_id = 62374
# shape = (50, 6)
# window_id = 62375
# shape = (50, 6)
# window_id = 62376
# shape = (50, 6)
# window_id = 62377
# shape = (50, 6)
# window_id = 62378
# shape = (50, 6)
# window_id = 62379
# shape = (50, 6)
# window_id = 62380
# shape = (50, 6)
# window_id = 62381
# shape = (50, 6)
# window_id = 62382
# shape = (50, 6)
# window_id = 62383
# shape = (50, 6)
# window_id = 62384
# shape = (50, 6)
# window_id = 62385
# shape = (50, 6)
# window_id = 62386
# shape = (50, 6)
# window_id = 62387
# shape = (50, 6)
# window_id = 62388
# shape = (50, 6)
# window_id = 62389
# shape = (50, 6)
# window_id = 62390
# shape = (50, 6)
# window_id = 62391
# shape = (50, 6)
# window_id = 62392
# shape = (50, 6)
# window_id = 62393
# shape = (50, 6)
# window_id = 62394
# shape = (50, 6)
# window_id = 62395
# shape = (50, 6)
# window_id = 62396
# shape = (50, 6)
# window_id = 62397
# shape = (50, 6)
# window_id = 62398
# shape = (50, 6)
# window_id = 62399
# shape = (50, 6)
# window_id = 62400
# shape = (50, 6)
# window_id = 62401
# shape = (50, 6)
# window_id = 62402
# shape = (50, 6)
# window_id = 62403
# shape = (50, 6)
# window_id = 62404
# shape = (50, 6)
# window_id = 62405
# shape = (50, 6)
# window_id = 62406
# shape = (50, 6)
# window_id = 62407
# shape = (50, 6)
# window_id = 62408
# shape = (50, 6)
# window_id = 62409
# shape = (50, 6)
# window_id = 62410
# shape = (50, 6)
# window_id = 62411
# shape = (50, 6)
# window_id = 62412
# shape = (50, 6)
# window_id = 62413
# shape = (50, 6)
# window_id = 62414
# shape = (50, 6)
# window_id = 62415
# shape = (50, 6)
# window_id = 62416
# shape = (50, 6)
# window_id = 62417
# shape = (50, 6)
# window_id = 62418
# shape = (50, 6)
# window_id = 62419
# shape = (50, 6)
# window_id = 62420
# shape = (50, 6)
# window_id = 62421
# shape = (50, 6)
# window_id = 62422
# shape = (50, 6)
# window_id = 62423
# shape = (50, 6)
# window_id = 62424
# shape = (50, 6)
# window_id = 62425
# shape = (50, 6)
# window_id = 62426
# shape = (50, 6)
# window_id = 62427
# shape = (50, 6)
# window_id = 62428
# shape = (50, 6)
# window_id = 62429
# shape = (50, 6)
# window_id = 62430
# shape = (50, 6)
# window_id = 62431
# shape = (50, 6)
# window_id = 62432
# shape = (50, 6)
# window_id = 62433
# shape = (50, 6)
# window_id = 62434
# shape = (50, 6)
# window_id = 62435
# shape = (50, 6)
# window_id = 62436
# shape = (50, 6)
# window_id = 62437
# shape = (50, 6)
# window_id = 62438
# shape = (50, 6)
# window_id = 62439
# shape = (50, 6)
# window_id = 62440
# shape = (50, 6)
# window_id = 62441
# shape = (50, 6)
# window_id = 62442
# shape = (50, 6)
# window_id = 62443
# shape = (50, 6)
# window_id = 62444
# shape = (50, 6)
# window_id = 62445
# shape = (50, 6)
# window_id = 62446
# shape = (50, 6)
# window_id = 62447
# shape = (50, 6)
# window_id = 62448
# shape = (50, 6)
# window_id = 62449
# shape = (50, 6)
# window_id = 62450
# shape = (50, 6)
# window_id = 62451
# shape = (50, 6)
# window_id = 62452
# shape = (50, 6)
# window_id = 62453
# shape = (50, 6)
# window_id = 62454
# shape = (50, 6)
# window_id = 62455
# shape = (50, 6)
# window_id = 62456
# shape = (50, 6)
# window_id = 62457
# shape = (50, 6)
# window_id = 62458
# shape = (50, 6)
# window_id = 62459
# shape = (50, 6)
# window_id = 62460
# shape = (50, 6)
# window_id = 62461
# shape = (50, 6)
# window_id = 62462
# shape = (50, 6)
# window_id = 62463
# shape = (50, 6)
# window_id = 62464
# shape = (50, 6)
# window_id = 62465
# shape = (50, 6)
# window_id = 62466
# shape = (50, 6)
# window_id = 62467
# shape = (50, 6)
# window_id = 62468
# shape = (50, 6)
# window_id = 62469
# shape = (50, 6)
# window_id = 62470
# shape = (50, 6)
# window_id = 62471
# shape = (50, 6)
# window_id = 62472
# shape = (50, 6)
# window_id = 62473
# shape = (50, 6)
# window_id = 62474
# shape = (50, 6)
# window_id = 62475
# shape = (50, 6)
# window_id = 62476
# shape = (50, 6)
# window_id = 62477
# shape = (50, 6)
# window_id = 62478
# shape = (50, 6)
# window_id = 62479
# shape = (50, 6)
# window_id = 62480
# shape = (50, 6)
# window_id = 62481
# shape = (50, 6)
# window_id = 62482
# shape = (50, 6)
# window_id = 62483
# shape = (50, 6)
# window_id = 62484
# shape = (50, 6)
# window_id = 62485
# shape = (50, 6)
# window_id = 62486
# shape = (50, 6)
# window_id = 62487
# shape = (50, 6)
# window_id = 62488
# shape = (50, 6)
# window_id = 62489
# shape = (50, 6)
# window_id = 62490
# shape = (50, 6)
# window_id = 62491
# shape = (50, 6)
# window_id = 62492
# shape = (50, 6)
# window_id = 62493
# shape = (50, 6)
# window_id = 62494
# shape = (50, 6)
# window_id = 62495
# shape = (50, 6)
# window_id = 62496
# shape = (50, 6)
# window_id = 62497
# shape = (50, 6)
# window_id = 62498
# shape = (50, 6)
# window_id = 62499
# shape = (50, 6)
# window_id = 62500
# shape = (50, 6)
# window_id = 62501
# shape = (50, 6)
# window_id = 62502
# shape = (50, 6)
# window_id = 62503
# shape = (50, 6)
# window_id = 62504
# shape = (50, 6)
# window_id = 62505
# shape = (50, 6)
# window_id = 62506
# shape = (50, 6)
# window_id = 62507
# shape = (50, 6)
# window_id = 62508
# shape = (50, 6)
# window_id = 62509
# shape = (50, 6)
# window_id = 62510
# shape = (50, 6)
# window_id = 62511
# shape = (50, 6)
# window_id = 62512
# shape = (50, 6)
# window_id = 62513
# shape = (50, 6)
# window_id = 62514
# shape = (50, 6)
# window_id = 62515
# shape = (50, 6)
# window_id = 62516
# shape = (50, 6)
# window_id = 62517
# shape = (50, 6)
# window_id = 62518
# shape = (50, 6)
# window_id = 62519
# shape = (50, 6)
# window_id = 62520
# shape = (50, 6)
# window_id = 62521
# shape = (50, 6)
# window_id = 62522
# shape = (50, 6)
# window_id = 62523
# shape = (50, 6)
# window_id = 62524
# shape = (50, 6)
# window_id = 62525
# shape = (50, 6)
# window_id = 62526
# shape = (50, 6)
# window_id = 62527
# shape = (50, 6)
# window_id = 62528
# shape = (50, 6)
# window_id = 62529
# shape = (50, 6)
# window_id = 62530
# shape = (50, 6)
# window_id = 62531
# shape = (50, 6)
# window_id = 62532
# shape = (50, 6)
# window_id = 62533
# shape = (50, 6)
# window_id = 62534
# shape = (50, 6)
# window_id = 62535
# shape = (50, 6)
# window_id = 62536
# shape = (50, 6)
# window_id = 62537
# shape = (50, 6)
# window_id = 62538
# shape = (50, 6)
# window_id = 62539
# shape = (50, 6)
# window_id = 62540
# shape = (50, 6)
# window_id = 62541
# shape = (50, 6)
# window_id = 62542
# shape = (50, 6)
# window_id = 62543
# shape = (50, 6)
# window_id = 62544
# shape = (50, 6)
# window_id = 62545
# shape = (50, 6)
# window_id = 62546
# shape = (50, 6)
# window_id = 62547
# shape = (50, 6)
# window_id = 62548
# shape = (50, 6)
# window_id = 62549
# shape = (50, 6)
# window_id = 62550
# shape = (50, 6)
# window_id = 62551
# shape = (50, 6)
# window_id = 62552
# shape = (50, 6)
# window_id = 62553
# shape = (50, 6)
# window_id = 62554
# shape = (50, 6)
# window_id = 62555
# shape = (50, 6)
# window_id = 62556
# shape = (50, 6)
# window_id = 62557
# shape = (50, 6)
# window_id = 62558
# shape = (50, 6)
# window_id = 62559
# shape = (50, 6)
# window_id = 62560
# shape = (50, 6)
# window_id = 62561
# shape = (50, 6)
# window_id = 62562
# shape = (50, 6)
# window_id = 62563
# shape = (50, 6)
# window_id = 62564
# shape = (50, 6)
# window_id = 62565
# shape = (50, 6)
# window_id = 62566
# shape = (50, 6)
# window_id = 62567
# shape = (50, 6)
# window_id = 62568
# shape = (50, 6)
# window_id = 62569
# shape = (50, 6)
# window_id = 62570
# shape = (50, 6)
# window_id = 62571
# shape = (50, 6)
# window_id = 62572
# shape = (50, 6)
# window_id = 62573
# shape = (50, 6)
# window_id = 62574
# shape = (50, 6)
# window_id = 62575
# shape = (50, 6)
# window_id = 62576
# shape = (50, 6)
# window_id = 62577
# shape = (50, 6)
# window_id = 62578
# shape = (50, 6)
# window_id = 62579
# shape = (50, 6)
# window_id = 62580
# shape = (50, 6)
# window_id = 62581
# shape = (50, 6)
# window_id = 62582
# shape = (50, 6)
# window_id = 62583
# shape = (50, 6)
# window_id = 62584
# shape = (50, 6)
# window_id = 62585
# shape = (50, 6)
# window_id = 62586
# shape = (50, 6)
# window_id = 62587
# shape = (50, 6)
# window_id = 62588
# shape = (50, 6)
# window_id = 62589
# shape = (50, 6)
# window_id = 62590
# shape = (50, 6)
# window_id = 62591
# shape = (50, 6)
# window_id = 62592
# shape = (50, 6)
# window_id = 62593
# shape = (50, 6)
# window_id = 62594
# shape = (50, 6)
# window_id = 62595
# shape = (50, 6)
# window_id = 62596
# shape = (50, 6)
# window_id = 62597
# shape = (50, 6)
# window_id = 62598
# shape = (50, 6)
# window_id = 62599
# shape = (50, 6)
# window_id = 62600
# shape = (50, 6)
# window_id = 62601
# shape = (50, 6)
# window_id = 62602
# shape = (50, 6)
# window_id = 62603
# shape = (50, 6)
# window_id = 62604
# shape = (50, 6)
# window_id = 62605
# shape = (50, 6)
# window_id = 62606
# shape = (50, 6)
# window_id = 62607
# shape = (50, 6)
# window_id = 62608
# shape = (50, 6)
# window_id = 62609
# shape = (50, 6)
# window_id = 62610
# shape = (50, 6)
# window_id = 62611
# shape = (50, 6)
# window_id = 62612
# shape = (50, 6)
# window_id = 62613
# shape = (50, 6)
# window_id = 62614
# shape = (50, 6)
# window_id = 62615
# shape = (50, 6)
# window_id = 62616
# shape = (50, 6)
# window_id = 62617
# shape = (50, 6)
# window_id = 62618
# shape = (50, 6)
# window_id = 62619
# shape = (50, 6)
# window_id = 62620
# shape = (50, 6)
# window_id = 62621
# shape = (50, 6)
# window_id = 62622
# shape = (50, 6)
# window_id = 62623
# shape = (50, 6)
# window_id = 62624
# shape = (50, 6)
# window_id = 62625
# shape = (50, 6)
# window_id = 62626
# shape = (50, 6)
# window_id = 62627
# shape = (50, 6)
# window_id = 62628
# shape = (50, 6)
# window_id = 62629
# shape = (50, 6)
# window_id = 62630
# shape = (50, 6)
# window_id = 62631
# shape = (50, 6)
# window_id = 62632
# shape = (50, 6)
# window_id = 62633
# shape = (50, 6)
# window_id = 62634
# shape = (50, 6)
# window_id = 62635
# shape = (50, 6)
# window_id = 62636
# shape = (50, 6)
# window_id = 62637
# shape = (50, 6)
# window_id = 62638
# shape = (50, 6)
# window_id = 62639
# shape = (50, 6)
# window_id = 62640
# shape = (50, 6)
# window_id = 62641
# shape = (50, 6)
# window_id = 62642
# shape = (50, 6)
# window_id = 62643
# shape = (50, 6)
# window_id = 62644
# shape = (50, 6)
# window_id = 62645
# shape = (50, 6)
# window_id = 62646
# shape = (50, 6)
# window_id = 62647
# shape = (50, 6)
# window_id = 62648
# shape = (50, 6)
# window_id = 62649
# shape = (50, 6)
# window_id = 62650
# shape = (50, 6)
# window_id = 62651
# shape = (50, 6)

# %%
X = np.asarray(X)
y = np.asarray(y)

print(f"X shape = {X.shape}")
print(f"y shape = {y.shape}")
# Out:
# X shape = (62652, 50, 6)
# y shape = (62652,)

# %% [markdown]
# We can do a similar test/train split for demonstration purposes. Remember that you will have to split your data by subjects, not radomly.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2, train_size=0.8)

y_train = np.asarray(pd.get_dummies(y_train), dtype=np.float32)
y_test = np.asarray(pd.get_dummies(y_test), dtype=np.float32)

# %%
print(f"X_train shape = {X_train.shape}")
print(f"y_train shape = {y_train.shape}")

print(f"X_test shape = {X_test.shape}")
print(f"y_test shape = {y_test.shape}")
# Out:
# X_train shape = (50121, 50, 6)
# y_train shape = (50121, 14)
# X_test shape = (12531, 50, 6)
# y_test shape = (12531, 14)

# %% [markdown]
# Now we are ready to start the training process

# %%
model.compile(
    optimizer=optimizers.SGD(lr=0.001),
    loss='binary_crossentropy',
    metrics = ['accuracy'])

# %%
model.fit(X_train, y_train,
        batch_size=2, epochs=10)
# Out:
# Train on 50121 samples
# Epoch 1/10
# 50121/50121 [==============================] - 307s 6ms/sample - loss: 0.2376 - accuracy: 0.9287
# Epoch 2/10
# 50121/50121 [==============================] - 307s 6ms/sample - loss: 0.2181 - accuracy: 0.9297
# Epoch 3/10
# 50121/50121 [==============================] - 303s 6ms/sample - loss: 0.2062 - accuracy: 0.9318
# Epoch 4/10
# 50121/50121 [==============================] - 317s 6ms/sample - loss: 0.1964 - accuracy: 0.9338
# Epoch 5/10
# 50121/50121 [==============================] - 305s 6ms/sample - loss: 0.1889 - accuracy: 0.9352
# Epoch 6/10
# 24734/50121 [=============>................] - ETA: 1:06:43 - loss: 0.1847 - accuracy: 0.9361
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/f3/3ch72mdj0q5bymvvjzvmk55h0000gn/T/ipykernel_16747/1201568748.py in <module>
#       1 model.fit(X_train, y_train,
# ----> 2         batch_size=2, epochs=10)
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/envs/pdiot/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# We can now view the accuracy of our model on the test dataset.

# %%
# stats
y_pred_ohe = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# %%
print("*" * 80)
print("Classification report")
print("*" * 80)
print(classification_report(y_true_labels, y_pred_labels))
# Out:
# ********************************************************************************
# Classification report
# ********************************************************************************
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5

# %% [markdown]
# ## Conclusion

# %% [markdown]
# You are now ready to start developing your own models for HAR. There are numerous tutorials online which you can follow to build models like LSTMs, CNNs, RFCs and many others.
#
# You have a wide choice of ways to solve this classification model. Here are a few things to think about:
#
# * What type of preprocessing do you want to apply to your data? Examples include:
#     * smoothing the sensor axes
#     * performing axis fusion
#     * extracting scalograms from the signal
#     * manually extracting features from the signal
#     * choosing to leave out certain axes
#
# * What type of model do you want to train?
#     * simple ML model
#     * deep learning model
#
# * Do you want a hierarchical model or a flat model?
#     * hierarchical models means you don't have to train the same type of model for each activity
#     * a flat model might be faster to train and apply in real time
